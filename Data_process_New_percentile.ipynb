# %%
#import src.interaction.social_interaction
#import src.interaction.code_interaction
#import buggy_commit
import pandas as pd
import numpy as np
import csv
import platform
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt

# %%
#Code
if platform.system() == 'Darwin' or platform.system() == 'Linux':
    _dir = 'Processed_data/'
else:
    _dir = 'Processed_data\\'
Files = [join(_dir, f) for f in listdir(_dir) if isfile(join(_dir, f))]
actual_file = 0
usable_files = 0
size_s = 0
size_m = 0
size_l = 0
result = []
for file in Files:
    try:
        _df = []
        actual_file += 1
        df = pd.read_pickle(file)
        buggy_commit_data_df = df.loc[0,'buggy_commit_data_df']
        commit_data_df = df.loc[0,'commit_data_df']
        commit_count = df.loc[0,'commit_count']
        sg_data_df = df.loc[0,'sg_data_df']
        cg_data_df = df.loc[0,'cg_data_df']
        if commit_data_df.shape[0] > 30:
            size_l += 1
        elif commit_data_df.shape[0] > 15:
            size_m += 1
        elif commit_data_df.shape[0] > 8:
            size_s += 1
        if commit_data_df.shape[0] < 8:
            continue
        for i in range(cg_data_df.shape[0]):
            buggy_commit_count = buggy_commit_data_df[buggy_commit_data_df['committer'] == cg_data_df.loc[i,'committer']]['count']
            if len(buggy_commit_count) == 0:
                continue
            commit_count = commit_data_df[commit_data_df['committer'] == cg_data_df.loc[i,'committer']]['count']
            if len(commit_count) == 0:
                continue
            node_degree = cg_data_df[cg_data_df['committer'] == cg_data_df.loc[i,'committer']]['count']
            #print([buggy_commit_count.values[0],commit_count.values[0],node_degree.values[0]])
            _df.append([buggy_commit_count.values[0]/commit_count.values[0],node_degree.values[0]])
        df = pd.DataFrame(_df, columns = ['per','degree'])
        if(df.shape[0] <= 0):
            continue
        usable_files += 1
        degree_d = np.array(df['degree'].values.tolist())
        #first = np.int32(np.percentile(degree_d,99.9))
        #second = np.int32(np.percentile(degree_d,75))
        #third = np.int32(np.percentile(degree_d,50))
        forth = np.int32(np.percentile(degree_d,95))
        first_l = []
        second_l = []
        third_l = []
        forth_l = []
        for i in range(df.shape[0]):
            if df.loc[i,'degree'] < forth:
                forth_l.append(df.loc[i,'per'])
            #elif df.loc[i,'degree'] < third:
            #    third_l.append(df.loc[i,'per'])
            #elif df.loc[i,'degree'] < second:
            #    second_l.append(df.loc[i,'per'])
            else:
                first_l.append(df.loc[i,'per'])
        #print(round(np.median(first_l),2),round(np.median(second_l),2),round(np.median(third_l),2),round(np.median(forth_l),2))
        result.append([file,commit_data_df.shape[0],round(np.median(first_l),2),round(np.median(forth_l),2)])
    except:
        continue
print(actual_file,usable_files)
print(size_s,size_m,size_l)
# Out:
# 233 221
# 42 83 92

# %%
c_result_df = pd.DataFrame(result, columns = ['project','c_size','c_1st','c_2nd','c_3rd','c_4th'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-6-58e0e82dc44c> in <module>
# ----> 1 c_result_df = pd.DataFrame(result, columns = ['project','c_size','c_1st','c_2nd','c_3rd','c_4th'])
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433                     if is_named_tuple(data[0]) and columns is None:
#     434                         columns = data[0]._fields
# --> 435                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     436                     columns = ensure_index(columns)
#     437
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     402     if isinstance(data[0], (list, tuple)):
#     403         return _list_to_arrays(data, columns, coerce_float=coerce_float,
# --> 404                                dtype=dtype)
#     405     elif isinstance(data[0], compat.Mapping):
#     406         return _list_of_dict_to_arrays(data, columns,
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     434         content = list(lib.to_object_array(data).T)
#     435     return _convert_object_array(content, columns, dtype=dtype,
# --> 436                                  coerce_float=coerce_float)
#     437
#     438
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _convert_object_array(content, columns, coerce_float, dtype)
#     490             raise AssertionError('{col:d} columns passed, passed data had '
#     491                                  '{con} columns'.format(col=len(columns),
# --> 492                                                         con=len(content)))
#     493
#     494     # provide soft conversion of object dtypes
#
# AssertionError: 6 columns passed, passed data had 4 columns

# %%
#Social
if platform.system() == 'Darwin' or platform.system() == 'Linux':
    _dir = 'Processed_data/'
else:
    _dir = 'Processed_data\\'
Files = [join(_dir, f) for f in listdir(_dir) if isfile(join(_dir, f))]
actual_file = 0
usable_files = 0
size_s = 0
size_m = 0
size_l = 0
result = []
for file in Files:
    try:
        _df = []
        actual_file += 1
        df = pd.read_pickle(file)
        buggy_commit_data_df = df.loc[0,'buggy_commit_data_df']
        commit_data_df = df.loc[0,'commit_data_df']
        commit_count = df.loc[0,'commit_count']
        sg_data_df = df.loc[0,'sg_data_df']
        cg_data_df = df.loc[0,'cg_data_df']
        if commit_data_df.shape[0] > 30:
            size_l += 1
        elif commit_data_df.shape[0] > 15:
            size_m += 1
        elif commit_data_df.shape[0] > 8:
            size_s += 1
        if commit_data_df.shape[0] < 8:
            continue
        for i in range(sg_data_df.shape[0]):
            buggy_commit_count = buggy_commit_data_df[buggy_commit_data_df['committer'] == sg_data_df.loc[i,'committer']]['count']
            if len(buggy_commit_count) == 0:
                continue
            commit_count = commit_data_df[commit_data_df['committer'] == sg_data_df.loc[i,'committer']]['count']
            if len(commit_count) == 0:
                continue
            node_degree = sg_data_df[sg_data_df['committer'] == sg_data_df.loc[i,'committer']]['count']
            #print([buggy_commit_count.values[0],commit_count.values[0],node_degree.values[0]])
            _df.append([buggy_commit_count.values[0]/commit_count.values[0],node_degree.values[0]])
        df = pd.DataFrame(_df, columns = ['per','degree'])
        if(df.shape[0] <= 0):
            continue
        usable_files += 1
        degree_d = np.array(df['degree'].values.tolist())
        #first = np.int32(np.percentile(degree_d,99.9))
        second = np.int32(np.percentile(degree_d,75))
        third = np.int32(np.percentile(degree_d,50))
        forth = np.int32(np.percentile(degree_d,25))
        first_l = []
        second_l = []
        third_l = []
        forth_l = []
        for i in range(df.shape[0]):
            if df.loc[i,'degree'] < forth:
                forth_l.append(df.loc[i,'per'])
            elif df.loc[i,'degree'] < third:
                third_l.append(df.loc[i,'per'])
            elif df.loc[i,'degree'] < second:
                second_l.append(df.loc[i,'per'])
            else:
                first_l.append(df.loc[i,'per'])
        #print(round(np.median(first_l),2),round(np.median(second_l),2),round(np.median(third_l),2),round(np.median(forth_l),2))
        result.append([file,commit_data_df.shape[0],round(np.median(first_l),2),round(np.median(second_l),2),round(np.median(third_l),2),round(np.median(forth_l),2)])
    except:
        continue
print(actual_file,usable_files)
print(size_s,size_m,size_l)

# %%
s_result_df = pd.DataFrame(result, columns = ['project','s_size','s_1st','s_2nd','s_3rd','s_4th'])

# %%
c_result_df_n = c_result_df.set_index('project')
s_result_df_n = s_result_df.set_index('project')

# %%
#c_result_df.to_excel('new_results/Result_data_team_c.xlsx')

# %%
joined_df = pd.concat([c_result_df_n,s_result_df_n],join='inner',axis = 1)

# %%
joined_df.dropna(inplace = True)

# %%
joined_df.to_excel('new_results/extra/Result_data_team_joined_extra.xlsx')

# %%
result
# Out:
# [['Processed Data/cocos2d-objc_final_results.pkl', 194, 0.42, 0.56],
#  ['Processed Data/termbox_final_results.pkl', 36, 0.44, 0.5],
#  ['Processed Data/twilio-csharp_final_results.pkl', 48, 0.36, 0.27],
#  ['Processed Data/active_shipping_final_results.pkl', 134, 0.4, 0.5],
#  ['Processed Data/module-starter_final_results.pkl', 24, 0.37, 1.0],
#  ['Processed Data/sprinkle_final_results.pkl', 64, 0.48, 0.8],
#  ['Processed Data/pdf-reader_final_results.pkl', 39, 0.37, 0.63],
#  ['Processed Data/MPAndroidChart_final_results.pkl', 78, 0.53, 1.0],
#  ['Processed Data/isbg_final_results.pkl', 17, 0.22, 0.43],
#  ['Processed Data/MBProgressHUD_final_results.pkl', 87, 0.39, 1.0],
#  ['Processed Data/pika_final_results.pkl', 135, 0.45, 1.0],
#  ['Processed Data/task-kensho_final_results.pkl', 10, 0.36, 0.68],
#  ['Processed Data/multiselect_final_results.pkl', 15, 0.59, 0.75],
#  ['Processed Data/django-helpdesk_final_results.pkl', 81, 0.5, 0.83],
#  ['Processed Data/pyccuracy_final_results.pkl', 15, 0.42, 0.4],
#  ['Processed Data/perlrdf_final_results.pkl', 19, 0.45, 0.61],
#  ['Processed Data/merchant_final_results.pkl', 39, 0.43, 0.49],
#  ['Processed Data/stdeb_final_results.pkl', 21, 0.34, 1.0],
#  ['Processed Data/riak-js_final_results.pkl', 51, 0.26, 0.5],
#  ['Processed Data/ocaml-cohttp_final_results.pkl', 61, 0.35, 0.7],
#  ['Processed Data/ValidateThis_final_results.pkl', 19, 0.52, 0.4],
#  ['Processed Data/models_final_results.pkl', 264, 0.37, 0.81],
#  ['Processed Data/qunit_final_results.pkl', 53, 0.47, 1.0],
#  ['Processed Data/SlickGrid_final_results.pkl', 56, 0.44, 0.71],
#  ['Processed Data/railroady_final_results.pkl', 50, 0.34, 1.0],
#  ['Processed Data/camo_final_results.pkl', 40, 0.45, 1.0],
#  ['Processed Data/thin_final_results.pkl', 86, 0.53, 1.0],
#  ['Processed Data/Plomino_final_results.pkl', 40, 0.37, 0.47],
#  ['Processed Data/node-jslint_final_results.pkl', 38, 0.24, 0.75],
#  ['Processed Data/Emacs-wgrep_final_results.pkl', 12, 0.63, 0.68],
#  ['Processed Data/material-ui_final_results.pkl', 529, 0.43, 0.88],
#  ['Processed Data/ancestry_final_results.pkl', 55, 0.42, 1.0],
#  ['Processed Data/znc_final_results.pkl', 133, 0.53, 0.67],
#  ['Processed Data/eventmachine_final_results.pkl', 117, 0.41, 1.0],
#  ['Processed Data/cairoshell_final_results.pkl', 10, 0.66, 0.75],
#  ['Processed Data/faster_require_final_results.pkl', 8, 0.39, 0.82],
#  ['Processed Data/jsdoc_final_results.pkl', 82, 0.54, 1.0],
#  ['Processed Data/network_final_results.pkl', 86, 0.32, 1.0],
#  ['Processed Data/swank-clojure_final_results.pkl', 47, 0.24, 0.49],
#  ['Processed Data/PhyloSift_final_results.pkl', 13, 0.47, 0.43],
#  ['Processed Data/homesick_final_results.pkl', 47, 0.42, 1.0],
#  ['Processed Data/acts-as-taggable-on_final_results.pkl', 160, 0.36, 1.0],
#  ['Processed Data/globalize_final_results.pkl', 26, 0.37, 0.54],
#  ['Processed Data/rkelly_final_results.pkl', 16, 0.4, 0.4],
#  ['Processed Data/textlink_final_results.pkl', 12, 0.21, 0.35],
#  ['Processed Data/cll_final_results.pkl', 33, 0.46, 0.36],
#  ['Processed Data/cperl-mode_final_results.pkl', 11, 0.24, 0.27],
#  ['Processed Data/networkx_final_results.pkl', 203, 0.55, 0.81],
#  ['Processed Data/cryptopus_final_results.pkl', 26, 0.43, 0.46],
#  ['Processed Data/styleguide_final_results.pkl', 65, 0.78, 0.6],
#  ['Processed Data/ExtUtils-MakeMaker_final_results.pkl', 51, 0.33, 0.5],
#  ['Processed Data/lfe_final_results.pkl', 33, 0.56, 1.0],
#  ['Processed Data/eclim_final_results.pkl', 41, 0.44, 0.82],
#  ['Processed Data/snuggsi_final_results.pkl', 9, 0.2, 0.18],
#  ['Processed Data/edittable_final_results.pkl', 15, 0.43, 0.67],
#  ['Processed Data/mongoid-site_final_results.pkl', 99, 0.2, 0.37],
#  ['Processed Data/mobileweb_final_results.pkl', 12, 0.29, 0.07],
#  ['Processed Data/iqvoc_final_results.pkl', 15, 0.5, 0.4],
#  ['Processed Data/jquery-ujs_final_results.pkl', 80, 0.34, 1.0],
#  ['Processed Data/urwid_final_results.pkl', 81, 0.62, 0.72],
#  ['Processed Data/django-allauth_final_results.pkl', 251, 0.48, 1.0],
#  ['Processed Data/epublib_final_results.pkl', 16, 0.38, 0.5],
#  ['Processed Data/hashie_final_results.pkl', 108, 0.3, 1.0],
#  ['Processed Data/metacpan-api_final_results.pkl', 72, 0.3, 0.52],
#  ['Processed Data/steal_final_results.pkl', 35, 0.45, 0.63],
#  ['Processed Data/fontspec_final_results.pkl', 15, 0.5, 1.0],
#  ['Processed Data/Kranc_final_results.pkl', 13, 0.33, 0.38],
#  ['Processed Data/emacs-eclim_final_results.pkl', 59, 0.58, 1.0],
#  ['Processed Data/jeweler_final_results.pkl', 45, 0.48, 0.67],
#  ['Processed Data/openlibrary_final_results.pkl', 116, 0.45, 0.51],
#  ['Processed Data/droid-fu_final_results.pkl', 14, 0.42, 0.59],
#  ['Processed Data/factory_bot_final_results.pkl', 61, 0.4, 1.0],
#  ['Processed Data/nanorc_final_results.pkl', 70, 0.64, 1.0],
#  ['Processed Data/sevenzipjbinding_final_results.pkl', 8, 0.52, 1.0],
#  ['Processed Data/metaz_final_results.pkl', 8, 0.48, 1.0],
#  ['Processed Data/munin-plugins-rails_final_results.pkl', 8, 0.34, 0.31],
#  ['Processed Data/thunderbird-conversations_final_results.pkl',
#   38,
#   0.36,
#   0.73],
#  ['Processed Data/pire_final_results.pkl', 16, 0.73, 0.52],
#  ['Processed Data/geonode_final_results.pkl', 242, 0.42, 0.58],
#  ['Processed Data/vraptor_final_results.pkl', 112, 0.36, 0.5],
#  ['Processed Data/jruby-maven-plugins_final_results.pkl', 23, 0.2, 0.33],
#  ['Processed Data/net-http-persistent_final_results.pkl', 17, 0.37, 1.0],
#  ['Processed Data/httparty_final_results.pkl', 160, 0.57, 1.0],
#  ['Processed Data/cancan_final_results.pkl', 61, 0.41, 1.0],
#  ['Processed Data/nv_final_results.pkl', 9, 0.32, 0.4],
#  ['Processed Data/voldemort_final_results.pkl', 96, 0.59, 0.67],
#  ['Processed Data/borschik_final_results.pkl', 12, 0.54, 0.39],
#  ['Processed Data/writetothem_final_results.pkl', 33, 0.44, 0.45],
#  ['Processed Data/jansson_final_results.pkl', 64, 0.39, 1.0],
#  ['Processed Data/animation_final_results.pkl', 21, 0.25, 0.5],
#  ['Processed Data/tmk_keyboard_final_results.pkl', 52, 0.39, 1.0],
#  ['Processed Data/redcloth_final_results.pkl', 29, 0.53, 0.72],
#  ['Processed Data/json_final_results.pkl', 45, 0.36, 1.0],
#  ['Processed Data/django-colorfield_final_results.pkl', 18, 0.13, 0.57],
#  ['Processed Data/Quicksilver_final_results.pkl', 35, 0.38, 0.71],
#  ['Processed Data/webpack_final_results.pkl', 462, 0.79, 1.0],
#  ['Processed Data/quran_android_final_results.pkl', 35, 0.48, 1.0],
#  ['Processed Data/tubaina_final_results.pkl', 33, 0.3, 0.5],
#  ['Processed Data/php-zmq_final_results.pkl', 18, 0.55, 0.47],
#  ['Processed Data/sip.js_final_results.pkl', 17, 0.51, 0.5],
#  ['Processed Data/browsermob-proxy_final_results.pkl', 21, 0.28, 0.6],
#  ['Processed Data/cruisecontrol.rb_final_results.pkl', 64, 0.62, 0.4],
#  ['Processed Data/neography_final_results.pkl', 60, 0.59, 0.81],
#  ['Processed Data/autojump_final_results.pkl', 60, 0.51, 1.0],
#  ['Processed Data/delayed_paperclip_final_results.pkl', 8, 0.2, 0.57],
#  ['Processed Data/django-nose_final_results.pkl', 43, 0.48, 1.0],
#  ['Processed Data/Arduino-IRremote_final_results.pkl', 42, 0.27, 0.88],
#  ['Processed Data/CMPopTipView_final_results.pkl', 41, 0.31, 1.0],
#  ['Processed Data/simplecov-html_final_results.pkl', 23, 0.34, 0.75],
#  ['Processed Data/ilbot_final_results.pkl', 21, 0.37, 0.5],
#  ['Processed Data/poolboy_final_results.pkl', 32, 0.35, 1.0],
#  ['Processed Data/Nustache_final_results.pkl', 26, 0.49, 1.0],
#  ['Processed Data/appledoc_final_results.pkl', 99, 0.45, 1.0],
#  ['Processed Data/django-watermark_final_results.pkl', 10, 0.5, 0.62],
#  ['Processed Data/pycassa_final_results.pkl', 57, 0.38, 0.83],
#  ['Processed Data/mongomapper_final_results.pkl', 106, 0.47, 0.56],
#  ['Processed Data/Amon_final_results(1).pkl', 37, 0.37, 0.83],
#  ['Processed Data/quick-tabs-chrome-extension_final_results.pkl',
#   29,
#   0.44,
#   1.0],
#  ['Processed Data/django-markitup_final_results.pkl', 21, 0.45, 0.8],
#  ['Processed Data/djbookru_final_results.pkl', 20, 0.46, 0.5],
#  ['Processed Data/vifm_final_results.pkl', 21, 0.7, 1.0],
#  ['Processed Data/eXpand_final_results.pkl', 25, 0.55, 0.33],
#  ['Processed Data/rspec-mode_final_results.pkl', 46, 0.48, 1.0],
#  ['Processed Data/seed_dump_final_results.pkl', 27, 0.25, 0.75],
#  ['Processed Data/addressable_final_results.pkl', 60, 0.48, 1.0],
#  ['Processed Data/bjoern_final_results.pkl', 24, 0.46, 1.0],
#  ['Processed Data/Bitcoin-Poker-Room_final_results.pkl', 9, 0.27, 0.36],
#  ['Processed Data/resque-status_final_results.pkl', 34, 0.34, 1.0],
#  ['Processed Data/markdown-js_final_results.pkl', 31, 0.43, 1.0],
#  ['Processed Data/IronJS_final_results.pkl', 12, 0.42, 0.49],
#  ['Processed Data/FSharpx.Extras_final_results.pkl', 73, 0.33, 0.39],
#  ['Processed Data/underscore_final_results.pkl', 295, 0.45, 1.0],
#  ['Processed Data/Shanty-Mongo_final_results.pkl', 10, 0.34, 0.75],
#  ['Processed Data/bakefile_final_results.pkl', 10, 0.46, 0.39],
#  ['Processed Data/rinari_final_results.pkl', 25, 0.29, 0.83],
#  ['Processed Data/django-json-rpc_final_results.pkl', 20, 0.4, 0.58],
#  ['Processed Data/billiard_final_results.pkl', 31, 0.29, 0.83],
#  ['Processed Data/paypal_adaptive_final_results.pkl', 27, 0.49, 0.83],
#  ['Processed Data/django-smart-selects_final_results.pkl', 39, 0.47, 1.0],
#  ['Processed Data/get-flash-videos_final_results.pkl', 63, 0.37, 0.5],
#  ['Processed Data/IronAHK_final_results.pkl', 8, 0.44, 0.33],
#  ['Processed Data/bookreader_final_results.pkl', 24, 0.55, 0.52],
#  ['Processed Data/Cork_final_results.pkl', 22, 0.28, 0.23],
#  ['Processed Data/jquery-endless-scroll_final_results.pkl', 10, 0.34, 1.0],
#  ['Processed Data/distel_final_results.pkl', 20, 0.49, 1.0],
#  ['Processed Data/openCOP_final_results.pkl', 8, 0.48, 1.0],
#  ['Processed Data/VsVim_final_results.pkl', 42, 0.59, 0.91],
#  ['Processed Data/tracmor_final_results.pkl', 11, 0.47, 0.56],
#  ['Processed Data/geddy_final_results.pkl', 106, 0.37, 0.5],
#  ['Processed Data/Ninject_final_results.pkl', 39, 0.46, 0.71],
#  ['Processed Data/ocra_final_results.pkl', 10, 0.44, 0.76],
#  ['Processed Data/annotate_models_final_results.pkl', 157, 0.46, 1.0],
#  ['Processed Data/croniter_final_results.pkl', 37, 0.59, 1.0],
#  ['Processed Data/node-csv_final_results.pkl', 39, 0.39, 1.0],
#  ['Processed Data/Memcached-Java-Client_final_results.pkl', 11, 0.67, 0.4],
#  ['Processed Data/rspec-dev_final_results.pkl', 30, 0.25, 0.33],
#  ['Processed Data/Mining-the-Social-Web_final_results.pkl', 8, 0.41, 0.42],
#  ['Processed Data/BGHUDAppKit_final_results.pkl', 13, 0.52, 0.65],
#  ['Processed Data/ete_final_results.pkl', 37, 0.51, 0.7],
#  ['Processed Data/redmine_taskjuggler_final_results.pkl', 11, 0.5, 0.43],
#  ['Processed Data/pr-downloader_final_results.pkl', 18, 0.61, 0.64],
#  ['Processed Data/hiki_final_results.pkl', 25, 0.36, 0.51],
#  ['Processed Data/TileStache_final_results.pkl', 82, 0.48, 0.68],
#  ['Processed Data/thyme_final_results.pkl', 9, 0.36, 1.0],
#  ['Processed Data/hs-tls_final_results.pkl', 36, 0.35, 0.67],
#  ['Processed Data/recaptcha_final_results.pkl', 103, 0.36, 1.0],
#  ['Processed Data/QComicBook_final_results.pkl', 9, 0.42, 0.75],
#  ['Processed Data/sfepy_final_results.pkl', 15, 0.47, 0.58],
#  ['Processed Data/tsung_final_results.pkl', 79, 0.46, 0.67],
#  ['Processed Data/jsawk_final_results.pkl', 10, 0.14, 0.75],
#  ['Processed Data/dm-serializer_final_results.pkl', 30, 0.29, 0.48],
#  ['Processed Data/gherkin2_final_results.pkl', 106, 0.4, 1.0],
#  ['Processed Data/moby_final_results.pkl', 2015, 0.51, 1.0],
#  ['Processed Data/nifty-generators_final_results.pkl', 15, 0.41, 1.0],
#  ['Processed Data/wp-lifestream_final_results.pkl', 21, 0.44, 0.33],
#  ['Processed Data/Drawpile_final_results.pkl', 25, 0.55, 0.72],
#  ['Processed Data/puppet-openssl_final_results.pkl', 28, 0.35, 0.75],
#  ['Processed Data/members_final_results.pkl', 29, 0.64, 0.47],
#  ['Processed Data/musicbrainz-server_final_results.pkl', 86, 0.49, 0.67],
#  ['Processed Data/xDoc_final_results.pkl', 12, 0.69, 0.43],
#  ['Processed Data/teambox_final_results.pkl', 32, 0.45, 0.42],
#  ['Processed Data/rubber_final_results.pkl', 77, 0.27, 0.5],
#  ['Processed Data/cascalog_final_results.pkl', 54, 0.28, 0.5],
#  ['Processed Data/albumidentify_final_results.pkl', 12, 0.42, 0.33],
#  ['Processed Data/taberareloo_final_results.pkl', 17, 0.34, 0.53],
#  ['Processed Data/vumi_final_results.pkl', 37, 0.54, 0.7],
#  ['Processed Data/haml_final_results.pkl', 87, 0.36, 1.0],
#  ['Processed Data/django-mailer-2_final_results.pkl', 12, 0.6, 0.56],
#  ['Processed Data/warbler_final_results.pkl', 63, 0.37, 1.0],
#  ['Processed Data/dokuwiki-plugin-data_final_results.pkl', 20, 0.57, 0.63],
#  ['Processed Data/keysnail_final_results.pkl', 16, 0.49, 0.75],
#  ['Processed Data/citrus_final_results.pkl', 37, 0.51, 0.6],
#  ['Processed Data/kettu_final_results.pkl', 19, 0.78, 0.5],
#  ['Processed Data/attoparsec_final_results.pkl', 40, 0.35, 1.0],
#  ['Processed Data/plutus_final_results.pkl', 15, 0.29, 0.67],
#  ['Processed Data/proper_final_results.pkl', 33, 0.58, 1.0],
#  ['Processed Data/active_hash_final_results.pkl', 51, 0.41, 0.75],
#  ['Processed Data/dnscheck_final_results.pkl', 20, 0.44, 0.34],
#  ['Processed Data/django-blog-zinnia_final_results.pkl', 51, 0.46, 0.75],
#  ['Processed Data/lawnchair_final_results.pkl', 66, 0.48, 1.0],
#  ['Processed Data/premailer_final_results.pkl', 81, 0.43, 1.0],
#  ['Processed Data/storyteller_final_results.pkl', 16, 0.65, 0.38],
#  ['Processed Data/vim-coffee-script_final_results.pkl', 32, 0.47, 1.0],
#  ['Processed Data/i18n_final_results.pkl', 94, 0.45, 1.0],
#  ['Processed Data/translation-project_final_results.pkl', 41, 0.09, 0.33],
#  ['Processed Data/filemanip_final_results.pkl', 9, 0.3, 0.38],
#  ['Processed Data/Django-facebook_final_results.pkl', 85, 0.6, 0.8],
#  ['Processed Data/Composable_final_results.pkl', 25, 0.36, 0.33],
#  ['Processed Data/xmltwig_final_results.pkl', 10, 0.57, 1.0],
#  ['Processed Data/socket.io-client_final_results.pkl', 94, 0.44, 1.0],
#  ['Processed Data/Font-Awesome_final_results.pkl', 80, 0.45, 1.0],
#  ['Processed Data/rocco_final_results.pkl', 21, 0.28, 1.0],
#  ['Processed Data/swiper_final_results.pkl', 129, 0.5, 1.0],
#  ['Processed Data/erlcloud_final_results.pkl', 158, 0.38, 0.81],
#  ['Processed Data/amon_final_results.pkl', 21, 0.45, 0.5],
#  ['Processed Data/junit4_final_results.pkl', 134, 0.4, 0.67],
#  ['Processed Data/libtrading_final_results.pkl', 14, 0.35, 0.88],
#  ['Processed Data/ccache_final_results.pkl', 14, 0.57, 0.88],
#  ['Processed Data/GLGE_final_results.pkl', 25, 0.64, 0.5],
#  ['Processed Data/ojs_final_results.pkl', 139, 0.47, 0.38],
#  ['Processed Data/shiro_final_results.pkl', 25, 0.27, 0.47],
#  ['Processed Data/magick-installer_final_results.pkl', 17, 0.18, 1.0],
#  ['Processed Data/middleman_final_results.pkl', 171, 0.36, 0.78],
#  ['Processed Data/OCUnit2JUnit_final_results.pkl', 16, 0.13, 0.5],
#  ['Processed Data/aws-lib_final_results.pkl', 26, 0.35, 0.67],
#  ['Processed Data/snes9x_final_results.pkl', 49, 0.37, 0.61],
#  ['Processed Data/sso_final_results.pkl', 11, 0.32, 0.75],
#  ['Processed Data/python-unicodecsv_final_results.pkl', 16, 0.5, 1.0],
#  ['Processed Data/iosched_final_results.pkl', 67, 0.26, 0.44],
#  ['Processed Data/go-gtk_final_results.pkl', 67, 0.49, 0.71],
#  ['Processed Data/go-tmbundle_final_results.pkl', 14, 0.23, 0.75],
#  ['Processed Data/npm_final_results.pkl', 31, 0.31, 1.0],
#  ['Processed Data/django-shop_final_results.pkl', 76, 0.38, 0.88],
#  ['Processed Data/ack.vim_final_results.pkl', 39, 0.37, 1.0],
#  ['Processed Data/freeCodeCamp_final_results.pkl', 743, 0.34, 0.8],
#  ['Processed Data/commandergenius_final_results.pkl', 15, 0.59, 0.41],
#  ['Processed Data/shadowsocks_final_results.pkl', 30, 0.28, 0.88],
#  ['Processed Data/libRocket_final_results.pkl', 56, 0.28, 0.75],
#  ['Processed Data/erjang_final_results.pkl', 11, 0.47, 0.5],
#  ['Processed Data/kryo-serializers_final_results.pkl', 24, 0.3, 0.88],
#  ['Processed Data/RestKit_final_results.pkl', 178, 0.5, 0.75],
#  ['Processed Data/NSubstitute_final_results.pkl', 26, 0.4, 0.81],
#  ['Processed Data/WebLoader_final_results.pkl', 25, 0.38, 1.0],
#  ['Processed Data/Tidal_final_results.pkl', 49, 0.19, 0.5],
#  ['Processed Data/ranger_final_results.pkl', 129, 0.46, 0.8],
#  ['Processed Data/pinax-blog_final_results.pkl', 26, 0.37, 0.5],
#  ['Processed Data/nightlytt_final_results.pkl', 15, 0.13, 0.5],
#  ['Processed Data/requirejs_final_results.pkl', 108, 0.5, 1.0],
#  ['Processed Data/malabar-mode_final_results.pkl', 15, 0.23, 0.5],
#  ['Processed Data/connect-mongodb_final_results.pkl', 16, 0.49, 0.5],
#  ['Processed Data/web_final_results.pkl', 29, 0.55, 1.0],
#  ['Processed Data/agit_final_results.pkl', 12, 0.41, 0.52],
#  ['Processed Data/bam_final_results.pkl', 21, 0.52, 0.58],
#  ['Processed Data/dumbo_final_results.pkl', 13, 0.25, 0.58],
#  ['Processed Data/calagator_final_results.pkl', 70, 0.29, 0.6],
#  ['Processed Data/redmine_time_tracker_final_results.pkl', 34, 0.51, 0.61],
#  ['Processed Data/express_final_results.pkl', 141, 0.35, 1.0],
#  ['Processed Data/yahoo-finance_final_results.pkl', 22, 0.51, 1.0],
#  ['Processed Data/Gummi_final_results.pkl', 12, 0.48, 0.5],
#  ['Processed Data/capistrano_final_results.pkl', 363, 0.27, 1.0],
#  ['Processed Data/dm-aggregates_final_results.pkl', 22, 0.32, 0.35],
#  ['Processed Data/presto_final_results.pkl', 17, 0.51, 0.33],
#  ['Processed Data/mockery_final_results.pkl', 143, 0.42, 1.0],
#  ['Processed Data/elRTE_final_results.pkl', 10, 0.53, 0.55],
#  ['Processed Data/ruckusing-migrations_final_results.pkl', 41, 0.34, 0.67],
#  ['Processed Data/perftools.rb_final_results.pkl', 13, 0.52, 1.0],
#  ['Processed Data/awaitility_final_results.pkl', 30, 0.35, 1.0],
#  ['Processed Data/rubyzip_final_results.pkl', 105, 0.46, 1.0],
#  ['Processed Data/chargify_api_ares_final_results.pkl', 48, 0.26, 0.5],
#  ['Processed Data/simplecov_final_results.pkl', 132, 0.42, 1.0],
#  ['Processed Data/TensorFlow-Examples_final_results.pkl', 22, 0.29, 1.0],
#  ['Processed Data/libmbfl_final_results.pkl', 10, 0.43, 0.34],
#  ['Processed Data/ekg2_final_results.pkl', 24, 0.35, 0.64],
#  ['Processed Data/sqlite3-ruby_final_results.pkl', 45, 0.49, 1.0],
#  ['Processed Data/Selenium-Remote-Driver_final_results.pkl', 46, 0.58, 0.73],
#  ['Processed Data/studio3_final_results.pkl', 36, 0.54, 0.48],
#  ['Processed Data/rb-inotify_final_results.pkl', 25, 0.33, 0.67],
#  ['Processed Data/html-minifier_final_results.pkl', 80, 0.56, 1.0],
#  ['Processed Data/vim-unimpaired_final_results.pkl', 12, 0.42, 1.0],
#  ['Processed Data/DotNetOpenAuth_final_results.pkl', 33, 0.59, 1.0],
#  ['Processed Data/vimium_final_results.pkl', 107, 0.45, 0.58],
#  ['Processed Data/silverstripe-news_final_results.pkl', 10, 0.44, 1.0],
#  ['Processed Data/augeas_final_results.pkl', 48, 0.44, 1.0],
#  ['Processed Data/libzmq_final_results.pkl', 400, 0.54, 1.0],
#  ['Processed Data/text_final_results.pkl', 60, 0.32, 1.0],
#  ['Processed Data/beautiful-docs_final_results.pkl', 13, 0.41, 0.75],
#  ['Processed Data/the-blue-alliance_final_results.pkl', 40, 0.47, 1.0],
#  ['Processed Data/maphilight_final_results.pkl', 13, 0.45, 0.75],
#  ['Processed Data/vim-ruby-refactoring_final_results.pkl', 16, 0.39, 0.67],
#  ['Processed Data/ace_final_results.pkl', 359, 0.44, 0.67],
#  ['Processed Data/hadoop-lzo_final_results.pkl', 30, 0.45, 0.42],
#  ['Processed Data/text-markdown_final_results.pkl', 11, 0.45, 0.29],
#  ['Processed Data/webservice-solr_final_results.pkl', 12, 0.47, 0.43],
#  ['Processed Data/roundhouse_final_results.pkl', 50, 0.35, 1.0],
#  ['Processed Data/webrat_final_results.pkl', 75, 0.39, 0.55],
#  ['Processed Data/slick_final_results.pkl', 18, 0.3, 0.41],
#  ['Processed Data/rails_best_practices_final_results.pkl', 83, 0.5, 1.0],
#  ['Processed Data/redis-namespace_final_results.pkl', 41, 0.23, 1.0],
#  ['Processed Data/devise_final_results.pkl', 456, 0.4, 1.0],
#  ['Processed Data/zkfiddle_final_results.pkl', 8, 0.47, 0.49],
#  ['Processed Data/alonetone_final_results.pkl', 20, 0.43, 0.47],
#  ['Processed Data/incanter_final_results.pkl', 115, 0.57, 0.67],
#  ['Processed Data/tr8n_final_results.pkl', 15, 0.51, 1.0],
#  ['Processed Data/sensei_final_results.pkl', 54, 0.38, 0.42],
#  ['Processed Data/django-test-utils_final_results.pkl', 13, 0.4, 0.55],
#  ['Processed Data/disco_final_results.pkl', 46, 0.45, 0.57],
#  ['Processed Data/teeworlds_final_results.pkl', 67, 0.44, 0.78],
#  ['Processed Data/jstree-grid_final_results.pkl', 25, 0.56, 0.75],
#  ['Processed Data/CPAN-Reporter_final_results.pkl', 11, 0.55, 0.5],
#  ['Processed Data/WoW-Pro-Guides_final_results.pkl', 22, 0.41, 0.27],
#  ['Processed Data/python-iptables_final_results.pkl', 43, 0.42, 1.0],
#  ['Processed Data/gruff_final_results.pkl', 39, 0.43, 0.93],
#  ['Processed Data/node-zookeeper_final_results.pkl', 32, 0.6, 0.5],
#  ['Processed Data/shoes-deprecated_final_results.pkl', 55, 0.4, 0.45],
#  ['Processed Data/noVNC_final_results.pkl', 75, 0.56, 1.0],
#  ['Processed Data/infinite-scroll_final_results.pkl', 55, 0.52, 1.0],
#  ['Processed Data/mootools-more_final_results.pkl', 109, 0.32, 0.59],
#  ['Processed Data/rspec_final_results.pkl', 26, 0.29, 0.5],
#  ['Processed Data/OAuth2Client_final_results.pkl', 50, 0.42, 0.78],
#  ['Processed Data/ooor_final_results.pkl', 14, 0.49, 0.4],
#  ['Processed Data/fastladder_final_results.pkl', 42, 0.46, 0.44],
#  ['Processed Data/gooddata-ruby_final_results.pkl', 54, 0.45, 0.51],
#  ['Processed Data/pyelasticsearch_final_results.pkl', 32, 0.5, 0.6],
#  ['Processed Data/react_final_results.pkl', 740, 0.48, 1.0],
#  ['Processed Data/nokogiri.org-tutorials_final_results.pkl', 22, 0.33, 1.0],
#  ['Processed Data/powertac-server_final_results.pkl', 30, 0.17, 0.26],
#  ['Processed Data/free-programming-books-zh_CN_final_results.pkl',
#   113,
#   0.5,
#   1.0],
#  ['Processed Data/FluentValidation_final_results.pkl', 88, 0.75, 1.0],
#  ['Processed Data/thor_final_results.pkl', 160, 0.4, 1.0],
#  ['Processed Data/dm-core_final_results.pkl', 82, 0.58, 0.56],
#  ['Processed Data/memcached-session-manager_final_results.pkl',
#   21,
#   0.43,
#   0.86],
#  ['Processed Data/devilry-django_final_results.pkl', 30, 0.33, 0.4],
#  ['Processed Data/gitit_final_results.pkl', 53, 0.28, 0.92],
#  ['Processed Data/errai_final_results.pkl', 69, 0.47, 0.63],
#  ['Processed Data/kitsune_final_results.pkl', 69, 0.36, 0.55],
#  ['Processed Data/infinitas_final_results.pkl', 17, 0.32, 0.32],
#  ['Processed Data/pgrouting_final_results.pkl', 64, 0.51, 0.53],
#  ['Processed Data/html5demos_final_results.pkl', 19, 0.37, 0.5],
#  ['Processed Data/Tron_final_results.pkl', 11, 0.62, 0.38],
#  ['Processed Data/sshj_final_results.pkl', 36, 0.38, 1.0],
#  ['Processed Data/fluentmigrator_final_results.pkl', 169, 0.44, 0.75],
#  ['Processed Data/gist-vim_final_results.pkl', 44, 0.61, 1.0],
#  ['Processed Data/neo4j-rest-client_final_results.pkl', 23, 0.51, 0.67],
#  ['Processed Data/wai_final_results.pkl', 191, 0.34, 0.5],
#  ['Processed Data/Espresso_final_results.pkl', 16, 0.39, 0.26],
#  ['Processed Data/legacy-cli_final_results.pkl', 146, 0.26, 0.5],
#  ['Processed Data/CopyQ_final_results.pkl', 27, 0.49, 0.52],
#  ['Processed Data/blaze-html_final_results.pkl', 29, 0.29, 0.28],
#  ['Processed Data/Coq-Equations_final_results.pkl', 15, 0.51, 0.5],
#  ['Processed Data/cl-opengl_final_results.pkl', 31, 0.62, 0.8],
#  ['Processed Data/winsparkle_final_results.pkl', 22, 0.36, 1.0],
#  ['Processed Data/symengine_final_results.pkl', 65, 0.54, 0.7],
#  ['Processed Data/coffeescript_final_results.pkl', 222, 0.71, 1.0],
#  ['Processed Data/rt_final_results.pkl', 63, 0.3, 0.51],
#  ['Processed Data/eiskaltdcpp_final_results.pkl', 34, 0.49, 0.7],
#  ['Processed Data/roxml_final_results.pkl', 19, 0.48, 0.5],
#  ['Processed Data/GRMustache_final_results.pkl', 18, 0.29, 0.26],
#  ['Processed Data/luasofia_final_results.pkl', 9, 0.42, 0.33],
#  ['Processed Data/jmxutils_final_results.pkl', 11, 0.23, 0.71],
#  ['Processed Data/ircd.js_final_results.pkl', 20, 0.6, 1.0],
#  ['Processed Data/hashlib_final_results.pkl', 15, 0.37, 1.0],
#  ['Processed Data/Penlight_final_results.pkl', 52, 0.57, 0.54],
#  ['Processed Data/tdiary-core_final_results.pkl', 49, 0.3, 0.4],
#  ['Processed Data/two_tents_final_results.pkl', 17, 0.35, 0.33],
#  ['Processed Data/unicode-math_final_results.pkl', 12, 0.52, 0.54],
#  ['Processed Data/dm-validations_final_results.pkl', 47, 0.63, 0.62],
#  ['Processed Data/dotfiles_final_results.pkl', 27, 0.15, 1.0],
#  ['Processed Data/CiderWebmail_final_results.pkl', 11, 0.49, 0.62],
#  ['Processed Data/bordeaux-threads_final_results.pkl', 14, 0.33, 1.0],
#  ['Processed Data/jdeb_final_results.pkl', 51, 0.45, 0.67],
#  ['Processed Data/self_final_results.pkl', 15, 0.44, 0.5],
#  ['Processed Data/vpanel_final_results.pkl', 9, 0.42, 0.85],
#  ['Processed Data/sqlcipher_final_results.pkl', 14, 0.45, 0.83],
#  ['Processed Data/awesome-vue_final_results.pkl', 110, 0.3, 1.0],
#  ['Processed Data/reshape_final_results.pkl', 13, 0.51, 1.0],
#  ['Processed Data/redmine_ckeditor_final_results.pkl', 13, 0.4, 0.5],
#  ['Processed Data/inotify-tools_final_results.pkl', 11, 0.5, 1.0],
#  ['Processed Data/MySQLTuner-perl_final_results.pkl', 90, 0.45, 1.0],
#  ['Processed Data/testthat_final_results.pkl', 60, 0.4, 1.0],
#  ['Processed Data/Front-end-Developer-Interview-Questions_final_results.pkl',
#   190,
#   0.15,
#   1.0],
#  ['Processed Data/delayed_job_final_results.pkl', 149, 0.37, 1.0],
#  ['Processed Data/incubator-dubbo_final_results.pkl', 52, 0.22, 0.29],
#  ['Processed Data/xmlbuilder-js_final_results.pkl', 30, 0.37, 1.0],
#  ['Processed Data/mysql2_final_results.pkl', 95, 0.46, 1.0],
#  ['Processed Data/psi_final_results.pkl', 51, 0.59, 0.44],
#  ['Processed Data/calendar_date_select_final_results.pkl', 33, 0.17, 0.59],
#  ['Processed Data/OpenPNE3_final_results.pkl', 56, 0.48, 0.52],
#  ['Processed Data/Empire_final_results.pkl', 20, 0.41, 0.48],
#  ['Processed Data/foodsoft_final_results.pkl', 25, 0.41, 0.57],
#  ['Processed Data/rgbds_final_results.pkl', 22, 0.5, 0.64],
#  ['Processed Data/easy-thumbnails_final_results.pkl', 66, 0.47, 0.67],
#  ['Processed Data/writeexcel_final_results.pkl', 12, 0.38, 0.35],
#  ['Processed Data/yajl-ruby_final_results.pkl', 32, 0.4, 0.5],
#  ['Processed Data/stringtemplate4_final_results.pkl', 16, 0.48, 0.5],
#  ['Processed Data/flapjack_final_results.pkl', 38, 0.49, 0.63],
#  ['Processed Data/mintinstall_final_results.pkl', 20, 0.35, 1.0],
#  ['Processed Data/kona_final_results.pkl', 32, 0.56, 0.61],
#  ['Processed Data/rack-cache_final_results.pkl', 35, 0.51, 1.0],
#  ['Processed Data/pybloomfiltermmap_final_results.pkl', 17, 0.47, 1.0],
#  ['Processed Data/gravit_final_results.pkl', 11, 0.4, 0.67],
#  ['Processed Data/heroku_san_final_results.pkl', 37, 0.36, 1.0],
#  ['Processed Data/jobsworth_final_results.pkl', 46, 0.38, 0.47],
#  ['Processed Data/mroonga_final_results.pkl', 34, 0.45, 0.4],
#  ['Processed Data/themes_for_rails_final_results.pkl', 15, 0.29, 0.88],
#  ['Processed Data/data_hacks_final_results.pkl', 11, 0.3, 0.75],
#  ['Processed Data/reveal.js_final_results.pkl', 245, 0.5, 1.0],
#  ['Processed Data/cmake-modules_final_results.pkl', 19, 0.27, 1.0],
#  ['Processed Data/twitter-stream_final_results.pkl', 13, 0.23, 0.83],
#  ['Processed Data/django-devserver_final_results.pkl', 37, 0.41, 1.0],
#  ['Processed Data/qlmarkdown_final_results.pkl', 23, 0.06, 1.0],
#  ['Processed Data/jsPDF_final_results.pkl', 97, 0.53, 1.0],
#  ['Processed Data/node-temp_final_results.pkl', 24, 0.51, 0.5],
#  ['Processed Data/redsocks_final_results.pkl', 11, 0.43, 0.94],
#  ['Processed Data/vim-endwise_final_results.pkl', 18, 0.3, 1.0],
#  ['Processed Data/dm-types_final_results.pkl', 44, 0.32, 0.67],
#  ['Processed Data/vim-quickrun_final_results.pkl', 35, 0.43, 1.0],
#  ['Processed Data/oauth_final_results.pkl', 14, 0.27, 1.0],
#  ['Processed Data/Xebium_final_results.pkl', 27, 0.49, 0.56],
#  ['Processed Data/coffee-mode_final_results.pkl', 50, 0.34, 1.0],
#  ['Processed Data/erlang-irc-bot_final_results.pkl', 8, 0.32, 0.75],
#  ['Processed Data/pianobar_final_results.pkl', 14, 0.5, 1.0],
#  ['Processed Data/libffi_final_results.pkl', 73, 0.42, 0.74],
#  ['Processed Data/excon_final_results.pkl', 141, 0.54, 1.0],
#  ['Processed Data/stringr_final_results.pkl', 18, 0.52, 1.0],
#  ['Processed Data/twistar_final_results.pkl', 11, 0.49, 1.0],
#  ['Processed Data/readthedocs.org_final_results.pkl', 288, 0.32, 0.93],
#  ['Processed Data/denyhosts_final_results.pkl', 13, 0.37, 0.57],
#  ['Processed Data/asn1c_final_results.pkl', 23, 0.4, 0.74],
#  ['Processed Data/perl-crypt-openssl-x509_final_results.pkl', 18, 0.6, 0.67],
#  ['Processed Data/clay_final_results.pkl', 37, 0.48, 0.44],
#  ['Processed Data/PostCalendar_final_results.pkl', 13, 0.41, 0.5],
#  ['Processed Data/vim-ruby_final_results.pkl', 58, 0.44, 1.0],
#  ['Processed Data/rock_final_results.pkl', 38, 0.5, 0.5],
#  ['Processed Data/arcadia_final_results.pkl', 8, 0.52, 0.38],
#  ['Processed Data/sizzle_final_results.pkl', 27, 0.6, 0.71],
#  ['Processed Data/xmlimporter_final_results.pkl', 13, 0.52, 0.52],
#  ['Processed Data/web2py_final_results.pkl', 208, 0.63, 0.79],
#  ['Processed Data/therubyracer_final_results.pkl', 29, 0.34, 1.0],
#  ['Processed Data/java-apns_final_results.pkl', 41, 0.42, 1.0],
#  ['Processed Data/twitter_final_results.pkl', 137, 0.23, 0.67],
#  ['Processed Data/aasm_final_results.pkl', 150, 0.37, 1.0],
#  ['Processed Data/rack-proxy_final_results.pkl', 32, 0.22, 1.0],
#  ['Processed Data/wro4j_final_results.pkl', 55, 0.34, 1.0],
#  ['Processed Data/fishers_exact_test_final_results.pkl', 11, 0.27, 0.5],
#  ['Processed Data/acts_as_paranoid_final_results.pkl', 56, 0.43, 1.0],
#  ['Processed Data/helios-server_final_results.pkl', 18, 0.33, 0.5],
#  ['Processed Data/pure-ftpd_final_results.pkl', 18, 0.38, 1.0],
#  ['Processed Data/social_stream_final_results.pkl', 45, 0.35, 0.5],
#  ['Processed Data/rudybot_final_results.pkl', 14, 0.19, 0.4],
#  ['Processed Data/antlr4_final_results.pkl', 167, 0.46, 0.5],
#  ['Processed Data/dbus-sharp_final_results.pkl', 19, 0.48, 0.49],
#  ['Processed Data/puppet-nfs_final_results.pkl', 25, 0.33, 0.9],
#  ['Processed Data/mintupdate_final_results.pkl', 26, 0.33, 0.71],
#  ['Processed Data/node-supervisor_final_results.pkl', 47, 0.41, 1.0],
#  ['Processed Data/vows_final_results.pkl', 38, 0.38, 0.52],
#  ['Processed Data/chronic_final_results.pkl', 64, 0.4, 0.5],
#  ['Processed Data/doctrine2_final_results.pkl', 648, 0.61, 1.0],
#  ['Processed Data/angular.js_final_results.pkl', 71, 0.28, 0.82],
#  ['Processed Data/django-request_final_results.pkl', 22, 0.6, 1.0],
#  ['Processed Data/Tinyboard_final_results.pkl', 32, 0.51, 0.41],
#  ['Processed Data/rubycas-server_final_results.pkl', 54, 0.19, 0.5],
#  ['Processed Data/liquid.js_final_results.pkl', 22, 0.31, 1.0],
#  ['Processed Data/kicker_final_results.pkl', 11, 0.36, 0.22],
#  ['Processed Data/abella_final_results.pkl', 10, 0.46, 0.58],
#  ['Processed Data/sparkup_final_results.pkl', 26, 0.51, 0.69],
#  ['Processed Data/bootstrap_final_results.pkl', 863, 0.5, 1.0],
#  ['Processed Data/LobbyProtocol_final_results.pkl', 14, 0.8, 0.5],
#  ['Processed Data/gmate_final_results.pkl', 57, 0.3, 0.33],
#  ['Processed Data/hbs_final_results.pkl', 23, 0.31, 1.0],
#  ['Processed Data/clang_complete_final_results.pkl', 64, 0.37, 1.0],
#  ['Processed Data/cloud-crowd_final_results.pkl', 12, 0.52, 0.71],
#  ['Processed Data/Mu_final_results.pkl', 15, 0.37, 1.0],
#  ['Processed Data/Taipei-Torrent_final_results.pkl', 19, 0.36, 0.56],
#  ['Processed Data/knockout.mapping_final_results.pkl', 22, 0.61, 1.0],
#  ['Processed Data/meteor_final_results.pkl', 208, 0.38, 1.0],
#  ['Processed Data/ajenti_final_results.pkl', 85, 0.36, 0.39],
#  ['Processed Data/EGOCache_final_results.pkl', 18, 0.55, 1.0],
#  ['Processed Data/cpm_final_results.pkl', 8, 0.35, 0.32],
#  ['Processed Data/foreman_final_results.pkl', 48, 0.28, 1.89],
#  ['Processed Data/culerity_final_results.pkl', 12, 0.25, 0.5],
#  ['Processed Data/net-dns_final_results.pkl', 15, 0.47, 1.0],
#  ['Processed Data/state_machine_final_results.pkl', 8, 0.59, 1.0],
#  ['Processed Data/scalatra_final_results.pkl', 130, 0.36, 0.67],
#  ['Processed Data/http_parser.rb_final_results.pkl', 20, 0.42, 1.0],
#  ['Processed Data/boo_final_results.pkl', 36, 0.51, 0.56],
#  ['Processed Data/psake_final_results.pkl', 59, 0.31, 1.0],
#  ['Processed Data/inputex_final_results.pkl', 22, 0.5, 0.39],
#  ['Processed Data/sthlmtraveling_final_results.pkl', 12, 0.33, 0.5],
#  ['Processed Data/appdirs_final_results.pkl', 24, 0.26, 0.67],
#  ['Processed Data/ReplicatorG_final_results.pkl', 59, 0.49, 0.5],
#  ['Processed Data/yaml_db_final_results.pkl', 16, 0.45, 0.75],
#  ['Processed Data/JAXL_final_results.pkl', 18, 0.52, 1.0],
#  ['Processed Data/node-mongodb-native_final_results.pkl', 286, 0.49, 1.0],
#  ['Processed Data/activerecord-postgres-hstore_final_results.pkl',
#   37,
#   0.25,
#   1.0],
#  ['Processed Data/SDWebImage_final_results.pkl', 244, 0.58, 1.0],
#  ['Processed Data/ruby-saml_final_results.pkl', 119, 0.48, 1.0],
#  ['Processed Data/tvrenamer_final_results.pkl', 16, 0.5, 0.67],
#  ['Processed Data/zguide_final_results.pkl', 301, 0.5, 0.83],
#  ['Processed Data/phonegap-plugins_final_results.pkl', 256, 0.12, 0.5],
#  ['Processed Data/awesome-python_final_results.pkl', 268, 0.62, 1.0],
#  ['Processed Data/tonic_final_results.pkl', 16, 0.39, 0.75],
#  ['Processed Data/em-http-request_final_results.pkl', 81, 0.33, 0.57],
#  ['Processed Data/ThinkUp_final_results.pkl', 66, 0.48, 1.0],
#  ['Processed Data/flask-autoindex_final_results.pkl', 15, 0.41, 0.5],
#  ['Processed Data/Supybot-plugins_final_results.pkl', 18, 0.43, 0.5],
#  ['Processed Data/nested_form_final_results.pkl', 38, 0.4, 1.0],
#  ['Processed Data/coco_final_results.pkl', 36, 0.65, 0.67],
#  ['Processed Data/Projects_final_results.pkl', 17, 0.39, 0.5],
#  ['Processed Data/gepub_final_results.pkl', 17, 0.38, 0.5],
#  ['Processed Data/openAV-Luppp_final_results.pkl', 10, 0.71, 1.0],
#  ['Processed Data/croogo_final_results.pkl', 71, 0.35, 0.88],
#  ['Processed Data/log4js-node_final_results.pkl', 125, 0.52, 0.67],
#  ['Processed Data/spreedly-gem_final_results.pkl', 18, 0.41, 0.5],
#  ['Processed Data/dokuwiki-plugin-translation_final_results.pkl',
#   19,
#   0.33,
#   0.4],
#  ['Processed Data/java.tmbundle_final_results.pkl', 16, 0.27, 0.55],
#  ['Processed Data/frozen-bubble_final_results.pkl', 15, 0.39, 0.52],
#  ['Processed Data/multipletab_final_results.pkl', 17, 0.35, 0.39],
#  ['Processed Data/ronn_final_results.pkl', 13, 0.32, 0.5],
#  ['Processed Data/coffee-script-tmbundle_final_results.pkl', 40, 0.26, 1.0],
#  ['Processed Data/libmaple_final_results.pkl', 24, 0.44, 0.74],
#  ['Processed Data/treestyletab_final_results.pkl', 48, 0.44, 0.55],
#  ['Processed Data/shiftplan_final_results.pkl', 11, 0.29, 0.42],
#  ['Processed Data/jquery-timeago_final_results.pkl', 97, 0.27, 1.0],
#  ['Processed Data/AdminLTE_final_results.pkl', 93, 0.48, 1.0],
#  ['Processed Data/jquery-animate-enhanced_final_results.pkl', 25, 0.58, 1.0],
#  ['Processed Data/node-serialport_final_results.pkl', 105, 0.41, 1.0],
#  ['Processed Data/analizo_final_results.pkl', 17, 0.28, 0.41],
#  ['Processed Data/cyclone-physics_final_results.pkl', 8, 0.09, 0.47],
#  ['Processed Data/natty_final_results.pkl', 10, 0.52, 1.0],
#  ['Processed Data/socialigniter_final_results.pkl', 13, 0.52, 0.43],
#  ['Processed Data/xboxdrv_final_results.pkl', 23, 0.47, 1.0],
#  ['Processed Data/fullcalendar_final_results.pkl', 48, 0.37, 0.38],
#  ['Processed Data/tcomment_vim_final_results.pkl', 56, 0.64, 1.0],
#  ['Processed Data/highrise_final_results.pkl', 27, 0.32, 0.75],
#  ['Processed Data/platform_final_results.pkl', 22, 0.4, 0.47],
#  ['Processed Data/python-messaging_final_results.pkl', 9, 0.53, 0.4],
#  ['Processed Data/simple-navigation_final_results.pkl', 28, 0.28, 0.58],
#  ['Processed Data/chronic_duration_final_results.pkl', 17, 0.43, 0.58],
#  ['Processed Data/maple-ide_final_results.pkl', 10, 0.34, 0.49],
#  ['Processed Data/oauth2-provider_final_results.pkl', 20, 0.44, 0.37],
#  ['Processed Data/Stylish-Select_final_results.pkl', 10, 0.48, 0.83],
#  ['Processed Data/surveyor_final_results.pkl', 35, 0.52, 0.58],
#  ['Processed Data/fakeweb_final_results.pkl', 19, 0.43, 0.76],
#  ['Processed Data/configliere_final_results.pkl', 11, 0.47, 0.28],
#  ['Processed Data/stomp-websocket_final_results.pkl', 13, 0.5, 0.88],
#  ['Processed Data/find-file-in-project_final_results.pkl', 17, 0.54, 0.75],
#  ['Processed Data/PHPThumb_final_results.pkl', 14, 0.69, 0.53],
#  ['Processed Data/gsl_final_results.pkl', 30, 0.37, 0.76],
#  ['Processed Data/deeplearningbook-chinese_final_results.pkl', 15, 0.47, 0.44],
#  ['Processed Data/leiningen_final_results.pkl', 347, 0.62, 1.0],
#  ['Processed Data/form_final_results.pkl', 45, 0.45, 1.0],
#  ['Processed Data/sgtpuzzles_final_results.pkl', 10, 0.35, 0.37],
#  ['Processed Data/awesome-courses_final_results.pkl', 100, 0.56, 1.0],
#  ['Processed Data/validates_timeliness_final_results.pkl', 17, 0.41, 1.0],
#  ['Processed Data/mod_zip_final_results.pkl', 14, 0.41, 1.0],
#  ['Processed Data/november_final_results.pkl', 15, 0.25, 0.36],
#  ['Processed Data/web2project_final_results.pkl', 33, 0.6, 0.47],
#  ['Processed Data/Phake_final_results.pkl', 46, 0.46, 1.0],
#  ['Processed Data/typus_final_results.pkl', 51, 0.3, 0.63],
#  ['Processed Data/theos_final_results.pkl', 19, 0.22, 0.5],
#  ['Processed Data/webassets_final_results.pkl', 148, 0.67, 1.0],
#  ['Processed Data/Sozi_final_results.pkl', 32, 0.4, 0.42],
#  ['Processed Data/meta-tags_final_results.pkl', 28, 0.26, 0.5],
#  ['Processed Data/DMDirc_final_results.pkl', 11, 0.74, 0.42],
#  ['Processed Data/LoveSeat_final_results.pkl', 18, 0.47, 1.0],
#  ['Processed Data/RMG-Py_final_results.pkl', 73, 0.42, 0.38],
#  ['Processed Data/scalaxb_final_results.pkl', 47, 0.56, 0.5],
#  ['Processed Data/macfsevents_final_results.pkl', 16, 0.37, 0.5],
#  ['Processed Data/pimd_final_results.pkl', 16, 0.5, 0.67],
#  ['Processed Data/marginalia_final_results.pkl', 38, 0.59, 0.85],
#  ['Processed Data/cmsplugin-filer_final_results.pkl', 53, 0.33, 0.65],
#  ['Processed Data/Chart.js_final_results.pkl', 179, 0.44, 0.75],
#  ['Processed Data/wrench-js_final_results.pkl', 30, 0.65, 1.0],
#  ['Processed Data/redis-rb_final_results.pkl', 133, 0.38, 1.0],
#  ['Processed Data/iviewer_final_results.pkl', 14, 0.44, 0.5],
#  ['Processed Data/ecommerce_final_results.pkl', 31, 0.66, 0.5],
#  ['Processed Data/geopy_final_results.pkl', 46, 0.41, 1.0],
#  ['Processed Data/kozuchi_final_results.pkl', 17, 0.47, 0.38],
#  ['Processed Data/Open-Knesset_final_results.pkl', 105, 0.38, 0.5],
#  ['Processed Data/fullPage.js_final_results.pkl', 121, 0.48, 1.0],
#  ['Processed Data/json_builder_final_results.pkl', 12, 0.41, 0.5],
#  ['Processed Data/hookbox_final_results.pkl', 12, 0.44, 0.5],
#  ['Processed Data/vim-surround_final_results.pkl', 12, 0.42, 1.0],
#  ['Processed Data/ruby-dbus_final_results.pkl', 28, 0.6, 0.93],
#  ['Processed Data/City-Go-Round_final_results.pkl', 8, 0.48, 0.57],
#  ['Processed Data/node-oauth_final_results.pkl', 48, 0.66, 1.0],
#  ['Processed Data/waxeye_final_results.pkl', 13, 0.38, 0.54],
#  ['Processed Data/classList.js_final_results.pkl', 18, 0.48, 1.0],
#  ['Processed Data/ripple_final_results.pkl', 41, 0.51, 0.56],
#  ['Processed Data/RubyTree_final_results.pkl', 22, 0.36, 0.5],
#  ['Processed Data/lusty_final_results.pkl', 28, 0.45, 0.5],
#  ['Processed Data/javabot_final_results.pkl', 16, 0.39, 0.42],
#  ['Processed Data/radiant_final_results.pkl', 83, 0.23, 0.5],
#  ['Processed Data/copycopter-ruby-client_final_results.pkl', 14, 0.6, 0.23],
#  ['Processed Data/timecop_final_results.pkl', 44, 0.44, 1.0],
#  ['Processed Data/uglifier_final_results.pkl', 28, 0.32, 1.0],
#  ['Processed Data/twilio-php_final_results.pkl', 67, 0.32, 0.31],
#  ['Processed Data/gitflow_final_results.pkl', 39, 0.55, 1.0],
#  ['Processed Data/documentjs_final_results.pkl', 45, 0.36, 0.27],
#  ['Processed Data/moment_final_results.pkl', 259, 0.38, 1.0],
#  ['Processed Data/check_nwc_health_final_results.pkl', 20, 0.41, 1.0],
#  ['Processed Data/perl5i_final_results.pkl', 33, 0.54, 0.5],
#  ['Processed Data/kensa_final_results.pkl', 33, 0.33, 0.26],
#  ['Processed Data/vim-javascript_final_results.pkl', 73, 0.36, 1.0],
#  ['Processed Data/limechat_final_results.pkl', 37, 0.22, 0.52],
#  ['Processed Data/tornado_final_results.pkl', 338, 0.56, 1.0],
#  ['Processed Data/rack-cors_final_results.pkl', 35, 0.29, 1.0],
#  ['Processed Data/couchdb-lucene_final_results.pkl', 22, 0.33, 1.0],
#  ['Processed Data/AppSales-Mobile_final_results.pkl', 47, 0.39, 0.5],
#  ['Processed Data/pelican_final_results.pkl', 340, 0.51, 1.0],
#  ['Processed Data/rhino-licensing_final_results.pkl', 15, 0.53, 0.68],
#  ['Processed Data/watir_final_results.pkl', 43, 0.38, 0.5],
#  ['Processed Data/Symfony-2-Eclipse-Plugin_final_results.pkl', 12, 0.37, 0.63],
#  ['Processed Data/pnp4nagios_final_results.pkl', 37, 0.38, 0.5],
#  ['Processed Data/ImageCMS_final_results.pkl', 62, 0.4, 0.34],
#  ['Processed Data/uservoice-ios-sdk_final_results.pkl', 64, 0.63, 0.56],
#  ['Processed Data/activerecord-jdbc-adapter_final_results.pkl',
#   112,
#   0.51,
#   0.72],
#  ['Processed Data/fitsharp_final_results.pkl', 16, 0.47, 0.5],
#  ['Processed Data/IrcDotNet_final_results.pkl', 13, 0.5, 0.33],
#  ['Processed Data/nu_final_results.pkl', 37, 0.5, 0.58],
#  ['Processed Data/vrome_final_results.pkl', 23, 0.51, 0.33],
#  ['Processed Data/videoInput_final_results.pkl', 15, 0.5, 0.5],
#  ['Processed Data/embedly-jquery_final_results.pkl', 23, 0.52, 0.54],
#  ['Processed Data/silverstripe-advancedworkflow_final_results.pkl',
#   55,
#   0.33,
#   0.58],
#  ['Processed Data/HTTP_final_results.pkl', 34, 0.37, 1.0],
#  ['Processed Data/handlebars.rb_final_results.pkl', 11, 0.43, 0.5],
#  ['Processed Data/python-magic_final_results.pkl', 33, 0.75, 1.0],
#  ['Processed Data/django-cache-machine_final_results.pkl', 19, 0.5, 0.5],
#  ['Processed Data/mongoid_taggable_final_results.pkl', 15, 0.39, 0.62],
#  ['Processed Data/django-taggit_final_results.pkl', 74, 0.41, 0.72],
#  ['Processed Data/maglev_final_results.pkl', 36, 0.55, 0.31],
#  ['Processed Data/TinyIB_final_results.pkl', 10, 0.46, 0.75],
#  ['Processed Data/scoped_search_final_results.pkl', 38, 0.79, 0.63],
#  ['Processed Data/qlstephen_final_results.pkl', 17, 0.37, 0.83],
#  ['Processed Data/breeze_final_results.pkl', 114, 0.34, 0.5],
#  ['Processed Data/CreateLink_final_results.pkl', 14, 0.6, 0.67],
#  ['Processed Data/jansi_final_results.pkl', 29, 0.54, 1.0],
#  ['Processed Data/powerdns-on-rails_final_results.pkl', 16, 0.47, 0.72],
#  ['Processed Data/jogl_final_results.pkl', 56, 0.46, 0.6],
#  ['Processed Data/cement_final_results.pkl', 32, 0.54, 0.88],
#  ['Processed Data/as3swf_final_results.pkl', 9, 0.62, 0.5],
#  ['Processed Data/ImpressPages_final_results.pkl', 56, 0.4, 0.39],
#  ['Processed Data/restfulie_final_results.pkl', 46, 0.34, 0.46],
#  ['Processed Data/basket_final_results.pkl', 33, 0.54, 0.76],
#  ['Processed Data/snakefire_final_results.pkl', 19, 0.43, 1.0],
#  ['Processed Data/uzbl_final_results.pkl', 101, 0.41, 0.6],
#  ['Processed Data/sorl-thumbnail_final_results.pkl', 116, 0.49, 1.0],
#  ['Processed Data/mootools-core_final_results.pkl', 80, 0.56, 0.56],
#  ['Processed Data/tinymce_final_results.pkl', 202, 0.29, 0.62],
#  ['Processed Data/redmine_git_hosting_final_results.pkl', 49, 0.58, 0.67],
#  ['Processed Data/dm-migrations_final_results.pkl', 34, 0.41, 0.5],
#  ['Processed Data/chishop_final_results.pkl', 17, 0.44, 0.48],
#  ['Processed Data/FUEL-CMS_final_results.pkl', 38, 0.42, 0.5],
#  ['Processed Data/hakyll_final_results.pkl', 129, 0.43, 1.0],
#  ['Processed Data/ruby-units_final_results.pkl', 25, 0.5, 0.67],
#  ['Processed Data/django-ordered-model_final_results.pkl', 34, 0.8, 1.0],
#  ['Processed Data/bitly_final_results.pkl', 29, 0.46, 1.0],
#  ['Processed Data/elasticsearch-net_final_results.pkl', 177, 0.51, 0.72],
#  ['Processed Data/joblib_final_results.pkl', 46, 0.45, 1.0],
#  ['Processed Data/pgbouncer_final_results.pkl', 34, 0.45, 1.0],
#  ['Processed Data/happymapper_final_results.pkl', 28, 0.39, 0.86],
#  ['Processed Data/limestone_final_results.pkl', 12, 0.68, 0.53],
#  ['Processed Data/bcrypt-ruby_final_results.pkl', 26, 0.41, 1.0],
#  ['Processed Data/reek_final_results.pkl', 82, 0.45, 1.0],
#  ['Processed Data/jasmine-node_final_results.pkl', 58, 0.47, 1.0],
#  ['Processed Data/scenejs_final_results.pkl', 21, 0.39, 0.33],
#  ['Processed Data/jQuery-Form-Validator_final_results.pkl', 60, 0.55, 0.68],
#  ['Processed Data/pause_final_results.pkl', 30, 0.08, 0.46],
#  ['Processed Data/devise_cas_authenticatable_final_results.pkl',
#   38,
#   0.51,
#   1.0],
#  ['Processed Data/jquery-placeholder_final_results.pkl', 18, 0.53, 1.0],
#  ['Processed Data/git-achievements_final_results.pkl', 12, 0.21, 0.5],
#  ['Processed Data/PYPOWER_final_results.pkl', 16, 0.68, 0.58],
#  ['Processed Data/Plack-Middleware-Session_final_results.pkl', 13, 0.44, 0.5],
#  ['Processed Data/health_check_final_results.pkl', 28, 0.46, 1.0],
#  ['Processed Data/openconferenceware_final_results.pkl', 10, 0.35, 0.55],
#  ['Processed Data/sammy_final_results.pkl', 50, 0.47, 1.0],
#  ['Processed Data/tilt_final_results.pkl', 71, 0.32, 0.8],
#  ['Processed Data/kupfer_final_results.pkl', 37, 0.61, 0.77],
#  ['Processed Data/OpenACD_final_results.pkl', 17, 0.56, 0.3],
#  ['Processed Data/datarray_final_results.pkl', 14, 0.5, 0.54],
#  ['Processed Data/farbtastic_final_results.pkl', 10, 0.31, 0.43],
#  ['Processed Data/sbt-idea_final_results.pkl', 24, 0.26, 0.75],
#  ['Processed Data/text-vcard_final_results.pkl', 10, 0.47, 0.67],
#  ['Processed Data/clutch_final_results.pkl', 15, 0.45, 0.8],
#  ['Processed Data/moonmoon_final_results.pkl', 14, 0.24, 1.0],
#  ['Processed Data/wireit_final_results.pkl', 9, 0.47, 0.58],
#  ['Processed Data/twilio-ruby_final_results.pkl', 72, 0.27, 0.5],
#  ['Processed Data/Starman_final_results.pkl', 26, 0.38, 0.75],
#  ['Processed Data/lubridate_final_results.pkl', 54, 0.62, 1.0],
#  ['Processed Data/decent_exposure_final_results.pkl', 36, 0.3, 1.0],
#  ['Processed Data/HOL_final_results.pkl', 70, 0.5, 0.45],
#  ['Processed Data/nitime_final_results.pkl', 23, 0.44, 0.6],
#  ['Processed Data/Backup-Manager_final_results.pkl', 31, 0.53, 0.54],
#  ['Processed Data/postal_final_results.pkl', 10, 0.25, 0.42],
#  ['Processed Data/mirage_final_results.pkl', 51, 0.38, 0.47],
#  ['Processed Data/criterion_final_results.pkl', 33, 0.38, 0.83],
#  ['Processed Data/twirssi_final_results.pkl', 11, 0.63, 0.5],
#  ['Processed Data/heimdal_final_results.pkl', 53, 0.27, 0.44],
#  ['Processed Data/octopi_final_results.pkl', 26, 0.39, 0.41],
#  ['Processed Data/appirater_final_results.pkl', 81, 0.45, 1.0],
#  ['Processed Data/zxing_final_results.pkl', 97, 0.29, 0.67],
#  ['Processed Data/ticgit_final_results.pkl', 18, 0.26, 0.46],
#  ['Processed Data/SpiffWorkflow_final_results.pkl', 20, 0.34, 0.54],
#  ['Processed Data/django-ckeditor_final_results.pkl', 94, 0.45, 1.0],
#  ['Processed Data/vmfest_final_results.pkl', 12, 0.25, 1.0],
#  ['Processed Data/patchwork_final_results.pkl', 14, 0.42, 0.75],
#  ['Processed Data/mogenerator_final_results.pkl', 84, 0.24, 1.0],
#  ['Processed Data/statistics_final_results.pkl', 26, 0.43, 1.0],
#  ['Processed Data/CodeIgniter-Ion-Auth_final_results.pkl', 215, 0.52, 1.0],
#  ['Processed Data/apotomo_final_results.pkl', 20, 0.47, 0.5],
#  ['Processed Data/phpdoctor_final_results.pkl', 13, 0.48, 0.79],
#  ['Processed Data/opentsdb_final_results.pkl', 28, 0.24, 1.0],
#  ['Processed Data/presets_final_results.pkl', 9, 0.21, nan],
#  ['Processed Data/psgi-specs_final_results.pkl', 14, 0.3, 0.67],
#  ['Processed Data/hello-world_final_results.pkl', 288, 0.38, 1.0],
#  ['Processed Data/cucumber-nagios_final_results.pkl', 13, 0.23, 0.62],
#  ['Processed Data/dupe_final_results.pkl', 9, 0.26, 0.5],
#  ['Processed Data/node-loggly_final_results.pkl', 22, 0.49, 1.0],
#  ['Processed Data/psych_final_results.pkl', 64, 0.4, 1.0],
#  ['Processed Data/emacs_chrome_final_results.pkl', 32, 0.39, 1.0],
#  ['Processed Data/el-get_final_results.pkl', 374, 0.34, 0.5],
#  ['Processed Data/database_cleaner_final_results.pkl', 176, 0.41, 1.0],
#  ['Processed Data/gorilla_final_results.pkl', 14, 0.45, 0.64],
#  ['Processed Data/friture_final_results.pkl', 8, 0.4, 0.33],
#  ['Processed Data/poolparty_final_results.pkl', 36, 0.42, 0.38],
#  ['Processed Data/quicklisp-client_final_results.pkl', 13, 0.21, 0.88],
#  ['Processed Data/doctestjs_final_results.pkl', 8, 0.35, 0.71],
#  ['Processed Data/faraday_final_results.pkl', 93, 0.36, 1.0],
#  ['Processed Data/INTER-Mediator_final_results.pkl', 9, 0.67, 0.51],
#  ['Processed Data/vimoutliner_final_results.pkl', 16, 0.28, 0.71],
#  ['Processed Data/fox_final_results.pkl', 12, 0.51, 0.29],
#  ['Processed Data/shower_final_results.pkl', 29, 0.21, 1.0],
#  ['Processed Data/glogg_final_results.pkl', 11, 0.66, 0.5],
# ...
#  ['Processed Data/django-form-designer_final_results.pkl', 26, 0.61, 0.5],
#  ['Processed Data/spark_final_results.pkl', 113, 0.39, 0.5],
#  ['Processed Data/winsw_final_results.pkl', 24, 0.4, 0.86],
#  ['Processed Data/jquery-ui_final_results.pkl', 105, 0.43, 1.0],
#  ['Processed Data/sebastian_final_results.pkl', 8, 0.28, 0.4],
#  ['Processed Data/glamkit-eventtools_final_results.pkl', 29, 0.33, 0.55],
#  ['Processed Data/django-dajaxice_final_results.pkl', 13, 0.47, 0.67],
#  ['Processed Data/progit_final_results.pkl', 481, 0.62, 0.83],
#  ['Processed Data/URI-Find_final_results.pkl', 9, 0.44, 0.42],
#  ['Processed Data/svn2git_final_results.pkl', 29, 0.29, 1.0],
#  ['Processed Data/auto-complete_final_results.pkl', 60, 0.49, 1.0],
#  ['Processed Data/lolita_final_results.pkl', 21, 0.44, 0.33],
#  ['Processed Data/asset_compress_final_results.pkl', 63, 0.46, 0.66],
#  ['Processed Data/InAppSettingsKit_final_results.pkl', 62, 0.51, 0.84],
#  ['Processed Data/jsoup_final_results.pkl', 58, 0.53, 1.0],
#  ['Processed Data/ci_reporter_final_results.pkl', 42, 0.22, 1.0],
#  ['Processed Data/OpenSSL-for-iPhone_final_results.pkl', 29, 0.35, 1.0],
#  ['Processed Data/peercaststation_final_results.pkl', 12, 0.12, 0.13],
#  ['Processed Data/GoodData-CL_final_results.pkl', 23, 0.35, 0.37],
#  ['Processed Data/jquery-validation_final_results.pkl', 36, 0.31, 1.0],
#  ['Processed Data/vim-addon-manager_final_results.pkl', 24, 0.55, 0.75],
#  ['Processed Data/jemplate_final_results.pkl', 29, 0.64, 0.44],
#  ['Processed Data/ruby.tmbundle_final_results.pkl', 37, 0.31, 0.56],
#  ['Processed Data/mach_star_final_results.pkl', 14, 0.35, 0.75],
#  ['Processed Data/cdec_final_results.pkl', 43, 0.41, 0.5],
#  ['Processed Data/compass_final_results.pkl', 174, 0.35, 1.0],
#  ['Processed Data/mocha_final_results.pkl', 29, 0.68, 1.0],
#  ['Processed Data/jquery-mousewheel_final_results.pkl', 11, 0.46, 0.68],
#  ['Processed Data/SCADS_final_results.pkl', 32, 0.43, 0.38],
#  ['Processed Data/ruby-oembed_final_results.pkl', 30, 0.5, 1.0],
#  ['Processed Data/youtube-dl_final_results.pkl', 423, 0.53, 1.0],
#  ['Processed Data/abtt_final_results.pkl', 19, 0.38, 0.27],
#  ['Processed Data/animate.css_final_results.pkl', 80, 0.22, 1.0],
#  ['Processed Data/AeroQuad_final_results.pkl', 22, 0.45, 0.48],
#  ['Processed Data/hcl_final_results.pkl', 15, 0.43, 0.5],
#  ['Processed Data/jison_final_results.pkl', 51, 0.39, 1.0],
#  ['Processed Data/redu_final_results.pkl', 29, 0.29, 0.34],
#  ['Processed Data/nodeunit_final_results.pkl', 69, 0.67, 1.0],
#  ['Processed Data/declarative_authorization_final_results.pkl',
#   21,
#   0.46,
#   0.35],
#  ['Processed Data/django-mptt_final_results.pkl', 103, 0.46, 1.0],
#  ['Processed Data/money_final_results.pkl', 200, 0.71, 1.0],
#  ['Processed Data/enumerated_attribute_final_results.pkl', 11, 0.41, 0.5],
#  ['Processed Data/XX-Net_final_results.pkl', 69, 0.46, 0.53],
#  ['Processed Data/pyapns_final_results.pkl', 12, 0.3, 0.5],
#  ['Processed Data/tweepy_final_results.pkl', 141, 0.37, 1.0],
#  ['Processed Data/will_paginate_final_results.pkl', 21, 0.29, 0.76],
#  ['Processed Data/activemessaging_final_results.pkl', 24, 0.53, 0.75],
#  ['Processed Data/ibus_final_results.pkl', 22, 0.45, 0.78],
#  ['Processed Data/safe_final_results.pkl', 17, 0.47, 0.5],
#  ['Processed Data/perl.tmbundle_final_results.pkl', 16, 0.1, 0.55],
#  ['Processed Data/zeromq.node_final_results.pkl', 70, 0.41, 0.67],
#  ['Processed Data/lazy_high_charts_final_results.pkl', 55, 0.31, 1.0],
#  ['Processed Data/scala-redis_final_results.pkl', 61, 0.48, 1.0],
#  ['Processed Data/arista_final_results.pkl', 15, 0.36, 0.47],
#  ['Processed Data/AndroidUtilCode_final_results.pkl', 19, 0.05, 0.15],
#  ['Processed Data/pharen_final_results.pkl', 13, 0.32, 0.5],
#  ['Processed Data/PDF-Writer_final_results.pkl', 19, 0.56, 0.5],
#  ['Processed Data/SharpZipLib_final_results.pkl', 33, 0.54, 0.85],
#  ['Processed Data/liboping_final_results.pkl', 11, 0.42, 0.53],
#  ['Processed Data/masonry_final_results.pkl', 12, 0.22, 0.45],
#  ['Processed Data/libais_final_results.pkl', 17, 0.36, 0.67],
#  ['Processed Data/turn_final_results.pkl', 35, 0.48, 0.58],
#  ['Processed Data/stringex_final_results.pkl', 63, 0.23, 1.0],
#  ['Processed Data/math--gsl_final_results.pkl', 23, 0.51, 0.51],
#  ['Processed Data/hirb_final_results.pkl', 13, 0.4, nan],
#  ['Processed Data/fakefs_final_results.pkl', 81, 0.36, 1.0],
#  ['Processed Data/phpcomplete.vim_final_results.pkl', 25, 0.61, 0.9],
#  ['Processed Data/django-eav_final_results.pkl', 19, 0.26, 0.46],
#  ['Processed Data/couchrest_final_results.pkl', 48, 0.33, 0.67],
#  ['Processed Data/clientcide_final_results.pkl', 8, 0.36, 1.0],
#  ['Processed Data/SoundManager2_final_results.pkl', 43, 0.56, 1.0],
#  ['Processed Data/jquery-mockjax_final_results.pkl', 75, 0.5, 1.0],
#  ['Processed Data/Albacore_final_results.pkl', 42, 0.35, 0.67],
#  ['Processed Data/yard_final_results.pkl', 110, 0.6, 1.0],
#  ['Processed Data/ghc-mod_final_results.pkl', 82, 0.43, 1.0],
#  ['Processed Data/yuicompressor-maven-plugin_final_results.pkl',
#   11,
#   0.26,
#   1.0],
#  ['Processed Data/mongo_final_results.pkl', 331, 0.41, 0.45],
#  ['Processed Data/assimp_final_results.pkl', 310, 0.53, 0.71],
#  ['Processed Data/caffe_final_results.pkl', 356, 0.52, 0.53],
#  ['Processed Data/Twig_final_results.pkl', 235, 0.85, 1.0],
#  ['Processed Data/bobby-tables_final_results.pkl', 25, 0.32, 0.6],
#  ['Processed Data/gobandroid_final_results.pkl', 14, 0.25, 0.55],
#  ['Processed Data/simple_form_final_results.pkl', 213, 0.37, 0.75],
#  ['Processed Data/awesome_print_final_results.pkl', 50, 0.61, 1.0],
#  ['Processed Data/em-websocket_final_results.pkl', 30, 0.39, 0.55],
#  ['Processed Data/restkit_final_results(1).pkl', 22, 0.4, 0.5],
#  ['Processed Data/haml-js_final_results.pkl', 25, 0.57, 0.5],
#  ['Processed Data/enki_final_results.pkl', 19, 0.41, 0.61],
#  ['Processed Data/petitions_final_results.pkl', 17, 0.29, 0.45],
#  ['Processed Data/silverstripe-versionedfiles_final_results.pkl',
#   26,
#   0.74,
#   0.67],
#  ['Processed Data/MegBot_final_results.pkl', 10, 0.52, 0.6],
#  ['Processed Data/ruby-readability_final_results.pkl', 23, 0.17, 0.6],
#  ['Processed Data/arc2_final_results.pkl', 19, 0.53, 1.0],
#  ['Processed Data/guard-livereload_final_results.pkl', 43, 0.34, 1.0],
#  ['Processed Data/awestruct_final_results.pkl', 45, 0.44, 0.6],
#  ['Processed Data/hamster_final_results.pkl', 24, 0.3, 0.68],
#  ['Processed Data/UglifyJS_final_results.pkl', 35, 0.46, 0.92],
#  ['Processed Data/odf-report_final_results.pkl', 13, 0.23, 0.75],
#  ['Processed Data/eskk.vim_final_results.pkl', 10, 0.5, 0.5],
#  ['Processed Data/uuidtools_final_results.pkl', 12, 0.37, 0.5],
#  ['Processed Data/haml-rails_final_results.pkl', 40, 0.38, 1.0],
#  ['Processed Data/countries_final_results.pkl', 214, 0.41, 1.0],
#  ['Processed Data/jQuery-Twitter-Plugin_final_results.pkl', 11, 0.41, 0.58],
#  ['Processed Data/kohana_final_results.pkl', 32, 0.2, 0.17],
#  ['Processed Data/amazon-ec2_final_results.pkl', 28, 0.2, 0.5],
#  ['Processed Data/flask-sqlalchemy_final_results.pkl', 60, 0.37, 1.0],
#  ['Processed Data/scout-plugins_final_results.pkl', 105, 0.2, 0.5],
#  ['Processed Data/ghi_final_results.pkl', 38, 0.38, 0.58],
#  ['Processed Data/pymarc_final_results.pkl', 37, 0.36, 0.69],
#  ['Processed Data/css.tmbundle_final_results.pkl', 17, 0.22, 0.54],
#  ['Processed Data/play-gae_final_results.pkl', 15, 0.54, 0.42],
#  ['Processed Data/debug_kit_final_results.pkl', 148, 0.47, 0.79],
#  ['Processed Data/shopify_api_final_results.pkl', 113, 0.47, 0.38],
#  ['Processed Data/sendgrid_toolkit_final_results.pkl', 17, 0.19, 1.0],
#  ['Processed Data/emesene_final_results.pkl', 73, 0.42, 0.69],
#  ['Processed Data/rails-base_final_results.pkl', 56, 0.43, 0.47],
#  ['Processed Data/interchange_final_results.pkl', 39, 0.47, 0.45],
#  ['Processed Data/jzmq_final_results.pkl', 96, 0.55, 1.0],
#  ['Processed Data/faye_final_results.pkl', 39, 0.41, 0.54],
#  ['Processed Data/dygraphs_final_results.pkl', 94, 0.44, 0.83],
#  ['Processed Data/cyclone_final_results.pkl', 64, 0.32, 0.67],
#  ['Processed Data/sax-js_final_results.pkl', 10, 0.3, 0.58],
#  ['Processed Data/pomodoro_final_results.pkl', 17, 0.52, 0.38],
#  ['Processed Data/redbot_final_results.pkl', 19, 0.34, 1.0],
#  ['Processed Data/rmlint_final_results.pkl', 42, 0.49, 0.67],
#  ['Processed Data/android-plugin_final_results.pkl', 32, 0.44, 0.69],
#  ['Processed Data/blockui_final_results.pkl', 14, 0.49, 1.0],
#  ['Processed Data/inline-pm_final_results.pkl', 14, 0.47, 0.33],
#  ['Processed Data/jsdom_final_results.pkl', 127, 0.62, 1.0],
#  ['Processed Data/jsonpickle_final_results.pkl', 35, 0.49, 0.67],
#  ['Processed Data/django-debug-toolbar_final_results.pkl', 161, 0.45, 1.0],
#  ['Processed Data/oscommerce2_final_results.pkl', 20, 0.25, 0.41],
#  ['Processed Data/css_parser_final_results.pkl', 46, 0.56, 0.83],
#  ['Processed Data/Twitter-OAuth-iPhone_final_results.pkl', 11, 0.29, 0.5],
#  ['Processed Data/curb_final_results.pkl', 69, 0.46, 1.0],
#  ['Processed Data/logjam_core_final_results.pkl', 19, 0.38, 0.55],
#  ['Processed Data/method-signatures_final_results.pkl', 19, 0.49, 0.58],
#  ['Processed Data/wymeditor_final_results.pkl', 45, 0.45, 0.71],
#  ['Processed Data/archey3_final_results.pkl', 17, 0.44, 1.0],
#  ['Processed Data/django-moderation_final_results.pkl', 29, 0.62, 0.67],
#  ['Processed Data/jquery-maskmoney_final_results.pkl', 25, 0.59, 0.5],
#  ['Processed Data/PIE_final_results.pkl', 12, 0.5, 1.0],
#  ['Processed Data/permanent_records_final_results.pkl', 26, 0.43, 1.0],
#  ['Processed Data/grails-database-migration_final_results.pkl', 44, 0.22, 0.3],
#  ['Processed Data/carrierwave_final_results.pkl', 358, 0.34, 1.0],
#  ['Processed Data/mustache_final_results.pkl', 8, 0.68, 1.0],
#  ['Processed Data/meta_search_final_results.pkl', 10, 0.4, nan],
#  ['Processed Data/django-forms-builder_final_results.pkl', 54, 0.37, 0.5],
#  ['Processed Data/Taffy_final_results.pkl', 53, 0.16, 0.88],
#  ['Processed Data/excel-writer-xlsx_final_results.pkl', 9, 0.56, 0.59],
#  ['Processed Data/tarantula_final_results.pkl', 27, 0.44, 0.5],
#  ['Processed Data/OpenCATS_final_results.pkl', 21, 0.21, 0.5],
#  ['Processed Data/django-authority_final_results.pkl', 23, 0.48, 0.5],
#  ['Processed Data/backup_final_results.pkl', 90, 0.41, 1.0],
#  ['Processed Data/node-glob_final_results.pkl', 14, 0.36, 1.0],
#  ['Processed Data/kestrel_final_results.pkl', 43, 0.35, 0.78],
#  ['Processed Data/Yaaic_final_results.pkl', 12, 0.18, 1.0],
#  ['Processed Data/spring-data-jpa_final_results.pkl', 15, 0.29, 0.42],
#  ['Processed Data/autoproj_final_results.pkl', 16, 0.47, 0.39],
#  ['Processed Data/CloudI_final_results.pkl', 10, 0.61, 0.38],
#  ['Processed Data/wp-varnish_final_results.pkl', 24, 0.39, 0.71],
#  ['Processed Data/jsonlint_final_results.pkl', 13, 0.29, 0.83],
#  ['Processed Data/acts_as_commentable_final_results.pkl', 27, 0.37, 0.67],
#  ['Processed Data/flask-babel_final_results.pkl', 20, 0.31, 0.58],
#  ['Processed Data/mongoengine_final_results.pkl', 86, 0.63, 0.67],
#  ['Processed Data/maycamp_arena_final_results.pkl', 13, 0.48, 0.47],
#  ['Processed Data/text-multimarkdown_final_results.pkl', 9, 0.57, 0.33],
#  ['Processed Data/mathquill_final_results.pkl', 54, 0.55, 0.55],
#  ['Processed Data/hxssl_final_results.pkl', 11, 0.5, 0.56],
#  ['Processed Data/flask_final_results.pkl', 381, 0.55, 1.0],
#  ['Processed Data/chef-rvm_final_results.pkl', 44, 0.31, 0.58],
#  ['Processed Data/vanity_final_results.pkl', 65, 0.47, 0.75],
#  ['Processed Data/cppagent_final_results.pkl', 12, 0.68, 0.81],
#  ['Processed Data/attr_encrypted_final_results.pkl', 20, 0.32, 0.52],
#  ['Processed Data/TwelveMonkeys_final_results.pkl', 22, 0.48, 0.55],
#  ['Processed Data/devise_invitable_final_results.pkl', 136, 0.87, 1.0],
#  ['Processed Data/MonoTouch.Dialog_final_results.pkl', 40, 0.34, 0.5],
#  ['Processed Data/git_osx_installer_final_results.pkl', 11, 0.34, 1.0],
#  ['Processed Data/nimbus_final_results.pkl', 18, 0.32, 0.31],
#  ['Processed Data/shocco_final_results.pkl', 11, 0.41, 1.0],
#  ['Processed Data/vim-markdown_final_results.pkl', 15, 0.22, 1.0],
#  ['Processed Data/ruby-oai_final_results.pkl', 15, 0.45, 0.61],
#  ['Processed Data/HandlerSocket-Plugin-for-MySQL_final_results.pkl',
#   17,
#   0.44,
#   0.67],
#  ['Processed Data/popHealth_final_results.pkl', 36, 0.3, 0.35],
#  ['Processed Data/xml2json_final_results.pkl', 15, 0.32, 0.75],
#  ['Processed Data/showoff_final_results.pkl', 80, 0.34, 0.7],
#  ['Processed Data/sga_final_results.pkl', 29, 0.57, 0.33],
#  ['Processed Data/spree_i18n_final_results.pkl', 192, 0.33, 1.0],
#  ['Processed Data/tito_final_results.pkl', 54, 0.51, 0.83],
#  ['Processed Data/warden_final_results.pkl', 39, 0.41, 1.0],
#  ['Processed Data/django-extensions_final_results.pkl', 388, 0.7, 1.0],
#  ['Processed Data/docs_final_results.pkl', 197, 0.43, 0.68],
#  ['Processed Data/node-mapnik_final_results.pkl', 46, 0.42, 0.5],
#  ['Processed Data/wsapi_final_results.pkl', 12, 0.43, 0.41],
#  ['Processed Data/keepassdroid_final_results.pkl', 42, 0.44, 0.75],
#  ['Processed Data/locutus_final_results.pkl', 90, 0.39, 0.5],
#  ['Processed Data/Droplet_final_results.pkl', 30, 0.62, 0.46],
#  ['Processed Data/pyodbc_final_results.pkl', 16, 0.5, 1.0],
#  ['Processed Data/clearance_final_results.pkl', 71, 0.38, 0.67],
#  ['Processed Data/GromacsWrapper_final_results.pkl', 13, 0.57, 0.56],
#  ['Processed Data/quicksand_final_results.pkl', 19, 0.37, 0.56],
#  ['Processed Data/newtabfromlocationbar_final_results.pkl', 8, 0.31, 0.17],
#  ['Processed Data/jenni_final_results.pkl', 46, 0.48, 0.69],
#  ['Processed Data/signature-pad_final_results.pkl', 8, 0.41, 0.6],
#  ['Processed Data/prototype_final_results.pkl', 30, 0.44, 0.6],
#  ['Processed Data/cradle_final_results.pkl', 44, 0.54, 0.83],
#  ['Processed Data/pycodestyle_final_results.pkl', 90, 0.48, 1.0],
#  ['Processed Data/ColReorder_final_results.pkl', 13, 0.44, 0.75],
#  ['Processed Data/django-activity-stream_final_results.pkl', 82, 0.45, 1.0],
#  ['Processed Data/mustache.github.com_final_results.pkl', 42, 0.19, 1.0],
#  ['Processed Data/maven-android-sdk-deployer_final_results.pkl',
#   73,
#   0.34,
#   1.0],
#  ['Processed Data/blogofile_final_results.pkl', 23, 0.47, 0.41],
#  ['Processed Data/SquishIt_final_results.pkl', 48, 0.43, 1.0],
#  ['Processed Data/robotium_final_results.pkl', 51, 0.39, 1.0],
#  ['Processed Data/SleekXMPP_final_results.pkl', 72, 0.52, 0.55],
#  ['Processed Data/feh_final_results.pkl', 40, 0.29, 1.0],
#  ['Processed Data/docsplit_final_results.pkl', 27, 0.38, 1.0],
#  ['Processed Data/junit-interface_final_results.pkl', 20, 0.41, 0.5],
#  ['Processed Data/onebody_final_results.pkl', 63, 0.33, 0.5],
#  ['Processed Data/android-maven-plugin_final_results.pkl', 168, 0.53, 0.88],
#  ['Processed Data/opCommunityTopicPlugin_final_results.pkl', 27, 0.53, 0.5],
#  ['Processed Data/clojars-web_final_results.pkl', 41, 0.42, 0.75],
#  ['Processed Data/BitTornado_final_results.pkl', 15, 0.41, 0.72],
#  ['Processed Data/gist_final_results.pkl', 70, 0.33, 0.67],
#  ['Processed Data/idios_final_results.pkl', 9, 0.18, 0.5],
#  ['Processed Data/twurl_final_results.pkl', 18, 0.34, 0.72],
#  ['Processed Data/sunpinyin_final_results.pkl', 36, 0.63, 0.33],
#  ['Processed Data/viking_final_results.pkl', 33, 0.4, 1.0],
#  ['Processed Data/phpcr-api-tests_final_results.pkl', 40, 0.56, 0.5],
#  ['Processed Data/pas.plugins.ldap_final_results.pkl', 20, 0.55, 0.59],
#  ['Processed Data/uuid_final_results.pkl', 16, 0.38, 1.0],
#  ['Processed Data/pyres_final_results.pkl', 34, 0.38, 0.53],
#  ['Processed Data/markdown_final_results.pkl', 79, 0.51, 1.0],
#  ['Processed Data/formtastic_final_results.pkl', 162, 0.32, 1.0],
#  ['Processed Data/publify_final_results.pkl', 102, 0.5, 0.67],
#  ['Processed Data/perspective-el_final_results.pkl', 22, 0.64, 1.0],
#  ['Processed Data/nar-maven-plugin_final_results.pkl', 72, 0.34, 1.0],
#  ['Processed Data/dipy_final_results.pkl', 110, 0.57, 0.6],
#  ['Processed Data/Turpial_final_results.pkl', 26, 0.49, 0.38],
#  ['Processed Data/mootools-meio-autocomplete_final_results.pkl', 8, 0.6, 0.71],
#  ['Processed Data/Elastica_final_results.pkl', 238, 0.6, 0.84],
#  ['Processed Data/core_final_results.pkl', 10, 0.42, 0.35],
#  ...]
