# %%
import social_interaction
import code_interaction
import buggy_commit
import pandas as pd
import numpy as np
import os
import platform
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt

# %%
if platform.system() == 'Darwin' or platform.system() == 'Linux':
    _dir = 'Data/'
else:
    _dir = 'Data\\'
Files = [join(_dir, f) for f in listdir(_dir) if isfile(join(_dir, f))]
print(Files)
# Out:
# ['Data/SlackTextViewController_issue.pkl', 'Data/.DS_Store', 'Data/SlackTextViewController_issue_comment.pkl', 'Data/SlackTextViewController_user.pkl', 'Data/SlackTextViewController_committed_file.pkl', 'Data/SlackTextViewController_commit.pkl']

# %%
issues = pd.read_pickle('Data/SlackTextViewController_commit.pkl')

# %%
issues
# Out:
#                                  commit_number  \
# 0     fafc68d57c4c1dcb3c87c9d3e76467ef77784c96
# 1     9ee9ff2b7507397e1f357c3b6529b61ebd6b4997
# 2     b470e8fe0ad9bcf1444873cd226c0b794d5b7f7c
# 3     eb4b4dab643dc54c8d654de082c73a1bfc783b73
# 4     17cfb2926a47b96cddb6abdb9840dce2b1119daa
# 5     4057a7d86cd08c6b652aa81885c7f6569a021aa0
# 6     e4739244b71cf7c7a2a931781f38662b0f2a56d0
# 7     6fa21ba982be42b0df6c45f8d94f0f4cdabd957b
# 8     48065f9b7267f1b00926db2853b115f11a50988a
# 9     2640cb2015ea1f9257d022d9549a8992c292cd90
# 10    5b9ce355f52dbe032f2d950c1c778ffe16dc1338
# 11    93146ba101c49d7a4d2a19450ea545377a6ce447
# 12    4dca0d4531aed6adbcf1c62754d4f3db4624eba0
# 13    c264f951b62df88fe96a02b0312d26a7a84269c0
# 14    01aae36db021a3f3e647692beab5ebf9e031d5f5
# 15    20644f4583464d2989fe37e4fd51c15347c10c60
# 16    48e6f95676050155196201e5ac74a5e695bb9a28
# 17    392b373cb2ff98ec1736f9edcb379102c7ecabfc
# 18    cf305fcdfdcf4bbbb8806eaaa8fc9a01a51fd7ca
# 19    754eaf285052a771f0565a9795b5606a75d88e15
# 20    b780d2fcbd8080b4113c4eac4ad486ea1eb930ed
# 21    0338edb613205a270a5bd0c8118c6c3ce801ce62
# 22    7eda772806274859342f7fe515b31d32b0218377
# 23    06daa0ece3e3f5b660d25fff72d80309ea8b942c
# 24    d26db06982a96ceaa1eb7d8f2124a11aed2194fe
# 25    87e6d21884862934697c0481cc6f412d4f92053c
# 26    4ac971bc340f5320d47d30495c30a40c468a85f6
# 27    daa0b3bd389319ee856dbc577a0662b435a1b9cb
# 28    e60bc85727fa24bd82aa5d9393d47a9d4cf0b6d5
# 29    7b8182daedcaf7a659aa8f294db3fcc871fcfbe1
# ...                                        ...
# 1156  ff96c2abb26f5aa6ea2fe5680575b3c7ed742dd6
# 1157  7890a84ebafca0822a34a142fe5b16ce0c668364
# 1158  ac17d975c0e24960657720e505732993aac2257e
# 1159  037bd7f3947a6464bb59728f08e6021c3e8f8335
# 1160  1f586ebafc4189db36b0c1a45f92b98fa1636da6
# 1161  42dd4ad1eaca392635fb15be3fd686bd1786a062
# 1162  dfa11324a652f6cc920249eea8f9bc75e57c7d98
# 1163  181042368fecc938fc9a938341fb0fd5b0c68aaa
# 1164  46113e08e411ff174793073e3d292c50b9d1964d
# 1165  4c74cbab29408dda9af33633f86dcc983a3b5363
# 1166  d5e01fc71cacb86da3f53c36e32056954285a913
# 1167  e0addb1e84d27a69bd0714f39fdb19c8805e0e72
# 1168  0f1b1e28992fbc6fe26d559925ab194aee808f53
# 1169  3a89e8ea0ab071626919a8c60c3a8be70088ab49
# 1170  9faa9d2c096661c21f6f320301033fb74c1b91a8
# 1171  de0e715393614bc05be476b3ecd0edd2806d93a5
# 1172  953ac90b3a0368cb45adef4ea7110cce87d24bb6
# 1173  fa390ae14bb4890a10c1479d67cec25c8b57651a
# 1174  0a7b7dbecba4c42ea3f1ae2707a8195cde1ed50e
# 1175  ad1675e585ce0fe795539ac143afc028b98357de
# 1176  e54d0515b489ab2395e0ccbdacff5360264eb53f
# 1177  4dc83a17463411fd32777a37a90e72e7199c4258
# 1178  37f91f23414dda33db5ce43a20958f19ddbd7b1d
# 1179  e1604ddbb2760a153c955bcea42ae55283d3e865
# 1180  3c9936780b30191969cde0100814a83d723532db
# 1181  2761b4e3551a90a26025f08175e4a875bea7031d
# 1182  cade6bb017b2081fe37565a426c3d4d788ded615
# 1183  d1cc653604d436b69ad3fcfc45f1df13161d9820
# 1184  30d4a2efdcf430d72530d4a3bd91793ca017864a
# 1185  178750fe96fe3d67819df9ee660705907c427b55
#
#                                                 message  \
# 0                                      Initial commit\n
# 1     Fixes scrolling offset correction when on top ...
# 2                                 Adds button support\n
# 3     Adds auto-layout support to the text container...
# 4     Refactors and renames variables. Adds hairline...
# 5                                     Adds git ignore\n
# 6                               Refactors SLKTextView\n
# 7     Moves all the toolbar subview and constraints ...
# 8     Anchors left and right buttons to the bottom o...
# 9     Adds auto-layout support for viewcontroller's ...
# 10    Fixes auto-layout issues with keyboard dragging\n
# 11                  Adds support for growing textview\n
# 12                                      Adds pod spec\n
# 13    Renames classes to match the library prefixes ...
# 14                                    Renames classes\n
# 15                    Adds lorem ipsum insertion text\n
# 16    Adds line limit support (in progress). Include...
# 17    Fixes flash scroll indicators. Adds text appen...
# 18       Adds typing indicator support (in progress).\n
# 19                                     Adds README.md\n
# 20                           Adds example's pod files\n
# 21                  Improves typing indicator display\n
# 22                                 Updates .gitignore\n
# 23                         Removes all DS_Store files\n
# 24                                  Updates gitignore\n
# 25                                .DS_Store banished!\n
# 26    Adds support for customizing left and right bu...
# 27          Makes auto-hidding right button, optional\n
# 28    Includes major improvements in layout and auto...
# 29    Adds the upload icon image for the sample proj...
# ...                                                 ...
# 1156  Expose required properties for the subclass, r...
# 1157  Merge pull request #561 from slackhq/expose_au...
# 1158  Adds support for an optional view to host outl...
# 1159      Fix broken link to code of conduct (#566)\n\n
# 1160  Fixes issue where the text input would not adj...
# 1161                  Fix markdown of README (#585)\n\n
# 1162  Added concrete targets in Podfile to work with...
# 1163  Update bottom margin to accommodate iPhone X h...
# 1164  Fixing the text input not being interactive si...
# 1165  Fix compiler error in example app (#629)\n\n* ...
# 1166  Solve a problem with the new sdk on iOS 11 tha...
# 1167  Configuring SlackTextViewController framework'...
# 1168                                         BB badge\n
# 1169                                      Badge style\n
# 1170                                   Scheme updates\n
# 1171               Merge branch 'master' into iPhoneX\n
# 1172  Skips the bottom safe area when the textinputb...
# 1173  Reverting #624 to be using UIToolbar again, sp...
# 1174                     [skip-ci] updating changelog\n
# 1175  Keep scroll view content inset adjustment. Fix...
# 1176  Allowing the customization of the highlighted ...
# 1177  Updating PR template and 1.9.6 changelog entri...
# 1178  Update bottom margin to accommodate iPhone X h...
# 1179                             Version bump (1.9.6)\n
# 1180  fix README typo concerning Swift tableView did...
# 1181  Declare framework dependencies in podspec (#66...
# 1182  Check textInputBar hidden or not when update t...
# 1183             Update README with deprecation message
# 1184                                   Update README.md
# 1185  Update formatting and layout of README depreca...
#
#                                         parent  buggy      issues
# 0                                         None      0        None
# 1     fafc68d57c4c1dcb3c87c9d3e76467ef77784c96      1        None
# 2     9ee9ff2b7507397e1f357c3b6529b61ebd6b4997      0        None
# 3     b470e8fe0ad9bcf1444873cd226c0b794d5b7f7c      1        None
# 4     eb4b4dab643dc54c8d654de082c73a1bfc783b73      0        None
# 5     17cfb2926a47b96cddb6abdb9840dce2b1119daa      0        None
# 6     4057a7d86cd08c6b652aa81885c7f6569a021aa0      0        None
# 7     e4739244b71cf7c7a2a931781f38662b0f2a56d0      0        None
# 8     6fa21ba982be42b0df6c45f8d94f0f4cdabd957b      0        None
# 9     48065f9b7267f1b00926db2853b115f11a50988a      0        None
# 10    2640cb2015ea1f9257d022d9549a8992c292cd90      1        None
# 11    5b9ce355f52dbe032f2d950c1c778ffe16dc1338      0        None
# 12    93146ba101c49d7a4d2a19450ea545377a6ce447      0        None
# 13    4dca0d4531aed6adbcf1c62754d4f3db4624eba0      1        None
# 14    c264f951b62df88fe96a02b0312d26a7a84269c0      0        None
# 15    01aae36db021a3f3e647692beab5ebf9e031d5f5      0        None
# 16    20644f4583464d2989fe37e4fd51c15347c10c60      0        None
# 17    48e6f95676050155196201e5ac74a5e695bb9a28      1        None
# 18    392b373cb2ff98ec1736f9edcb379102c7ecabfc      0        None
# 19    cf305fcdfdcf4bbbb8806eaaa8fc9a01a51fd7ca      0        None
# 20    754eaf285052a771f0565a9795b5606a75d88e15      0        None
# 21    b780d2fcbd8080b4113c4eac4ad486ea1eb930ed      0        None
# 22    0338edb613205a270a5bd0c8118c6c3ce801ce62      0        None
# 23    7eda772806274859342f7fe515b31d32b0218377      0        None
# 24    06daa0ece3e3f5b660d25fff72d80309ea8b942c      0        None
# 25    d26db06982a96ceaa1eb7d8f2124a11aed2194fe      0        None
# 26    87e6d21884862934697c0481cc6f412d4f92053c      0        None
# 1167  e0addb1e84d27a69bd0714f39fdb19c8805e0e72
# 1173  fa390ae14bb4890a10c1479d67cec25c8b57651a
# 1175  ad1675e585ce0fe795539ac143afc028b98357de
# 1176  e54d0515b489ab2395e0ccbdacff5360264eb53f
# 1178  37f91f23414dda33db5ce43a20958f19ddbd7b1d
# 1180  3c9936780b30191969cde0100814a83d723532db
# 1181  2761b4e3551a90a26025f08175e4a875bea7031d
# 1182  cade6bb017b2081fe37565a426c3d4d788ded615
#
#                                                 message  \
# 189   Fixes crash in sample project on iOS7 because ...
# 191   Merge pull request #4 from yury/tabbar-support...
# 193   Doesn't disable the QuickType bar when the mag...
# 194   Merge pull request #7 from slackhq/quicktype-d...
# 196   Merge pull request #9 from theDoug/patch-1\n\n...
# 206   Fixes interactive dismiss mode on iOS7. Fixes ...
# 210   PopoverController support on iPad, by not movi...
# 214   Merge pull request #17 from nfeiglin/master\n\...
# 218   Merge pull request #19 from squarezw/patch-1\n...
# 223   Merge pull request #23 from nfeiglin/master\n\...
# 235   Merge pull request #26 from slackhq/template\n...
# 241   Avoids the keyboard to be dismissed during the...
# 244   TextView placeholder label is aligns taking in...
# 247   Makes InputToolbar's inner padding customisabl...
# 255   Closes slackhq/SlackTextViewController#30, inc...
# 256   Merge pull request #31 from Wayfarer247/master...
# 266   Merge pull request #33 from slackhq/undo-redo-...
# 270   Merge pull request #36 from netguru/textview-s...
# 287   Fixes external keyboard detection when using a...
# 299   Merge pull request #43 from slackhq/keyboard-p...
# 302   Merge pull request #44 from fluidsonic/patch-1...
# 304                             Codestyle correction.\n
# 307   Fixed that initial values were not set for SLK...
# 310   Renamed SLKTextViewController's inputAccessory...
# 321   Merge pull request #47 from slackhq/pasteboard...
# 323   Fixes endless loop caused by -reloadInputViewI...
# 340           Exposes the singleTapGesture. Fixes #53\n
# 345   Adds -loadView method, and set the view progra...
# 357                               Attempts to fix #52\n
# 369   Merge pull request #60 from alexsoble/master\n...
# ...                                                 ...
# 1120  Merge pull request #523 from cyhsutw/update-co...
# 1127  Merge pull request #528 from ClementPadovani/p...
# 1130  Merge pull request #532 from slackhq/inputHeig...
# 1132  Merge pull request #533 from jvbreen1/fixComme...
# 1134  Merge pull request #537 from slackhq/guideline...
# 1136  Merge pull request #538 from slackhq/guideline...
# 1138  Merge pull request #539 from slackhq/inputHeig...
# 1139  Fix README inconsistency\n\nThe Obj-C example ...
# 1142  Merge pull request #542 from slackhq/keyboardH...
# 1147  Merge pull request #547 from ClementPadovani/m...
# 1151  Merge pull request #552 from slackhq/typing-su...
# 1153  Merge pull request #555 from kirb/kirb/fix/emp...
# 1155  Merge pull request #549 from algrid/fix-509\n\...
# 1157  Merge pull request #561 from slackhq/expose_au...
# 1158  Adds support for an optional view to host outl...
# 1159      Fix broken link to code of conduct (#566)\n\n
# 1160  Fixes issue where the text input would not adj...
# 1161                  Fix markdown of README (#585)\n\n
# 1162  Added concrete targets in Podfile to work with...
# 1164  Fixing the text input not being interactive si...
# 1165  Fix compiler error in example app (#629)\n\n* ...
# 1166  Solve a problem with the new sdk on iOS 11 tha...
# 1167  Configuring SlackTextViewController framework'...
# 1173  Reverting #624 to be using UIToolbar again, sp...
# 1175  Keep scroll view content inset adjustment. Fix...
# 1176  Allowing the customization of the highlighted ...
# 1178  Update bottom margin to accommodate iPhone X h...
# 1180  fix README typo concerning Swift tableView did...
# 1181  Declare framework dependencies in podspec (#66...
# 1182  Check textInputBar hidden or not when update t...
#
#                                         parent      issues
# 189   869821db9e17c7e5d21881d43fd2efef8b5e1b67         [1]
# 191   1d9dbd7a66191ef646e9adb3b03e6e75509dd410         [4]
# 193   66e803532507002ea7a03f009a548be2db30285b         [6]
# 194   b5397d0a59375ab987529307fddd23792621759b         [6]
# 196   ef7d01df524b2975a6a76be3e0ff53e83b288074         [9]
# 206   5c7a135c4dfd871c885bc872a0458b673abaf172        [11]
# 210   de422bc286b572f4b145b236e37511a38edbb4dc        [14]
# 214   463b1cfc6c3485c4fbb7743269e919d815112ad7        [17]
# 218   905f35c8e2f9e6192efc9c0d8a1bb9acd94ba676        [19]
# 223   f09aabfe91b9e22d1c06f234615c14245b0d0e39        [23]
# 235   29f83f3de76961f449a6b077457623084dcc5504        [26]
# 241   01307f99029d1f9cb374ce40b2fccd914da3e6fa        [27]
# 244   bcf349782ab5f0d54028f425988ee75b02d9e099        [28]
# 247   e96f635b08eb6fff52c1a1c1085699ee65303354        [29]
# 255   a2258f5583a93ed639d099de687f8bc9ff324319        [30]
# 256   a2258f5583a93ed639d099de687f8bc9ff324319        [31]
# 266   ef60515a13ac452e21b509de003c04ea7e788959        [33]
# 270   05d8a69e78042c8b33a186f66493d7cee90b14ff        [36]
# 287   02ea8cf7ca72f432fb1427d5e5301d308ed64c6a        [38]
# 299   764aa2e7800c05dc8752950e273cdc2b7853a138        [41]
# 302   aa971558c069183d1cdefc9540ed04fb84e940e5        [44]
# 304   85a26d64c973842f019c69e14e27c3e2cdaa37b8        [37]
# 307   a98bf5fb0fb72d7926f1c3a2a8c0af8467b1cc2d        [46]
# 310   8f42f42963e7f01fb6b3b30c953c9b98d3099263        [45]
# 321   870f9be79b04418c0d8b415cf77acbd025ea009b        [47]
# 323   9816f577b882705fa970a18ba08a8ae860be585f        [49]
# 340   8d8b181003895949118eb45f4898e0955e71407e        [53]
# 345   36fa5fb144ef99c88a2682989dcafa03f5c9d5e2        [52]
# 357   7983d624fdaf1a756f9b24488adae5f44a7a61f4        [52]
# 369   32d0c21c11c184dd2631e2e45b3369824ebda4c0        [60]
# ...                                        ...         ...
# 1120  7ea387a7a0e6d092511c785f6ccd32068cf3a861       [523]
# 1127  e8418587b455f80ef93b6c86a1f3e34c73c1aa21       [528]
# 1130  28c015e3c0a96385bac3da060e521dea88e144c9       [532]
# 1132  0bd5b6fb04ecadda2ac1949e3308627d22762f89       [533]
# 1134  6bca7120932c0a0c8b91f3f7b30371b8ebabb069       [537]
# 1136  5d2588175616b1fdbfd141f7c24bb583121b3a64       [538]
# 1138  2fbcbe41e561e44c2f1ed456fa47f780d76b1af9       [539]
# 1139  27087de0d39bceb3099f775aa799e0703cc11d77       [540]
# 1142  97ff0cd0782df2846d306242f33b9d2a94876682       [542]
# 1147  0b20b830c6c389c7c553cc264980a16d6de79ca1       [547]
# 1151  180363ae32edb27c26e4fe50c77ee76b5ce11599       [552]
# 1153  38ad6e5704da874d3fd77ecc1ca3ef33813771ab       [555]
# 1155  08fdbfcce29668d295fcc4174d48e17d4fc97127       [549]
# 1157  d872bc33ba39fbd87343a4a40929bdacccaaf9e4       [561]
# 1158  7890a84ebafca0822a34a142fe5b16ce0c668364       [562]
# 1159  ac17d975c0e24960657720e505732993aac2257e       [566]
# 1160  037bd7f3947a6464bb59728f08e6021c3e8f8335       [507]
# 1161  1f586ebafc4189db36b0c1a45f92b98fa1636da6       [585]
# 1162  42dd4ad1eaca392635fb15be3fd686bd1786a062       [609]
# 1164  dfa11324a652f6cc920249eea8f9bc75e57c7d98  [604, 624]
# 1165  46113e08e411ff174793073e3d292c50b9d1964d       [629]
# 1166  4c74cbab29408dda9af33633f86dcc983a3b5363       [631]
# 1167  d5e01fc71cacb86da3f53c36e32056954285a913       [640]
# 1173  953ac90b3a0368cb45adef4ea7110cce87d24bb6       [619]
# 1175  9faa9d2c096661c21f6f320301033fb74c1b91a8  [642, 643]
# 1176  ad1675e585ce0fe795539ac143afc028b98357de       [613]
# 1178  4dc83a17463411fd32777a37a90e72e7199c4258  [624, 619]
# 1180  e1604ddbb2760a153c955bcea42ae55283d3e865       [662]
# 1181  3c9936780b30191969cde0100814a83d723532db       [666]
# 1182  2761b4e3551a90a26025f08175e4a875bea7031d       [661]
#
# [256 rows x 4 columns]

# %%
for items in issues_df.iterrows():
    print(items[1][5])
    if len(items[1][5]) > 0:
        print(items[1][5])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3102             return self._engine.get_value(s, k,
# -> 3103                                           tz=getattr(series.dtype, 'tz', None))
#    3104         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 5
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-7faa13f25344> in <module>()
#       1 for items in issues_df.iterrows():
# ----> 2     print(items[1][5])
#       3     if len(items[1][5]) > 0:
#       4         print(items[1][5])
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     764         key = com._apply_if_callable(key, self)
#     765         try:
# --> 766             result = self.index.get_value(self, key)
#     767
#     768             if not is_scalar(result):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3107
#    3108             try:
# -> 3109                 return libindex.get_value_box(s, key)
#    3110             except IndexError:
#    3111                 raise
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# IndexError: index out of bounds

# %%
def Q6_function(df):    
    """
    :type : DataFrame
    :rtype: DataFrame
    """
    # TYPE YOUR CODE HERE
    
    for col in df.columns:
        if '-' in set(df[col]):
            col_sum = 0
            number_of_items = 0
            for index,value in df[col].iteritems():
                if value != '-':
                    number_of_items += 1
                    col_sum += float(value)
            mean = col_sum/number_of_items      
            df[col].replace('-',mean,inplace = True)
            df[col] = df[col].astype('float64',copy = False,errors = 'ignore')
        else:
            df[col] = df[col].astype('int64',copy = False,errors = 'ignore')
    df_mean = df.mean(axis = 0)
    df_mean.drop('id',inplace = True)
    df_mean = df_mean.values.tolist()
# Call the function and print the results.
Q6_df = Q6_function(Q5_df)
print(Q6_df)
