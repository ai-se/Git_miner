# %%
import social_interaction
import code_interaction
import buggy_commit
import pandas as pd
import numpy as np
import os
import platform
from os import listdir
from os.path import isfile, join
import matplotlib.pyplot as plt

# %%
if platform.system() == 'Darwin' or platform.system() == 'Linux':
    _dir = 'Data/'
else:
    _dir = 'Data\\'
Files = [join(_dir, f) for f in listdir(_dir) if isfile(join(_dir, f))]
print(Files)
# Out:
# ['Data/mocha_committed_file.pkl', 'Data/.DS_Store', 'Data/mocha_commit.pkl']

# %%
issues = pd.read_pickle('Data/mocha_committed_file.pkl')

# %%
issues
# Out:
#                                      commit_id  \
# 0     7b9e5d1b1c419235f8c23f1c681531290d856779
# 1     ea940c217afd0d70086063f95c15338bab4ba91a
# 2     75667816befaa6c595648bae0e9e6f25898b1e68
# 3     b2fbad9009fbaab4bbc827c9606f8b84e3e235a6
# 4     91d49b29aece42847f828dd82c3e46e210065e1e
# 5     b4f5a2624d34deca3a5c2e8bf04ef258135830d5
# 6     5ef7b7a50cd1a147264d582d13731ce3fbad99ff
# 7     9bb541148e66c57e23b58b2a152aeffd1e3fbfb7
# 8     e4a72d45dcce4b870e8252d99e2b13f1273c79c4
# 9     e4a72d45dcce4b870e8252d99e2b13f1273c79c4
# 10    e4a72d45dcce4b870e8252d99e2b13f1273c79c4
# 11    e4a72d45dcce4b870e8252d99e2b13f1273c79c4
# 12    e4a72d45dcce4b870e8252d99e2b13f1273c79c4
# 13    e4a72d45dcce4b870e8252d99e2b13f1273c79c4
# 14    2d9a0cd6b9b06de21800982a174176a664bae8b1
# 15    620b2b7d45a3a5065b5050d6ca2224da7768c360
# 16    8f6fffcae1ee9ebf454a2ae85bb28f7807c08486
# 17    048ca025c4200841ec9d297b5d262b11205f6219
# 18    9377a07f6c1b15e92be41df45a6dc29eadaae8a0
# 19    9377a07f6c1b15e92be41df45a6dc29eadaae8a0
# 20    b6bf622984a124e0e92366445e4139ae3040d55e
# 21    b6bf622984a124e0e92366445e4139ae3040d55e
# 22    c6a5b2912a85323254379463174a68788b793fdd
# 23    1e65e03064591c2d95e52aecc043c4507d7c3fd0
# 24    6d198a4c4b98c9e7556d2d5bc8a0f5dc5574ec6e
# 25    dbef53e33ac3fe7e0685b1c301859bfbb7d673d6
# 26    dbef53e33ac3fe7e0685b1c301859bfbb7d673d6
# 27    41bc979f17b38cf4e7305cc9d37302e9248ba7d1
# 28    41bc979f17b38cf4e7305cc9d37302e9248ba7d1
# 29    41bc979f17b38cf4e7305cc9d37302e9248ba7d1
# ...                                        ...
# 9965  c9d5e6dd51617cd16e675c316e04785029f47a63
# 9966  c9d5e6dd51617cd16e675c316e04785029f47a63
# 9967  615e307e1111173b6ad21f666432b7fc10a632b5
# 9968  615e307e1111173b6ad21f666432b7fc10a632b5
# 9969  615e307e1111173b6ad21f666432b7fc10a632b5
# 9970  615e307e1111173b6ad21f666432b7fc10a632b5
# 9971  615e307e1111173b6ad21f666432b7fc10a632b5
# 9972  615e307e1111173b6ad21f666432b7fc10a632b5
# 9973  615e307e1111173b6ad21f666432b7fc10a632b5
# 13                            lib/reporters/progress.js
# 14                                            Readme.md
# 15                                            Readme.md
# 16                                            Readme.md
# 17                                          lib/test.js
# 18                                         lib/suite.js
# 19                                          lib/test.js
# 20                                            Readme.md
# 21                                        lib/runner.js
# 22                                            Readme.md
# 23                                            Readme.md
# 24                                            bin/mocha
# 25                                            bin/mocha
# 26                            lib/interfaces/exports.js
# 27                                            bin/mocha
# 28                                lib/interfaces/bdd.js
# 29                                lib/interfaces/tdd.js
# ...                                                 ...
# 9965                          test/unit/timeout.spec.js
# 9966                            test/unit/utils.spec.js
# 9967                                    lib/runnable.js
# 9968                                      lib/runner.js
# 9969  test/integration/fixtures/timeout-0-done.fixtu...
# 9970  test/integration/fixtures/timeout-0-noexit.fix...
# 9971  test/integration/fixtures/timeout-0-promise.fi...
# 9972                   test/integration/options.spec.js
# 9973                   test/integration/timeout.spec.js
# 9974                                    lib/runnable.js
# 9975  test/integration/fixtures/timeout-0-done.fixtu...
# 9976  test/integration/fixtures/timeout-0-noexit.fix...
# 9977  test/integration/fixtures/timeout-0-promise.fi...
# 9978                   test/integration/options.spec.js
# 9979                   test/integration/timeout.spec.js
# 9980                                       lib/mocha.js
# 9981                            test/unit/mocha.spec.js
# 9982                            test/unit/mocha.spec.js
# 9983                       test/node-unit/mocha.spec.js
# 9984                            test/unit/mocha.spec.js
# 9985                       test/node-unit/mocha.spec.js
# 9986                                       lib/mocha.js
# 9987                                       lib/mocha.js
# 9988                       test/node-unit/mocha.spec.js
# 9989                                       lib/mocha.js
# 9990                                       lib/mocha.js
# 9991                       test/node-unit/mocha.spec.js
# 9992                                       lib/mocha.js
# 9993                                         bin/_mocha
# 9994                       test/node-unit/mocha.spec.js
#
# [9995 rows x 4 columns]

# %%
issues_df = issues.dropna(subset=['issues'])

# %%
issues_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-51043829f07f> in <module>()
# ----> 1 issues_df
#
# NameError: name 'issues_df' is not defined

# %%
for items in issues_df.iterrows():
    print(items[1][5])
    if len(items[1][5]) > 0:
        print(items[1][5])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3102             return self._engine.get_value(s, k,
# -> 3103                                           tz=getattr(series.dtype, 'tz', None))
#    3104         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 5
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-63-7faa13f25344> in <module>()
#       1 for items in issues_df.iterrows():
# ----> 2     print(items[1][5])
#       3     if len(items[1][5]) > 0:
#       4         print(items[1][5])
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     764         key = com._apply_if_callable(key, self)
#     765         try:
# --> 766             result = self.index.get_value(self, key)
#     767
#     768             if not is_scalar(result):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    3107
#    3108             try:
# -> 3109                 return libindex.get_value_box(s, key)
#    3110             except IndexError:
#    3111                 raise
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# pandas/_libs/index.pyx in pandas._libs.index.get_value_box()
#
# IndexError: index out of bounds

# %%
def Q6_function(df):    
    """
    :type : DataFrame
    :rtype: DataFrame
    """
    # TYPE YOUR CODE HERE
    
    for col in df.columns:
        if '-' in set(df[col]):
            col_sum = 0
            number_of_items = 0
            for index,value in df[col].iteritems():
                if value != '-':
                    number_of_items += 1
                    col_sum += float(value)
            mean = col_sum/number_of_items      
            df[col].replace('-',mean,inplace = True)
            df[col] = df[col].astype('float64',copy = False,errors = 'ignore')
        else:
            df[col] = df[col].astype('int64',copy = False,errors = 'ignore')
    df_mean = df.mean(axis = 0)
    df_mean.drop('id',inplace = True)
    df_mean = df_mean.values.tolist()
# Call the function and print the results.
Q6_df = Q6_function(Q5_df)
print(Q6_df)
