# %%
import interaction.social_interaction as social_interaction
import interaction.code_interaction as code_interaction
import main.git_log.buggy_commit as buggy_commit
import pandas as pd
import numpy as np
import os
repo_url = 'https://github.com/abinit/abinit.git'
repo_name = 'abinit'

# %%
#sg = social_interaction.create_social_inteaction_graph(repo_name)
cg = code_interaction.create_code_interaction_graph(repo_url,repo_name)

# %%
bugs_data = buggy_commit.buggy_commit_maker(repo_name,repo_url,repo_name)
bugs_data.get_buggy_commits()
buggy_commit_data = bugs_data.get_buggy_committer()

# %%
sg_data = sg.get_user_node_degree()

# %%
cg_data = cg.get_user_node_degree()
# Out:
# starting graph
# abichecks/buildsys/Refs/abiref_gnu_5.3_debug.ac
# abichecks/buildsys/Refs/abiref_nag_6.1_openmpi.ac
# abichecks/buildsys/Refs/bob_gnu_5.3_openmp.ac
# abichecks/buildsys/Refs/buda_gnu_4.7_cuda.ac
# abichecks/buildsys/Refs/buda_intel_14.0_mpich.ac
# abichecks/buildsys/Refs/coba2_intel_13.1_openmpi.ac
# abichecks/buildsys/Refs/cronos_gnu_4.6_paral.ac
# abichecks/buildsys/Refs/cronos_gnu_5.3_paral.ac
# abichecks/buildsys/Refs/graphene_gnu_4.9_macports.ac
# abichecks/buildsys/Refs/ibm6_ibm_14.1_poe.ac
# abichecks/buildsys/Refs/inca_gnu_4.9_mpich.ac
# abichecks/buildsys/Refs/max2_gnu_5.3_dep.ac
# abichecks/buildsys/Refs/max2_gnu_5.3_mpich.ac
# abichecks/buildsys/Refs/petrus_nag_5.3_openmpi.ac
# abichecks/buildsys/Refs/testf_gnu_6.1_fb.ac
# abichecks/buildsys/Refs/tikal_gnu_4.9_cov.ac
# abichecks/buildsys/Refs/tikal_gnu_4.9_mpich.ac
# abichecks/buildsys/Refs/tikal_intel_15.0_serial.ac
# abichecks/buildsys/Refs/ubu_gnu_4.9_packages.ac
# abichecks/buildsys/Refs/ubu_intel_13.1_openmpi.ac
# abichecks/buildsys/Refs/ubu_intel_15.0_dfti.ac
# abichecks/buildsys/Refs/ubu_intel_16.0_mpich.ac
# abichecks/buildsys/Refs/abiref_gnu_5.3_debug.ac
# abichecks/buildsys/Refs/abiref_nag_6.1_openmpi.ac
# abichecks/buildsys/Refs/bob_gnu_5.3_openmp.ac
# abichecks/buildsys/Refs/buda_gnu_4.7_cuda.ac
# abichecks/buildsys/Refs/buda_intel_14.0_mpich.ac
# abichecks/buildsys/Refs/coba2_intel_13.1_openmpi.ac
# abichecks/buildsys/Refs/cronos_gnu_4.6_paral.ac
# abichecks/buildsys/Refs/cronos_gnu_5.3_paral.ac
# abichecks/buildsys/Refs/graphene_gnu_4.9_macports.ac
# abichecks/buildsys/Refs/ibm6_ibm_14.1_poe.ac
# abichecks/buildsys/Refs/inca_gnu_4.9_mpich.ac
# abichecks/buildsys/Refs/max2_gnu_5.3_dep.ac
# abichecks/buildsys/Refs/max2_gnu_5.3_mpich.ac
# abichecks/buildsys/Refs/petrus_nag_5.3_openmpi.ac
# abichecks/buildsys/Refs/testf_gnu_6.1_fb.ac
# abichecks/buildsys/Refs/tikal_gnu_4.9_cov.ac
# abichecks/buildsys/Refs/tikal_gnu_4.9_mpich.ac
# abichecks/buildsys/Refs/tikal_intel_15.0_serial.ac
# abichecks/buildsys/Refs/ubu_gnu_4.9_packages.ac
# abichecks/buildsys/Refs/ubu_intel_13.1_openmpi.ac
# abichecks/buildsys/Refs/ubu_intel_15.0_dfti.ac
# abichecks/buildsys/Refs/ubu_intel_16.0_mpich.ac
# src/78_effpot/_78_effpot
# src/78_effpot/abinit.src
# src/78_effpot/ddb_to_effective_potential.F90
# src/78_effpot/init10.F90
# src/78_effpot/libxml.c
# src/78_effpot/m_effective_potential
# src/78_effpot/m_effective_potential.F90
# src/78_effpot/m_effective_potential_file.F90
# src/78_effpot/m_epigene_dataset.F90
# src/78_effpot/m_libxml.F90
# src/78_effpot/m_monte_carlo.F90
# src/78_effpot/strain_phonon_coupling.F90
# src/72_response/m_strain.F90
# src/95_drive/mover_effpot.F90
# src/98_main/epigene.F90
# tests/v7/Input/t120.in
# tests/v7/Input/t121.in
# tests/v7/Input/t122.in
# tests/v7/Input/t123.in
# tests/v7/Refs/system.xml
# tests/v7/Refs/t120.out
# tests/v7/Refs/t121.ddb.out
# tests/v7/Refs/t122.out
# tests/v7/Refs/t123.out
# src/77_ddb/m_band2eps_dataset.F90
# developers/maintainers/fix-cpp-options.py
# src/61_occeig/m_fstab.F90
# src/72_response/m_ddk.F90
# INSTALL.md
# README.md
# README_xlf.md
# doc/README.md
# tests/README.md
# developers/README.md
# doc/input_variables/README.md
# scripts/README.md
# src/README.md
# INSTALL
# tests/README
# INSTALL.md
# README.md
# README_xlf.md
# developers/README.md
# doc/README.md
# doc/input_variables/README.md
# scripts/README.md
# src/README.md
# tests/README.md
# abichecks/.gitignore
# INSTALL.md
# README.md
# README_xlf.md
# abichecks/.gitignore
# developers/README.md
# doc/README.md
# doc/input_variables/README.md
# scripts/README.md
# src/61_occeig/m_fstab.F90
# src/72_response/m_ddk.F90
# src/README.md
# tests/README.md
# abichecks/.gitignore
# developers/maintainers/fix-cpp-options.py
# INSTALL.md
# README.md
# README_xlf.md
# abichecks/.gitignore
# abichecks/buildsys/Refs/abiref_gnu_5.3_debug.ac
# abichecks/buildsys/Refs/abiref_nag_6.1_openmpi.ac
# abichecks/buildsys/Refs/bob_gnu_5.3_openmp.ac
# abichecks/buildsys/Refs/buda_gnu_4.7_cuda.ac
# abichecks/buildsys/Refs/buda_intel_14.0_mpich.ac
# abichecks/buildsys/Refs/coba2_intel_13.1_openmpi.ac
# abichecks/buildsys/Refs/cronos_gnu_4.6_paral.ac
# abichecks/buildsys/Refs/cronos_gnu_5.3_paral.ac
# abichecks/buildsys/Refs/graphene_gnu_4.9_macports.ac
# abichecks/buildsys/Refs/ibm6_ibm_14.1_poe.ac
# abichecks/buildsys/Refs/inca_gnu_4.9_mpich.ac
# abichecks/buildsys/Refs/max2_gnu_5.3_dep.ac
# abichecks/buildsys/Refs/max2_gnu_5.3_mpich.ac
# abichecks/buildsys/Refs/petrus_nag_5.3_openmpi.ac
# abichecks/buildsys/Refs/testf_gnu_6.1_fb.ac
# abichecks/buildsys/Refs/tikal_gnu_4.9_cov.ac
# abichecks/buildsys/Refs/tikal_gnu_4.9_mpich.ac
# abichecks/buildsys/Refs/tikal_intel_15.0_serial.ac
# abichecks/buildsys/Refs/ubu_gnu_4.9_packages.ac
# abichecks/buildsys/Refs/ubu_intel_13.1_openmpi.ac
# abichecks/buildsys/Refs/ubu_intel_15.0_dfti.ac
# abichecks/buildsys/Refs/ubu_intel_16.0_mpich.ac
# developers/README.md
# developers/maintainers/fix-cpp-options.py
# doc/README.md
# doc/input_variables/README.md
# scripts/README.md
# src/61_occeig/m_fstab.F90
# src/72_response/m_ddk.F90
# src/README.md
# tests/README.md
# INSTALL.md
# README.md
# README_xlf.md
# abichecks/.gitignore
# developers/README.md
# doc/README.md
# doc/input_variables/README.md
# scripts/README.md
# src/README.md
# tests/README.md
# INSTALL.md
# README.md
# README_xlf.md
# abichecks/.gitignore
# developers/README.md
# doc/README.md
# doc/input_variables/README.md
# scripts/README.md
# src/README.md
# tests/README.md
# src/59_ionetcdf/README
# src/59_ionetcdf/_59_ionetcdf_
# src/59_ionetcdf/abinit.src
# src/59_ionetcdf/m_crystal_io.F90
# src/59_ionetcdf/m_dfpt_io.F90
# src/59_ionetcdf/write_eig.F90
# src/59_ionetcdf/wrt_moldyn_netcdf.F90
# INSTALL.md
# README.md
# README_xlf.md
# abichecks/.gitignore
# developers/README.md
# developers/maintainers/fix-cpp-options.py
# doc/README.md
# doc/input_variables/README.md
# scripts/README.md
# src/59_ionetcdf/README
# src/59_ionetcdf/_59_ionetcdf_
# src/59_ionetcdf/abinit.src
# src/59_ionetcdf/m_crystal_io.F90
# src/59_ionetcdf/m_dfpt_io.F90
# src/59_ionetcdf/write_eig.F90
# src/59_ionetcdf/wrt_moldyn_netcdf.F90
# src/61_occeig/m_fstab.F90
# src/72_response/m_ddk.F90
# src/README.md
# tests/README.md
# src/66_nonlocal/m_vkbr.F90
# src/59_ionetcdf/README
# src/59_ionetcdf/_59_ionetcdf_
# src/59_ionetcdf/abinit.src
# src/59_ionetcdf/m_crystal_io.F90
# src/59_ionetcdf/m_dfpt_io.F90
# src/59_ionetcdf/write_eig.F90
# src/59_ionetcdf/wrt_moldyn_netcdf.F90
# INSTALL.md
# README.md
# README_xlf.md
# abichecks/.gitignore
# developers/README.md
# developers/maintainers/fix-cpp-options.py
# doc/README.md
# doc/input_variables/README.md
# scripts/README.md
# src/59_ionetcdf/README
# src/59_ionetcdf/_59_ionetcdf_
# src/59_ionetcdf/abinit.src
# src/59_ionetcdf/m_crystal_io.F90
# src/59_ionetcdf/m_dfpt_io.F90
# src/59_ionetcdf/write_eig.F90
# src/59_ionetcdf/wrt_moldyn_netcdf.F90
# src/61_occeig/m_fstab.F90
# src/72_response/m_ddk.F90
# src/README.md
# tests/README.md
# INSTALL.md
# README.md
# README_xlf.md
# abichecks/.gitignore
# developers/README.md
# developers/maintainers/fix-cpp-options.py
# doc/README.md
# doc/input_variables/README.md
# scripts/README.md
# src/59_ionetcdf/README
# src/59_ionetcdf/_59_ionetcdf_
# src/59_ionetcdf/abinit.src
# src/59_ionetcdf/m_crystal_io.F90
# src/59_ionetcdf/m_dfpt_io.F90
# src/59_ionetcdf/write_eig.F90
# src/59_ionetcdf/wrt_moldyn_netcdf.F90
# src/61_occeig/m_fstab.F90
# src/72_response/m_ddk.F90
# src/README.md
# tests/README.md
# abichecks/.gitignore
# developers/maintainers/fix-cpp-options.py
# src/59_ionetcdf/README
# src/59_ionetcdf/_59_ionetcdf_
# src/59_ionetcdf/abinit.src
# src/59_ionetcdf/m_crystal_io.F90
# src/59_ionetcdf/m_dfpt_io.F90
# src/59_ionetcdf/write_eig.F90
# src/59_ionetcdf/wrt_moldyn_netcdf.F90
# src/59_ionetcdf/README
# src/59_ionetcdf/_59_ionetcdf_
# src/59_ionetcdf/abinit.src
# src/59_ionetcdf/m_crystal_io.F90
# src/59_ionetcdf/m_dfpt_io.F90
# src/59_ionetcdf/write_eig.F90
# src/59_ionetcdf/wrt_moldyn_netcdf.F90
# src/54_abiutil/m_dens.F90
# src/54_abiutil/m_dens.F90
# src/54_abiutil/m_dens.F90
# src/66_nonlocal/m_vkbr.F90
# src/78_effpot/compute_anharmonics.F90
# src/78_effpot/m_anharmonics_terms.F90
# src/78_effpot/m_harmonics_terms.F90
# src/51_manage_mpi/initmpi_supercell.F90
# src/78_eph/m_gkk.F90
# tests/v7/Input/t89.in
# tests/v7/Refs/t89.out
# INSTALL.md
# README.md
# README_xlf.md
# abichecks/.gitignore
# developers/README.md
# developers/maintainers/fix-cpp-options.py
# doc/README.md
# doc/input_variables/README.md
# scripts/README.md
# src/59_ionetcdf/README
# src/59_ionetcdf/_59_ionetcdf_
# src/59_ionetcdf/abinit.src
# src/59_ionetcdf/m_crystal_io.F90
# src/59_ionetcdf/m_dfpt_io.F90
# src/59_ionetcdf/write_eig.F90
# src/59_ionetcdf/wrt_moldyn_netcdf.F90
# src/61_occeig/m_fstab.F90
# src/66_nonlocal/m_vkbr.F90
# src/72_response/m_ddk.F90
# src/README.md
# tests/README.md
# src/54_abiutil/m_dens.F90
# tests/v6/Refs/t11o_DS2_BLZTRP.ns_energy
# tests/v6/Refs/t11o_DS2_BLZTRP.struct
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.def
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.intrans
# tests/v6/Refs/t11o_DS2_BLZTRP.ns_energy
# tests/v6/Refs/t11o_DS2_BLZTRP.struct
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.def
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.intrans
# tests/v6/Refs/t11o_DS2_BLZTRP.ns_energy
# tests/v6/Refs/t11o_DS2_BLZTRP.struct
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.def
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.intrans
# src/78_eph/m_phpi.F90
# INSTALL.md
# README.md
# README_xlf.md
# abichecks/.gitignore
# developers/README.md
# developers/maintainers/fix-cpp-options.py
# doc/README.md
# doc/input_variables/README.md
# scripts/README.md
# src/54_abiutil/m_dens.F90
# src/59_ionetcdf/README
# src/59_ionetcdf/_59_ionetcdf_
# src/59_ionetcdf/abinit.src
# src/59_ionetcdf/m_crystal_io.F90
# src/59_ionetcdf/m_dfpt_io.F90
# src/59_ionetcdf/write_eig.F90
# src/59_ionetcdf/wrt_moldyn_netcdf.F90
# src/61_occeig/m_fstab.F90
# src/66_nonlocal/m_vkbr.F90
# src/72_response/m_ddk.F90
# src/README.md
# tests/README.md
# src/dtset.log
# src/54_abiutil/m_dens.F90
# src/66_nonlocal/m_vkbr.F90
# src/78_eph/m_gkk.F90
# tests/v6/Refs/t11o_DS2_BLZTRP.ns_energy
# tests/v6/Refs/t11o_DS2_BLZTRP.struct
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.def
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.intrans
# tests/v7/Input/t89.in
# tests/v7/Refs/t89.out
# src/78_eph/m_gkk.F90
# tests/v6/Refs/t11o_DS2_BLZTRP.ns_energy
# tests/v6/Refs/t11o_DS2_BLZTRP.struct
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.def
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.intrans
# tests/v7/Input/t89.in
# tests/v7/Refs/t89.out
# src/78_effpot/m_multibinit_dataset.F90
# src/98_main/multibinit.F90
# tests/paral/Input/t12.in
# tests/paral/Input/t95.in
# tests/paral/Input/t96.in
# tests/paral/Input/t97.in
# tests/paral/Refs/system.xml
# tests/paral/Refs/t95_MPI1.out
# tests/paral/Refs/t95_MPI10.out
# tests/paral/Refs/t95_MPI2.out
# tests/paral/Refs/t95_MPI4.out
# tests/paral/Refs/t96_MPI1.out
# tests/paral/Refs/t96_MPI10.out
# tests/paral/Refs/t96_MPI2.out
# tests/paral/Refs/t96_MPI4.out
# tests/paral/Refs/t97_MPI1.out
# tests/paral/Refs/t97_MPI10.out
# tests/paral/Refs/t97_MPI2.out
# tests/paral/Refs/t97_MPI4.out
# tests/paral/Input/t98.in
# tests/paral/Refs/t98_MPI1.out
# tests/paral/Refs/t98_MPI10.out
# tests/paral/Refs/t98_MPI2.out
# tests/paral/Refs/t98_MPI4.out
# tests/v7/Input/t124.in
# tests/v7/Refs/t124.out
# src/78_effpot/effpot_xml.c
# src/78_effpot/m_effpot_xml.F90
# src/78_effpot/m_polynomial_coeff.F90
# src/78_effpot/m_polynomial_term.F90
# src/28_numeric_noabirule/m_sort.F90
# src/28_numeric_noabirule/m_sort.F90
# tests/unitary/Refs/tfftmkl_03.stdout
# tests/unitary/Refs/tfftmkl_04.stdout
# tests/unitary/Refs/tfftmkl_03.stdout
# tests/unitary/Refs/tfftmkl_04.stdout
# src/28_numeric_noabirule/m_sort.F90
# tests/unitary/Refs/tfftmkl_03.stdout
# tests/unitary/Refs/tfftmkl_04.stdout
# src/78_eph/m_phpi.F90
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/core/gsrfile.py
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/core/gsrfile.py
# src/78_eph/m_phpi.F90
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/core/gsrfile.py
# src/78_eph/m_phpi.F90
# abichecks/.gitignore
# developers/maintainers/fix-cpp-options.py
# src/61_occeig/m_fstab.F90
# src/72_response/m_ddk.F90
# src/59_ionetcdf/README
# src/59_ionetcdf/_59_ionetcdf_
# src/59_ionetcdf/abinit.src
# src/59_ionetcdf/m_crystal_io.F90
# src/59_ionetcdf/m_dfpt_io.F90
# src/59_ionetcdf/write_eig.F90
# src/59_ionetcdf/wrt_moldyn_netcdf.F90
# src/61_occeig/m_pjedos.F90
# src/61_occeig/m_epjdos.F90
# src/67_common/m_epjdos.F90
# src/67_common/partial_dos_fractions_paw.F90
# tests/Psps_for_tests/C.psp8
# tests/mpiio/Input/t27.in
# tests/mpiio/Refs/t27_MPI4.out
# tests/mpiio/Refs/t27_MPI4o_DS2_DOS_AT0001
# tests/mpiio/Refs/t26_MPI4o_DS5_DOS_AT0002
# src/54_abiutil/m_dens.F90
# src/66_nonlocal/m_vkbr.F90
# tests/mpiio/Input/t28.in
# tests/mpiio/Refs/t28_MPI4.out
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4o_DS2_DOS_AT0001
# tests/v7/Refs/t17o_DS1_DOS
# tests/v7/Refs/t17o_DS2_DOS_AT0001
# tests/v7/Refs/t04o_DOS_ATEXTRA0010
# tests/v6/Refs/t11o_DS2_BLZTRP.ns_energy
# tests/v6/Refs/t11o_DS2_BLZTRP.struct
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.def
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.intrans
# src/78_eph/m_gkk.F90
# tests/v7/Input/t89.in
# tests/v7/Refs/t89.out
# src/28_numeric_noabirule/m_sort.F90
# tests/unitary/Refs/tfftmkl_03.stdout
# tests/unitary/Refs/tfftmkl_04.stdout
# src/67_common/m_epjdos.F90
# src/67_common/partial_dos_fractions_paw.F90
# tests/Psps_for_tests/C.psp8
# tests/mpiio/Input/t27.in
# tests/mpiio/Input/t28.in
# tests/mpiio/Refs/t26_MPI4o_DS5_DOS_AT0002
# tests/mpiio/Refs/t27_MPI4.out
# tests/mpiio/Refs/t27_MPI4o_DS2_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4.out
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4o_DS2_DOS_AT0001
# tests/v7/Refs/t04o_DOS_ATEXTRA0010
# tests/v7/Refs/t17o_DS1_DOS
# tests/v7/Refs/t17o_DS2_DOS_AT0001
# src/72_response/m_strain.F90
# src/77_ddb/m_band2eps_dataset.F90
# src/78_effpot/_78_effpot
# src/78_effpot/abinit.src
# src/78_effpot/compute_anharmonics.F90
# src/78_effpot/ddb_to_effective_potential.F90
# src/78_effpot/effpot_xml.c
# src/78_effpot/init10.F90
# src/78_effpot/m_anharmonics_terms.F90
# src/78_effpot/m_effective_potential.F90
# src/78_effpot/m_effective_potential_file.F90
# src/78_effpot/m_effpot_xml.F90
# src/78_effpot/m_harmonics_terms.F90
# src/78_effpot/m_monte_carlo.F90
# src/78_effpot/m_multibinit_dataset.F90
# src/95_drive/mover_effpot.F90
# src/98_main/multibinit.F90
# tests/paral/Input/t95.in
# tests/paral/Input/t96.in
# tests/paral/Input/t97.in
# tests/paral/Input/t98.in
# tests/paral/Refs/system.xml
# tests/paral/Refs/t95_MPI1.out
# tests/paral/Refs/t95_MPI10.out
# tests/paral/Refs/t95_MPI2.out
# tests/paral/Refs/t95_MPI4.out
# tests/paral/Refs/t96_MPI1.out
# tests/paral/Refs/t96_MPI10.out
# tests/paral/Refs/t96_MPI2.out
# tests/paral/Refs/t96_MPI4.out
# tests/paral/Refs/t97_MPI1.out
# tests/paral/Refs/t97_MPI10.out
# tests/paral/Refs/t97_MPI2.out
# tests/paral/Refs/t97_MPI4.out
# tests/paral/Refs/t98_MPI1.out
# tests/paral/Refs/t98_MPI10.out
# tests/paral/Refs/t98_MPI2.out
# tests/paral/Refs/t98_MPI4.out
# tests/v7/Input/t120.in
# tests/v7/Input/t121.in
# tests/v7/Input/t122.in
# tests/v7/Input/t123.in
# tests/v7/Input/t124.in
# tests/v7/Refs/system.xml
# tests/v7/Refs/t120.out
# tests/v7/Refs/t121.ddb.out
# tests/v7/Refs/t122.out
# tests/v7/Refs/t123.out
# tests/v7/Refs/t124.out
# tests/unitary/Refs/tfftmkl_03.stdout
# tests/unitary/Refs/tfftmkl_04.stdout
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/core/gsrfile.py
# src/78_eph/m_phpi.F90
# tests/v8/Refs/.gitkeep
# tests/v8/README
# tests/v8/__init__.py
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/core/gsrfile.py
# src/28_numeric_noabirule/m_sort.F90
# src/67_common/m_epjdos.F90
# src/67_common/partial_dos_fractions_paw.F90
# src/72_response/m_strain.F90
# src/77_ddb/m_band2eps_dataset.F90
# src/78_effpot/_78_effpot
# src/78_effpot/abinit.src
# src/78_effpot/compute_anharmonics.F90
# src/78_effpot/ddb_to_effective_potential.F90
# src/78_effpot/effpot_xml.c
# src/78_effpot/init10.F90
# src/78_effpot/m_anharmonics_terms.F90
# src/78_effpot/m_effective_potential.F90
# src/78_effpot/m_effective_potential_file.F90
# src/78_effpot/m_effpot_xml.F90
# src/78_effpot/m_harmonics_terms.F90
# src/78_effpot/m_monte_carlo.F90
# src/78_effpot/m_multibinit_dataset.F90
# src/78_eph/m_phpi.F90
# src/95_drive/mover_effpot.F90
# src/98_main/multibinit.F90
# tests/Psps_for_tests/C.psp8
# tests/mpiio/Input/t27.in
# tests/mpiio/Input/t28.in
# tests/mpiio/Refs/t26_MPI4o_DS5_DOS_AT0002
# tests/mpiio/Refs/t27_MPI4.out
# tests/mpiio/Refs/t27_MPI4o_DS2_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4.out
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4o_DS2_DOS_AT0001
# tests/paral/Input/t95.in
# tests/paral/Input/t96.in
# tests/paral/Input/t97.in
# tests/paral/Input/t98.in
# tests/paral/Refs/system.xml
# tests/paral/Refs/t95_MPI1.out
# tests/paral/Refs/t95_MPI10.out
# tests/paral/Refs/t95_MPI2.out
# tests/paral/Refs/t95_MPI4.out
# tests/paral/Refs/t96_MPI1.out
# tests/paral/Refs/t96_MPI10.out
# tests/paral/Refs/t96_MPI2.out
# tests/paral/Refs/t96_MPI4.out
# tests/paral/Refs/t97_MPI1.out
# tests/paral/Refs/t97_MPI10.out
# tests/paral/Refs/t97_MPI2.out
# tests/paral/Refs/t97_MPI4.out
# tests/paral/Refs/t98_MPI1.out
# tests/paral/Refs/t98_MPI10.out
# tests/paral/Refs/t98_MPI2.out
# tests/paral/Refs/t98_MPI4.out
# tests/unitary/Refs/tfftmkl_03.stdout
# tests/unitary/Refs/tfftmkl_04.stdout
# tests/v7/Input/t120.in
# tests/v7/Input/t121.in
# tests/v7/Input/t122.in
# tests/v7/Input/t123.in
# tests/v7/Input/t124.in
# tests/v7/Refs/system.xml
# tests/v7/Refs/t04o_DOS_ATEXTRA0010
# tests/v7/Refs/t120.out
# tests/v7/Refs/t121.ddb.out
# tests/v7/Refs/t122.out
# tests/v7/Refs/t123.out
# tests/v7/Refs/t124.out
# tests/v7/Refs/t17o_DS1_DOS
# tests/v7/Refs/t17o_DS2_DOS_AT0001
# src/67_common/m_epjdos.F90
# src/67_common/partial_dos_fractions_paw.F90
# src/72_response/m_strain.F90
# src/77_ddb/m_band2eps_dataset.F90
# src/78_effpot/_78_effpot
# src/78_effpot/abinit.src
# src/78_effpot/compute_anharmonics.F90
# src/78_effpot/ddb_to_effective_potential.F90
# src/78_effpot/effpot_xml.c
# src/78_effpot/init10.F90
# src/78_effpot/m_anharmonics_terms.F90
# src/78_effpot/m_effective_potential.F90
# src/78_effpot/m_effective_potential_file.F90
# src/78_effpot/m_effpot_xml.F90
# src/78_effpot/m_harmonics_terms.F90
# src/78_effpot/m_monte_carlo.F90
# src/78_effpot/m_multibinit_dataset.F90
# src/95_drive/mover_effpot.F90
# src/98_main/multibinit.F90
# tests/Psps_for_tests/C.psp8
# tests/mpiio/Input/t27.in
# tests/mpiio/Input/t28.in
# tests/mpiio/Refs/t26_MPI4o_DS5_DOS_AT0002
# tests/mpiio/Refs/t27_MPI4.out
# tests/mpiio/Refs/t27_MPI4o_DS2_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4.out
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4o_DS2_DOS_AT0001
# tests/paral/Input/t95.in
# tests/paral/Input/t96.in
# tests/paral/Input/t97.in
# tests/paral/Input/t98.in
# tests/paral/Refs/system.xml
# tests/paral/Refs/t95_MPI1.out
# tests/paral/Refs/t95_MPI10.out
# tests/paral/Refs/t95_MPI2.out
# tests/paral/Refs/t95_MPI4.out
# tests/paral/Refs/t96_MPI1.out
# tests/paral/Refs/t96_MPI10.out
# tests/paral/Refs/t96_MPI2.out
# tests/paral/Refs/t96_MPI4.out
# tests/paral/Refs/t97_MPI1.out
# tests/paral/Refs/t97_MPI10.out
# tests/paral/Refs/t97_MPI2.out
# tests/paral/Refs/t97_MPI4.out
# tests/paral/Refs/t98_MPI1.out
# tests/paral/Refs/t98_MPI10.out
# tests/paral/Refs/t98_MPI2.out
# tests/paral/Refs/t98_MPI4.out
# tests/v7/Input/t120.in
# tests/v7/Input/t121.in
# tests/v7/Input/t122.in
# tests/v7/Input/t123.in
# tests/v7/Input/t124.in
# tests/v7/Refs/system.xml
# tests/v7/Refs/t04o_DOS_ATEXTRA0010
# tests/v7/Refs/t120.out
# tests/v7/Refs/t121.ddb.out
# tests/v7/Refs/t122.out
# tests/v7/Refs/t123.out
# tests/v7/Refs/t124.out
# tests/v7/Refs/t17o_DS1_DOS
# tests/v7/Refs/t17o_DS2_DOS_AT0001
# tests/v8/Refs/.gitkeep
# tests/v8/README
# tests/v8/__init__.py
# src/78_eph/m_sigmaph.F90
# src/78_eph/m_sigmaph.F90
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/core/gsrfile.py
# src/28_numeric_noabirule/m_sort.F90
# src/67_common/m_epjdos.F90
# src/67_common/partial_dos_fractions_paw.F90
# src/72_response/m_strain.F90
# src/77_ddb/m_band2eps_dataset.F90
# src/78_effpot/_78_effpot
# src/78_effpot/abinit.src
# src/78_effpot/compute_anharmonics.F90
# src/78_effpot/ddb_to_effective_potential.F90
# src/78_effpot/effpot_xml.c
# src/78_effpot/init10.F90
# src/78_effpot/m_anharmonics_terms.F90
# src/78_effpot/m_effective_potential.F90
# src/78_effpot/m_effective_potential_file.F90
# src/78_effpot/m_effpot_xml.F90
# src/78_effpot/m_harmonics_terms.F90
# src/78_effpot/m_monte_carlo.F90
# src/78_effpot/m_multibinit_dataset.F90
# src/78_eph/m_gkk.F90
# src/78_eph/m_phpi.F90
# src/95_drive/mover_effpot.F90
# src/98_main/multibinit.F90
# tests/Psps_for_tests/C.psp8
# tests/mpiio/Input/t27.in
# tests/mpiio/Input/t28.in
# tests/mpiio/Refs/t26_MPI4o_DS5_DOS_AT0002
# tests/mpiio/Refs/t27_MPI4.out
# tests/mpiio/Refs/t27_MPI4o_DS2_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4.out
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4o_DS2_DOS_AT0001
# tests/paral/Input/t95.in
# tests/paral/Input/t96.in
# tests/paral/Input/t97.in
# tests/paral/Input/t98.in
# tests/paral/Refs/system.xml
# tests/paral/Refs/t95_MPI1.out
# tests/paral/Refs/t95_MPI10.out
# tests/paral/Refs/t95_MPI2.out
# tests/paral/Refs/t95_MPI4.out
# tests/paral/Refs/t96_MPI1.out
# tests/paral/Refs/t96_MPI10.out
# tests/paral/Refs/t96_MPI2.out
# tests/paral/Refs/t96_MPI4.out
# tests/paral/Refs/t97_MPI1.out
# tests/paral/Refs/t97_MPI10.out
# tests/paral/Refs/t97_MPI2.out
# tests/paral/Refs/t97_MPI4.out
# tests/paral/Refs/t98_MPI1.out
# tests/paral/Refs/t98_MPI10.out
# tests/paral/Refs/t98_MPI2.out
# tests/paral/Refs/t98_MPI4.out
# tests/unitary/Refs/tfftmkl_03.stdout
# tests/unitary/Refs/tfftmkl_04.stdout
# tests/v6/Refs/t11o_DS2_BLZTRP.ns_energy
# tests/v6/Refs/t11o_DS2_BLZTRP.struct
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.def
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.intrans
# tests/v7/Input/t120.in
# tests/v7/Input/t121.in
# tests/v7/Input/t122.in
# tests/v7/Input/t123.in
# tests/v7/Input/t124.in
# tests/v7/Input/t89.in
# tests/v7/Refs/system.xml
# tests/v7/Refs/t04o_DOS_ATEXTRA0010
# tests/v7/Refs/t120.out
# tests/v7/Refs/t121.ddb.out
# tests/v7/Refs/t122.out
# tests/v7/Refs/t123.out
# tests/v7/Refs/t124.out
# tests/v7/Refs/t17o_DS1_DOS
# tests/v7/Refs/t17o_DS2_DOS_AT0001
# tests/v7/Refs/t89.out
# tests/v8/Refs/.gitkeep
# tests/v8/README
# tests/v8/__init__.py
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/core/gsrfile.py
# src/28_numeric_noabirule/m_sort.F90
# src/67_common/m_epjdos.F90
# src/67_common/partial_dos_fractions_paw.F90
# src/78_effpot/ddb_to_effective_potential.F90
# src/78_eph/m_phpi.F90
# src/78_eph/m_sigmaph.F90
# tests/Psps_for_tests/C.psp8
# tests/mpiio/Input/t27.in
# tests/mpiio/Input/t28.in
# tests/mpiio/Refs/t26_MPI4o_DS5_DOS_AT0002
# tests/mpiio/Refs/t27_MPI4.out
# tests/mpiio/Refs/t27_MPI4o_DS2_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4.out
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4o_DS2_DOS_AT0001
# tests/unitary/Refs/tfftmkl_03.stdout
# tests/unitary/Refs/tfftmkl_04.stdout
# tests/v7/Refs/t04o_DOS_ATEXTRA0010
# tests/v7/Refs/t17o_DS1_DOS
# tests/v7/Refs/t17o_DS2_DOS_AT0001
# tests/v8/Refs/.gitkeep
# tests/v8/README
# tests/v8/__init__.py
# src/78_effpot/m_fit_polynomial_coeff.F90
# src/78_eph/m_sigmaph.F90
# src/78_effpot/m_polynomial_coeff.F90
# src/78_effpot/m_polynomial_term.F90
# src/56_recipspace/m_kpts.F90
# tests/v7/Refs/t88o_DS1_PH.bxsf
# src/78_eph/m_sigmaph.F90
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_TOTAL
# INSTALL.md
# README.md
# README_xlf.md
# abichecks/.gitignore
# developers/README.md
# developers/maintainers/fix-cpp-options.py
# doc/README.md
# doc/input_variables/README.md
# scripts/README.md
# src/61_occeig/m_fstab.F90
# src/72_response/m_ddk.F90
# src/README.md
# tests/README.md
# src/59_ionetcdf/README
# src/59_ionetcdf/_59_ionetcdf_
# src/59_ionetcdf/abinit.src
# src/59_ionetcdf/m_crystal_io.F90
# src/59_ionetcdf/m_dfpt_io.F90
# src/59_ionetcdf/write_eig.F90
# src/59_ionetcdf/wrt_moldyn_netcdf.F90
# src/66_nonlocal/m_vkbr.F90
# src/54_abiutil/m_dens.F90
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/core/gsrfile.py
# src/28_numeric_noabirule/m_sort.F90
# src/67_common/m_epjdos.F90
# src/67_common/partial_dos_fractions_paw.F90
# src/72_response/m_strain.F90
# src/77_ddb/m_band2eps_dataset.F90
# src/78_effpot/_78_effpot
# src/78_effpot/abinit.src
# src/78_effpot/compute_anharmonics.F90
# src/78_effpot/ddb_to_effective_potential.F90
# src/78_effpot/effpot_xml.c
# src/78_effpot/init10.F90
# src/78_effpot/m_anharmonics_terms.F90
# src/78_effpot/m_effective_potential.F90
# src/78_effpot/m_effective_potential_file.F90
# src/78_effpot/m_effpot_xml.F90
# src/78_effpot/m_harmonics_terms.F90
# src/78_effpot/m_monte_carlo.F90
# src/78_effpot/m_multibinit_dataset.F90
# src/78_eph/m_gkk.F90
# src/78_eph/m_phpi.F90
# src/95_drive/mover_effpot.F90
# src/98_main/multibinit.F90
# tests/Psps_for_tests/C.psp8
# tests/mpiio/Input/t27.in
# tests/mpiio/Input/t28.in
# tests/mpiio/Refs/t26_MPI4o_DS5_DOS_AT0002
# tests/mpiio/Refs/t27_MPI4.out
# tests/mpiio/Refs/t27_MPI4o_DS2_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4.out
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4o_DS2_DOS_AT0001
# tests/paral/Input/t95.in
# tests/paral/Input/t96.in
# tests/paral/Input/t97.in
# tests/paral/Input/t98.in
# tests/paral/Refs/system.xml
# tests/paral/Refs/t95_MPI1.out
# tests/paral/Refs/t95_MPI10.out
# tests/paral/Refs/t95_MPI2.out
# tests/paral/Refs/t95_MPI4.out
# tests/paral/Refs/t96_MPI1.out
# tests/paral/Refs/t96_MPI10.out
# tests/paral/Refs/t96_MPI2.out
# tests/paral/Refs/t96_MPI4.out
# tests/paral/Refs/t97_MPI1.out
# tests/paral/Refs/t97_MPI10.out
# tests/paral/Refs/t97_MPI2.out
# tests/paral/Refs/t97_MPI4.out
# tests/paral/Refs/t98_MPI1.out
# tests/paral/Refs/t98_MPI10.out
# tests/paral/Refs/t98_MPI2.out
# tests/paral/Refs/t98_MPI4.out
# tests/unitary/Refs/tfftmkl_03.stdout
# tests/unitary/Refs/tfftmkl_04.stdout
# tests/v6/Refs/t11o_DS2_BLZTRP.ns_energy
# tests/v6/Refs/t11o_DS2_BLZTRP.struct
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.def
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.intrans
# tests/v7/Input/t120.in
# tests/v7/Input/t121.in
# tests/v7/Input/t122.in
# tests/v7/Input/t123.in
# tests/v7/Input/t124.in
# tests/v7/Input/t89.in
# tests/v7/Refs/system.xml
# tests/v7/Refs/t04o_DOS_ATEXTRA0010
# tests/v7/Refs/t120.out
# tests/v7/Refs/t121.ddb.out
# tests/v7/Refs/t122.out
# tests/v7/Refs/t123.out
# tests/v7/Refs/t124.out
# tests/v7/Refs/t17o_DS1_DOS
# tests/v7/Refs/t17o_DS2_DOS_AT0001
# tests/v7/Refs/t89.out
# src/78_eph/m_sigmaph.F90
# tests/v8/Refs/.gitkeep
# tests/v8/README
# tests/v8/__init__.py
# src/78_effpot/m_polynomial_coeff.F90
# src/78_effpot/m_polynomial_term.F90
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_TOTAL
# tests/paral/Input/t99.in
# tests/paral/Refs/t99_MPI8.out
# tests/paral/Refs/t99_MPI8o_DS2_Legendre_coefficients.dat
# tests/v8/Input/t01.in
# tests/v8/Refs/t01.out
# tests/v8/Refs/t01o_DS2_Legendre_coefficients.dat
# tests/paral/Refs/t99_MPI10.out
# tests/paral/Refs/t99_MPI10o_DS2_Legendre_coefficients.dat
# tests/paral/Refs/t99_MPI4.out
# tests/paral/Refs/t99_MPI4o_DS2_Legendre_coefficients.dat
# tests/paral/Input/t99.in
# tests/paral/Refs/t99_MPI4.out
# tests/paral/Refs/t99_MPI4o_DS2_Legendre_coefficients.dat
# tests/v8/Input/t01.in
# tests/v8/Refs/t01.out
# tests/v8/Refs/t01o_DS2_Legendre_coefficients.dat
# tests/paral/Input/t99.in
# tests/paral/Refs/t99_MPI4.out
# tests/paral/Refs/t99_MPI4o_DS2_Legendre_coefficients.dat
# tests/v8/Input/t01.in
# tests/v8/Refs/t01.out
# tests/v8/Refs/t01o_DS2_Legendre_coefficients.dat
# tests/paral/Input/t99.in
# tests/paral/Refs/t99_MPI4.out
# tests/paral/Refs/t99_MPI4o_DS2_Legendre_coefficients.dat
# tests/v8/Input/t01.in
# tests/v8/Refs/t01.out
# tests/v8/Refs/t01o_DS2_Legendre_coefficients.dat
# tests/v7/Refs/t93.out_ep_SBK_ORG
# tests/v7/Refs/t94.out_ep_SBK_ORG
# tests/v7/Refs/t93.out_ep_SBK
# tests/v7/Refs/t94.out_ep_SBK
# tests/v7/Refs/t93.out_ep_SBK_ORG
# tests/v7/Refs/t94.out_ep_SBK_ORG
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_TOTAL
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/core/gsrfile.py
# src/28_numeric_noabirule/m_sort.F90
# src/54_abiutil/m_dens.F90
# src/59_ionetcdf/README
# src/59_ionetcdf/_59_ionetcdf_
# src/59_ionetcdf/abinit.src
# src/59_ionetcdf/m_crystal_io.F90
# src/59_ionetcdf/m_dfpt_io.F90
# src/59_ionetcdf/write_eig.F90
# src/59_ionetcdf/wrt_moldyn_netcdf.F90
# src/66_nonlocal/m_vkbr.F90
# src/67_common/m_epjdos.F90
# src/67_common/partial_dos_fractions_paw.F90
# src/72_response/m_strain.F90
# src/77_ddb/m_band2eps_dataset.F90
# src/78_effpot/_78_effpot
# src/78_effpot/abinit.src
# src/78_effpot/compute_anharmonics.F90
# src/78_effpot/effpot_xml.c
# src/78_effpot/init10.F90
# src/78_effpot/m_anharmonics_terms.F90
# src/78_effpot/m_effective_potential.F90
# src/78_effpot/m_effective_potential_file.F90
# src/78_effpot/m_harmonics_terms.F90
# src/78_effpot/m_monte_carlo.F90
# src/78_effpot/m_multibinit_dataset.F90
# src/78_effpot/m_polynomial_coeff.F90
# src/78_effpot/m_polynomial_term.F90
# src/78_eph/m_gkk.F90
# src/78_eph/m_phpi.F90
# src/78_eph/m_sigmaph.F90
# src/95_drive/mover_effpot.F90
# src/98_main/multibinit.F90
# tests/Psps_for_tests/C.psp8
# tests/mpiio/Input/t27.in
# tests/mpiio/Input/t28.in
# tests/mpiio/Refs/t26_MPI4o_DS5_DOS_AT0002
# tests/mpiio/Refs/t27_MPI4.out
# tests/mpiio/Refs/t27_MPI4o_DS2_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4.out
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4o_DS2_DOS_AT0001
# tests/paral/Input/t95.in
# tests/paral/Input/t96.in
# tests/paral/Input/t97.in
# tests/paral/Input/t98.in
# tests/v7/Refs/system.xml
# tests/paral/Refs/t95_MPI1.out
# tests/paral/Refs/t95_MPI10.out
# tests/paral/Refs/t95_MPI2.out
# tests/paral/Refs/t95_MPI4.out
# tests/paral/Refs/t96_MPI1.out
# tests/paral/Refs/t96_MPI10.out
# tests/paral/Refs/t96_MPI2.out
# tests/paral/Refs/t96_MPI4.out
# tests/paral/Refs/t97_MPI1.out
# tests/paral/Refs/t97_MPI10.out
# tests/paral/Refs/t97_MPI2.out
# tests/paral/Refs/t97_MPI4.out
# tests/paral/Refs/t98_MPI1.out
# tests/paral/Refs/t98_MPI10.out
# tests/paral/Refs/t98_MPI2.out
# tests/paral/Refs/t98_MPI4.out
# tests/unitary/Refs/tfftmkl_03.stdout
# tests/unitary/Refs/tfftmkl_04.stdout
# tests/v6/Refs/t11o_DS2_BLZTRP.ns_energy
# tests/v6/Refs/t11o_DS2_BLZTRP.struct
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.def
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.intrans
# tests/v7/Input/t120.in
# tests/v7/Input/t121.in
# tests/v7/Input/t122.in
# tests/v7/Input/t123.in
# tests/v7/Input/t124.in
# tests/v7/Input/t89.in
# tests/v7/Refs/t04o_DOS_ATEXTRA0010
# tests/v7/Refs/t120.out
# tests/v7/Refs/t121.ddb.out
# tests/v7/Refs/t122.out
# tests/v7/Refs/t123.out
# tests/v7/Refs/t124.out
# tests/v7/Refs/t17o_DS1_DOS
# tests/v7/Refs/t17o_DS2_DOS_AT0001
# tests/v7/Refs/t89.out
# tests/v8/Refs/.gitkeep
# tests/v8/README
# tests/v8/__init__.py
# tests/paral/Input/t99.in
# tests/paral/Refs/t99_MPI4.out
# tests/paral/Refs/t99_MPI4o_DS2_Legendre_coefficients.dat
# tests/v7/Refs/t93.out_ep_SBK_ORG
# tests/v7/Refs/t94.out_ep_SBK_ORG
# tests/v8/Input/t01.in
# tests/v8/Refs/t01.out
# tests/v8/Refs/t01o_DS2_Legendre_coefficients.dat
# tests/v7/Refs/t93.out_ep_SBK_ORG
# tests/v7/Refs/t94.out_ep_SBK_ORG
# tests/v7/Refs/t93.out_ep_SBK_ORG
# tests/v7/Refs/t94.out_ep_SBK_ORG
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_TOTAL
# tests/mpiio/Refs/t26_MPI4o_DS5_VCLMB_1DM
# tests/mpiio/Refs/t27_MPI4o_DS1_VCLMB_1DM
# tests/mpiio/Refs/t27_MPI4o_DS2_VCLMB_1DM
# tests/mpiio/Refs/t28_MPI4o_DS1_VCLMB_1DM
# tests/mpiio/Refs/t28_MPI4o_DS2_VCLMB_1DM
# tests/mpiio/Refs/t26_MPI4o_DS5_VCLMB_1DM
# tests/mpiio/Refs/t27_MPI4o_DS1_VCLMB_1DM
# tests/mpiio/Refs/t27_MPI4o_DS2_VCLMB_1DM
# tests/mpiio/Refs/t28_MPI4o_DS1_VCLMB_1DM
# tests/mpiio/Refs/t28_MPI4o_DS2_VCLMB_1DM
# src/56_recipspace/m_kpts.F90
# tests/mpiio/Refs/t26_MPI4o_DS5_VCLMB_1DM
# tests/mpiio/Refs/t27_MPI4o_DS1_VCLMB_1DM
# tests/mpiio/Refs/t27_MPI4o_DS2_VCLMB_1DM
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_TOTAL
# tests/mpiio/Refs/t28_MPI4o_DS1_VCLMB_1DM
# tests/mpiio/Refs/t28_MPI4o_DS2_VCLMB_1DM
# tests/paral/Input/t99.in
# tests/paral/Refs/t99_MPI4.out
# tests/paral/Refs/t99_MPI4o_DS2_Legendre_coefficients.dat
# tests/v7/Refs/t88o_DS1_PH.bxsf
# tests/v7/Refs/t93.out_ep_SBK_ORG
# tests/v7/Refs/t94.out_ep_SBK_ORG
# tests/v8/Input/t01.in
# tests/v8/Refs/t01.out
# tests/v8/Refs/t01o_DS2_Legendre_coefficients.dat
# src/56_recipspace/m_kpts.F90
# tests/mpiio/Refs/t26_MPI4o_DS5_VCLMB_1DM
# tests/mpiio/Refs/t27_MPI4o_DS1_VCLMB_1DM
# tests/mpiio/Refs/t27_MPI4o_DS2_VCLMB_1DM
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_TOTAL
# tests/mpiio/Refs/t28_MPI4o_DS1_VCLMB_1DM
# tests/mpiio/Refs/t28_MPI4o_DS2_VCLMB_1DM
# tests/paral/Input/t99.in
# tests/paral/Refs/t99_MPI4.out
# tests/paral/Refs/t99_MPI4o_DS2_Legendre_coefficients.dat
# tests/v7/Refs/t88o_DS1_PH.bxsf
# tests/v7/Refs/t93.out_ep_SBK_ORG
# tests/v7/Refs/t94.out_ep_SBK_ORG
# tests/v8/Input/t01.in
# tests/v8/Refs/t01.out
# tests/v8/Refs/t01o_DS2_Legendre_coefficients.dat
# src/45_geomoptim/m_lbfgs.F90
# src/45_geomoptim/pred_lbfgs.F90
# INSTALL.md
# README.md
# README_xlf.md
# abichecks/.gitignore
# developers/README.md
# developers/maintainers/fix-cpp-options.py
# doc/README.md
# doc/input_variables/README.md
# scripts/README.md
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/core/gsrfile.py
# src/28_numeric_noabirule/m_sort.F90
# src/54_abiutil/m_dens.F90
# src/59_ionetcdf/README
# src/59_ionetcdf/_59_ionetcdf_
# src/59_ionetcdf/abinit.src
# src/59_ionetcdf/m_crystal_io.F90
# src/59_ionetcdf/m_dfpt_io.F90
# src/59_ionetcdf/write_eig.F90
# src/59_ionetcdf/wrt_moldyn_netcdf.F90
# src/61_occeig/m_fstab.F90
# src/66_nonlocal/m_vkbr.F90
# src/67_common/m_epjdos.F90
# src/67_common/partial_dos_fractions_paw.F90
# src/72_response/m_ddk.F90
# src/72_response/m_strain.F90
# src/77_ddb/m_band2eps_dataset.F90
# src/78_effpot/_78_effpot
# src/78_effpot/abinit.src
# src/78_effpot/compute_anharmonics.F90
# src/78_effpot/effpot_xml.c
# src/78_effpot/init10.F90
# src/78_effpot/m_anharmonics_terms.F90
# src/78_effpot/m_effective_potential.F90
# src/78_effpot/m_effective_potential_file.F90
# src/78_effpot/m_harmonics_terms.F90
# src/78_effpot/m_monte_carlo.F90
# src/78_effpot/m_multibinit_dataset.F90
# src/78_effpot/m_polynomial_coeff.F90
# src/78_effpot/m_polynomial_term.F90
# src/78_eph/m_gkk.F90
# src/78_eph/m_phpi.F90
# src/78_eph/m_sigmaph.F90
# src/95_drive/mover_effpot.F90
# src/98_main/multibinit.F90
# src/README.md
# tests/Psps_for_tests/C.psp8
# tests/README.md
# tests/mpiio/Input/t27.in
# tests/mpiio/Input/t28.in
# tests/mpiio/Refs/t26_MPI4o_DS5_DOS_AT0002
# tests/mpiio/Refs/t27_MPI4.out
# tests/mpiio/Refs/t27_MPI4o_DS2_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4.out
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_TOTAL
# tests/mpiio/Refs/t28_MPI4o_DS2_DOS_AT0001
# tests/paral/Input/t95.in
# tests/paral/Input/t96.in
# tests/paral/Input/t97.in
# tests/paral/Input/t98.in
# tests/paral/Input/t99.in
# tests/v7/Refs/system.xml
# tests/paral/Refs/t95_MPI1.out
# tests/paral/Refs/t95_MPI10.out
# tests/paral/Refs/t95_MPI2.out
# tests/paral/Refs/t95_MPI4.out
# tests/paral/Refs/t96_MPI1.out
# tests/paral/Refs/t96_MPI10.out
# tests/paral/Refs/t96_MPI2.out
# tests/paral/Refs/t96_MPI4.out
# tests/paral/Refs/t97_MPI1.out
# tests/paral/Refs/t97_MPI10.out
# tests/paral/Refs/t97_MPI2.out
# tests/paral/Refs/t97_MPI4.out
# tests/paral/Refs/t98_MPI1.out
# tests/paral/Refs/t98_MPI10.out
# tests/paral/Refs/t98_MPI2.out
# tests/paral/Refs/t98_MPI4.out
# tests/paral/Refs/t99_MPI4.out
# tests/paral/Refs/t99_MPI4o_DS2_Legendre_coefficients.dat
# tests/unitary/Refs/tfftmkl_03.stdout
# tests/unitary/Refs/tfftmkl_04.stdout
# tests/v6/Refs/t11o_DS2_BLZTRP.ns_energy
# tests/v6/Refs/t11o_DS2_BLZTRP.struct
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.def
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.intrans
# tests/v7/Input/t120.in
# tests/v7/Input/t121.in
# tests/v7/Input/t122.in
# tests/v7/Input/t123.in
# tests/v7/Input/t124.in
# tests/v7/Input/t89.in
# tests/v7/Refs/t04o_DOS_ATEXTRA0010
# tests/v7/Refs/t120.out
# tests/v7/Refs/t121.ddb.out
# tests/v7/Refs/t122.out
# tests/v7/Refs/t123.out
# tests/v7/Refs/t124.out
# tests/v7/Refs/t17o_DS1_DOS
# tests/v7/Refs/t17o_DS2_DOS_AT0001
# tests/v7/Refs/t89.out
# tests/v7/Refs/t93.out_ep_SBK_ORG
# tests/v7/Refs/t94.out_ep_SBK_ORG
# tests/v8/Refs/.gitkeep
# tests/v8/Input/t01.in
# tests/v8/README
# tests/v8/Refs/t01.out
# tests/v8/Refs/t01o_DS2_Legendre_coefficients.dat
# tests/v8/__init__.py
# tests/mpiio/Refs/t26_MPI4o_DS5_VCLMB_1DM
# tests/mpiio/Refs/t27_MPI4o_DS1_VCLMB_1DM
# tests/mpiio/Refs/t27_MPI4o_DS2_VCLMB_1DM
# tests/mpiio/Refs/t28_MPI4o_DS1_VCLMB_1DM
# tests/mpiio/Refs/t28_MPI4o_DS2_VCLMB_1DM
# tests/v8/Input/t02.in
# tests/v8/Refs/t02.out
# src/56_recipspace/m_kpts.F90
# tests/v7/Refs/t88o_DS1_PH.bxsf
# src/28_numeric_noabirule/m_sort.F90
# src/45_geomoptim/m_lbfgs.F90
# src/45_geomoptim/pred_lbfgs.F90
# src/56_recipspace/m_kpts.F90
# src/67_common/m_epjdos.F90
# src/67_common/partial_dos_fractions_paw.F90
# src/72_response/m_strain.F90
# src/77_ddb/m_band2eps_dataset.F90
# src/78_effpot/_78_effpot
# src/78_effpot/abinit.src
# src/78_effpot/compute_anharmonics.F90
# src/78_effpot/effpot_xml.c
# src/78_effpot/init10.F90
# src/78_effpot/m_anharmonics_terms.F90
# src/78_effpot/m_effective_potential.F90
# src/78_effpot/m_effective_potential_file.F90
# src/78_effpot/m_harmonics_terms.F90
# src/78_effpot/m_monte_carlo.F90
# src/78_effpot/m_multibinit_dataset.F90
# src/78_effpot/m_polynomial_coeff.F90
# src/78_effpot/m_polynomial_term.F90
# src/78_eph/m_sigmaph.F90
# src/95_drive/mover_effpot.F90
# src/98_main/multibinit.F90
# tests/Psps_for_tests/C.psp8
# tests/mpiio/Input/t27.in
# tests/mpiio/Input/t28.in
# tests/mpiio/Refs/t26_MPI4o_DS5_DOS_AT0002
# tests/mpiio/Refs/t26_MPI4o_DS5_VCLMB_1DM
# tests/mpiio/Refs/t27_MPI4.out
# tests/mpiio/Refs/t27_MPI4o_DS2_DOS_AT0001
# tests/mpiio/Refs/t27_MPI4o_DS1_VCLMB_1DM
# tests/mpiio/Refs/t27_MPI4o_DS2_VCLMB_1DM
# tests/mpiio/Refs/t28_MPI4.out
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_TOTAL
# tests/mpiio/Refs/t28_MPI4o_DS1_VCLMB_1DM
# tests/mpiio/Refs/t28_MPI4o_DS2_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4o_DS2_VCLMB_1DM
# tests/paral/Input/t95.in
# tests/paral/Input/t96.in
# tests/paral/Input/t97.in
# tests/paral/Input/t98.in
# tests/paral/Input/t99.in
# tests/v7/Refs/system.xml
# tests/paral/Refs/t95_MPI1.out
# tests/paral/Refs/t95_MPI10.out
# tests/paral/Refs/t95_MPI2.out
# tests/paral/Refs/t95_MPI4.out
# tests/paral/Refs/t96_MPI1.out
# tests/paral/Refs/t96_MPI10.out
# tests/paral/Refs/t96_MPI2.out
# tests/paral/Refs/t96_MPI4.out
# tests/paral/Refs/t97_MPI1.out
# tests/paral/Refs/t97_MPI10.out
# tests/paral/Refs/t97_MPI2.out
# tests/paral/Refs/t97_MPI4.out
# tests/paral/Refs/t98_MPI1.out
# tests/paral/Refs/t98_MPI10.out
# tests/paral/Refs/t98_MPI2.out
# tests/paral/Refs/t98_MPI4.out
# tests/paral/Refs/t99_MPI4.out
# tests/paral/Refs/t99_MPI4o_DS2_Legendre_coefficients.dat
# tests/unitary/Refs/tfftmkl_03.stdout
# tests/unitary/Refs/tfftmkl_04.stdout
# tests/v7/Input/t120.in
# tests/v7/Input/t121.in
# tests/v7/Input/t122.in
# tests/v7/Input/t123.in
# tests/v7/Input/t124.in
# tests/v7/Refs/t04o_DOS_ATEXTRA0010
# tests/v7/Refs/t120.out
# tests/v7/Refs/t121.ddb.out
# tests/v7/Refs/t122.out
# tests/v7/Refs/t123.out
# tests/v7/Refs/t124.out
# tests/v7/Refs/t17o_DS1_DOS
# tests/v7/Refs/t17o_DS2_DOS_AT0001
# tests/v7/Refs/t88o_DS1_PH.bxsf
# tests/v7/Refs/t93.out_ep_SBK_ORG
# tests/v7/Refs/t94.out_ep_SBK_ORG
# tests/v8/Refs/.gitkeep
# tests/v8/Input/t01.in
# tests/v8/Input/t02.in
# tests/v8/README
# tests/v8/Refs/t01.out
# tests/v8/Refs/t01o_DS2_Legendre_coefficients.dat
# tests/v8/Refs/t02.out
# tests/v8/__init__.py
# scripts/post_processing/ElectronPhononCoupling/Examples/Calculations/01-LiF-dynamical/calc.in
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/data/inputs_for_tests/t41.py
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/data/inputs_for_tests/t42.py
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/data/outputs_of_tests/t41_EP.nc
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/data/outputs_of_tests/t42_REN.txt
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/data/outputs_of_tests/t42_EP.nc
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/util/__init__.py
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/util/ddb_converter.py
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/util/ncutil.py
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/util/reduce_kpoints.py
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/util/symmetrize_kpoints.py
# scripts/post_processing/ElectronPhononCoupling/Examples/1-1-dynamical-zpr.py
# scripts/post_processing/ElectronPhononCoupling/Examples/1-2-dynamical-tdr.py
# scripts/post_processing/ElectronPhononCoupling/Examples/1-3-dynamical-zpb.py
# scripts/post_processing/ElectronPhononCoupling/Examples/2-1-static-zpr.py
# scripts/post_processing/ElectronPhononCoupling/Examples/2-2-static-tdr.py
# scripts/post_processing/ElectronPhononCoupling/Examples/2-3-static-zpb.py
# scripts/post_processing/ElectronPhononCoupling/Examples/3-1-static-zpr.py
# scripts/post_processing/ElectronPhononCoupling/Examples/3-2-static-tdr.py
# scripts/post_processing/ElectronPhononCoupling/Examples/3-3-static-zpb.py
# scripts/post_processing/ElectronPhononCoupling/Examples/3-4-static-tdb.py
# scripts/post_processing/ElectronPhononCoupling/Examples/4-1-zp-spectral-function.py
# scripts/post_processing/ElectronPhononCoupling/Examples/4-2-tp-spectral-function.py
# scripts/post_processing/ElectronPhononCoupling/Examples/Calculations/02-LiF-static/calc.files
# scripts/post_processing/ElectronPhononCoupling/Examples/Calculations/02-LiF-static/calc.in
# scripts/post_processing/ElectronPhononCoupling/Examples/Calculations/Pseudos/03-Li.LDA.TM.pspnc
# scripts/post_processing/ElectronPhononCoupling/Examples/Calculations/Pseudos/09-F.LDA.TM.pspnc
# scripts/post_processing/ElectronPhononCoupling/Examples/README.rst
# scripts/post_processing/ElectronPhononCoupling/Examples/plot-td-spectral-function.py
# scripts/post_processing/ElectronPhononCoupling/Examples/plot-zp-spectral-function.py
# scripts/post_processing/ElectronPhononCoupling/Examples/Calculations/01-LiF-dynamical/calc.in
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/data/inputs_for_tests/t41.py
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/data/inputs_for_tests/t42.py
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/data/outputs_of_tests/t41_EP.nc
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/data/outputs_of_tests/t42_REN.txt
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/data/outputs_of_tests/t42_EP.nc
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/util/__init__.py
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/util/ddb_converter.py
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/util/ncutil.py
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/util/reduce_kpoints.py
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/util/symmetrize_kpoints.py
# scripts/post_processing/ElectronPhononCoupling/Examples/1-1-dynamical-zpr.py
# scripts/post_processing/ElectronPhononCoupling/Examples/1-2-dynamical-tdr.py
# scripts/post_processing/ElectronPhononCoupling/Examples/1-3-dynamical-zpb.py
# scripts/post_processing/ElectronPhononCoupling/Examples/2-1-static-zpr.py
# scripts/post_processing/ElectronPhononCoupling/Examples/2-2-static-tdr.py
# scripts/post_processing/ElectronPhononCoupling/Examples/2-3-static-zpb.py
# scripts/post_processing/ElectronPhononCoupling/Examples/3-1-static-zpr.py
# scripts/post_processing/ElectronPhononCoupling/Examples/3-2-static-tdr.py
# scripts/post_processing/ElectronPhononCoupling/Examples/3-3-static-zpb.py
# scripts/post_processing/ElectronPhononCoupling/Examples/3-4-static-tdb.py
# scripts/post_processing/ElectronPhononCoupling/Examples/4-1-zp-spectral-function.py
# scripts/post_processing/ElectronPhononCoupling/Examples/4-2-tp-spectral-function.py
# scripts/post_processing/ElectronPhononCoupling/Examples/Calculations/02-LiF-static/calc.files
# scripts/post_processing/ElectronPhononCoupling/Examples/Calculations/02-LiF-static/calc.in
# scripts/post_processing/ElectronPhononCoupling/Examples/Calculations/Pseudos/03-Li.LDA.TM.pspnc
# scripts/post_processing/ElectronPhononCoupling/Examples/Calculations/Pseudos/09-F.LDA.TM.pspnc
# scripts/post_processing/ElectronPhononCoupling/Examples/README.rst
# scripts/post_processing/ElectronPhononCoupling/Examples/plot-td-spectral-function.py
# scripts/post_processing/ElectronPhononCoupling/Examples/plot-zp-spectral-function.py
# developers/maintainers/fix-cpp-options.py
# src/59_ionetcdf/README
# src/59_ionetcdf/_59_ionetcdf_
# src/59_ionetcdf/abinit.src
# src/59_ionetcdf/m_crystal_io.F90
# src/59_ionetcdf/m_dfpt_io.F90
# src/59_ionetcdf/write_eig.F90
# src/59_ionetcdf/wrt_moldyn_netcdf.F90
# src/54_abiutil/m_dens.F90
# src/66_nonlocal/m_vkbr.F90
# tests/v6/Refs/t11o_DS2_BLZTRP.ns_energy
# tests/v6/Refs/t11o_DS2_BLZTRP.struct
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.def
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.intrans
# src/28_numeric_noabirule/m_sort.F90
# src/78_eph/m_gkk.F90
# tests/unitary/Refs/tfftmkl_03.stdout
# tests/unitary/Refs/tfftmkl_04.stdout
# tests/v7/Input/t89.in
# tests/v7/Refs/t89.out
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/core/gsrfile.py
# src/67_common/m_epjdos.F90
# src/67_common/partial_dos_fractions_paw.F90
# src/72_response/m_strain.F90
# src/77_ddb/m_band2eps_dataset.F90
# src/78_effpot/_78_effpot
# src/78_effpot/abinit.src
# src/78_effpot/compute_anharmonics.F90
# src/78_effpot/ddb_to_effective_potential.F90
# src/78_effpot/effpot_xml.c
# src/78_effpot/init10.F90
# src/78_effpot/m_anharmonics_terms.F90
# src/78_effpot/m_effective_potential.F90
# src/78_effpot/m_effective_potential_file.F90
# src/78_effpot/m_effpot_xml.F90
# src/78_effpot/m_harmonics_terms.F90
# src/78_effpot/m_monte_carlo.F90
# src/78_effpot/m_multibinit_dataset.F90
# src/78_eph/m_phpi.F90
# src/95_drive/mover_effpot.F90
# src/98_main/multibinit.F90
# tests/Psps_for_tests/C.psp8
# tests/mpiio/Input/t27.in
# tests/mpiio/Input/t28.in
# tests/mpiio/Refs/t26_MPI4o_DS5_DOS_AT0002
# tests/mpiio/Refs/t27_MPI4.out
# tests/mpiio/Refs/t27_MPI4o_DS2_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4.out
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4o_DS2_DOS_AT0001
# tests/paral/Input/t95.in
# tests/paral/Input/t96.in
# tests/paral/Input/t97.in
# tests/paral/Input/t98.in
# tests/paral/Refs/system.xml
# tests/paral/Refs/t95_MPI1.out
# tests/paral/Refs/t95_MPI10.out
# tests/paral/Refs/t95_MPI2.out
# tests/paral/Refs/t95_MPI4.out
# tests/paral/Refs/t96_MPI1.out
# tests/paral/Refs/t96_MPI10.out
# tests/paral/Refs/t96_MPI2.out
# tests/paral/Refs/t96_MPI4.out
# tests/paral/Refs/t97_MPI1.out
# tests/paral/Refs/t97_MPI10.out
# tests/paral/Refs/t97_MPI2.out
# tests/paral/Refs/t97_MPI4.out
# tests/paral/Refs/t98_MPI1.out
# tests/paral/Refs/t98_MPI10.out
# tests/paral/Refs/t98_MPI2.out
# tests/paral/Refs/t98_MPI4.out
# tests/v7/Input/t120.in
# tests/v7/Input/t121.in
# tests/v7/Input/t122.in
# tests/v7/Input/t123.in
# tests/v7/Input/t124.in
# tests/v7/Refs/system.xml
# tests/v7/Refs/t04o_DOS_ATEXTRA0010
# tests/v7/Refs/t120.out
# tests/v7/Refs/t121.ddb.out
# tests/v7/Refs/t122.out
# tests/v7/Refs/t123.out
# tests/v7/Refs/t124.out
# tests/v7/Refs/t17o_DS1_DOS
# tests/v7/Refs/t17o_DS2_DOS_AT0001
# tests/v8/Refs/.gitkeep
# tests/v8/README
# tests/v8/__init__.py
# scripts/post_processing/ElectronPhononCoupling/ElectronPhononCoupling/core/gsrfile.py
# src/28_numeric_noabirule/m_sort.F90
# src/54_abiutil/m_dens.F90
# src/66_nonlocal/m_vkbr.F90
# src/67_common/m_epjdos.F90
# src/67_common/partial_dos_fractions_paw.F90
# src/72_response/m_strain.F90
# src/77_ddb/m_band2eps_dataset.F90
# src/78_effpot/_78_effpot
# src/78_effpot/abinit.src
# src/78_effpot/compute_anharmonics.F90
# src/78_effpot/ddb_to_effective_potential.F90
# src/78_effpot/effpot_xml.c
# src/78_effpot/init10.F90
# src/78_effpot/m_anharmonics_terms.F90
# src/78_effpot/m_effective_potential.F90
# src/78_effpot/m_effective_potential_file.F90
# src/78_effpot/m_effpot_xml.F90
# src/78_effpot/m_harmonics_terms.F90
# src/78_effpot/m_monte_carlo.F90
# src/78_effpot/m_multibinit_dataset.F90
# src/78_eph/m_gkk.F90
# src/78_eph/m_phpi.F90
# src/95_drive/mover_effpot.F90
# src/98_main/multibinit.F90
# tests/Psps_for_tests/C.psp8
# tests/mpiio/Input/t27.in
# tests/mpiio/Input/t28.in
# tests/mpiio/Refs/t26_MPI4o_DS5_DOS_AT0002
# tests/mpiio/Refs/t27_MPI4.out
# tests/mpiio/Refs/t27_MPI4o_DS2_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4.out
# tests/mpiio/Refs/t28_MPI4o_DS1_DOS_AT0001
# tests/mpiio/Refs/t28_MPI4o_DS2_DOS_AT0001
# tests/paral/Input/t95.in
# tests/paral/Input/t96.in
# tests/paral/Input/t97.in
# tests/paral/Input/t98.in
# tests/paral/Refs/system.xml
# tests/paral/Refs/t95_MPI1.out
# tests/paral/Refs/t95_MPI10.out
# tests/paral/Refs/t95_MPI2.out
# tests/paral/Refs/t95_MPI4.out
# tests/paral/Refs/t96_MPI1.out
# tests/paral/Refs/t96_MPI10.out
# tests/paral/Refs/t96_MPI2.out
# tests/paral/Refs/t96_MPI4.out
# tests/paral/Refs/t97_MPI1.out
# tests/paral/Refs/t97_MPI10.out
# tests/paral/Refs/t97_MPI2.out
# tests/paral/Refs/t97_MPI4.out
# tests/paral/Refs/t98_MPI1.out
# tests/paral/Refs/t98_MPI10.out
# tests/paral/Refs/t98_MPI2.out
# tests/paral/Refs/t98_MPI4.out
# tests/unitary/Refs/tfftmkl_03.stdout
# tests/unitary/Refs/tfftmkl_04.stdout
# tests/v6/Refs/t11o_DS2_BLZTRP.ns_energy
# tests/v6/Refs/t11o_DS2_BLZTRP.struct
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.def
# tests/v6/Refs/t11o_DS2_ns_BLZTRP.intrans
# tests/v7/Input/t120.in
# tests/v7/Input/t121.in
# tests/v7/Input/t122.in
# tests/v7/Input/t123.in
# tests/v7/Input/t124.in
# tests/v7/Input/t89.in
# tests/v7/Refs/system.xml
# tests/v7/Refs/t04o_DOS_ATEXTRA0010
# tests/v7/Refs/t120.out
# tests/v7/Refs/t121.ddb.out
# tests/v7/Refs/t122.out
# ...
# doc/tutorial/generated_files/lesson_base4.html
# doc/tutorial/generated_files/lesson_basepar.html
# doc/tutorial/generated_files/lesson_bse.html
# doc/tutorial/generated_files/lesson_dftu.html
# doc/tutorial/generated_files/lesson_dmft.html
# doc/tutorial/generated_files/lesson_elastic.html
# doc/tutorial/generated_files/lesson_eph.html
# doc/tutorial/generated_files/lesson_ffield.html
# doc/tutorial/generated_files/lesson_fold2bloch.html
# doc/tutorial/generated_files/lesson_gw1.html
# doc/tutorial/generated_files/lesson_gw2.html
# doc/tutorial/generated_files/lesson_nlo.html
# doc/tutorial/generated_files/lesson_nuc.html
# doc/tutorial/generated_files/lesson_optic.html
# doc/tutorial/generated_files/lesson_paral_dfpt.html
# doc/tutorial/generated_files/lesson_paral_gspw.html
# doc/tutorial/generated_files/lesson_paral_gswvl.html
# doc/tutorial/generated_files/lesson_paral_images.html
# doc/tutorial/generated_files/lesson_paral_mbt.html
# doc/tutorial/generated_files/lesson_paral_moldyn.html
# doc/tutorial/generated_files/lesson_paw1.html
# doc/tutorial/generated_files/lesson_paw2.html
# doc/tutorial/generated_files/lesson_paw3.html
# doc/tutorial/generated_files/lesson_positron.html
# doc/tutorial/generated_files/lesson_rf1.html
# doc/tutorial/generated_files/lesson_rf2.html
# doc/tutorial/generated_files/lesson_source_code.html
# doc/tutorial/generated_files/lesson_spin.html
# doc/tutorial/generated_files/lesson_tddft.html
# doc/tutorial/generated_files/lesson_tdepes.html
# doc/tutorial/generated_files/lesson_ucalc_crpa.html
# doc/tutorial/generated_files/lesson_udet.html
# doc/tutorial/generated_files/lesson_wannier90.html
# doc/tutorial/generated_files/lesson_welcome.html
# doc/tutorial/origin_files/README.md
# doc/tutorial/origin_files/lesson_analysis_tools.yml
# doc/tutorial/origin_files/lesson_base1.yml
# doc/tutorial/origin_files/lesson_base2.yml
# doc/tutorial/origin_files/lesson_base3.yml
# doc/tutorial/origin_files/lesson_base4.yml
# doc/tutorial/origin_files/lesson_basepar.yml
# doc/tutorial/origin_files/lesson_bse.yml
# doc/tutorial/origin_files/lesson_dftu.yml
# doc/tutorial/origin_files/lesson_dmft.yml
# doc/tutorial/origin_files/lesson_dmft.yml_ORG
# doc/tutorial/origin_files/lesson_elastic.yml
# doc/tutorial/origin_files/lesson_eph.yml
# doc/tutorial/origin_files/lesson_ffield.yml
# doc/tutorial/origin_files/lesson_fold2bloch.yml
# doc/tutorial/origin_files/lesson_gw1.yml
# doc/tutorial/origin_files/lesson_gw2.yml
# doc/tutorial/origin_files/lesson_nlo.yml
# doc/tutorial/origin_files/lesson_nuc.yml
# doc/tutorial/origin_files/lesson_optic.yml
# doc/tutorial/origin_files/lesson_paral_dfpt.yml
# doc/tutorial/origin_files/lesson_paral_gspw.yml
# doc/tutorial/origin_files/lesson_paral_gswvl.yml
# doc/tutorial/origin_files/lesson_paral_images.yml
# doc/tutorial/origin_files/lesson_paral_mbt.yml
# doc/tutorial/origin_files/lesson_paral_moldyn.yml
# doc/tutorial/origin_files/lesson_paw1.yml
# doc/tutorial/origin_files/lesson_paw2.yml
# doc/tutorial/origin_files/lesson_paw3.yml
# doc/tutorial/origin_files/lesson_positron.yml
# doc/tutorial/origin_files/lesson_rf1.yml
# doc/tutorial/origin_files/lesson_rf2.yml
# doc/tutorial/origin_files/lesson_source_code.yml
# doc/tutorial/origin_files/lesson_spin.yml
# doc/tutorial/origin_files/lesson_tddft.yml
# doc/tutorial/origin_files/lesson_tdepes.yml
# doc/tutorial/origin_files/lesson_ucalc_crpa.yml
# doc/tutorial/origin_files/lesson_udet.yml
# doc/tutorial/origin_files/lesson_wannier90.yml
# doc/tutorial/origin_files/lesson_welcome.yml
# doc/tutorial/origin_files/lessons.yml
# doc/users/generated_files/all_files.html
# doc/users/generated_files/help_abinit.html
# doc/users/generated_files/help_aim.html
# doc/users/generated_files/help_anaddb.html
# doc/users/generated_files/help_cut3d.html
# doc/users/generated_files/help_features.html
# doc/users/generated_files/help_fold2bloch.html
# doc/users/generated_files/help_mrgddb.html
# doc/users/generated_files/help_mrgscr.html
# doc/users/generated_files/help_new_user.html
# doc/users/generated_files/help_optic.html
# doc/users/generated_files/help_respfn.html
# doc/users/origin_files/help_abinit.yml
# doc/users/origin_files/help_aim.yml
# doc/users/origin_files/help_anaddb.yml
# doc/users/origin_files/help_cut3d.yml
# doc/users/origin_files/help_features.yml
# doc/users/origin_files/help_fold2bloch.yml
# doc/users/origin_files/help_mrgddb.yml
# doc/users/origin_files/help_mrgscr.yml
# doc/users/origin_files/help_new_user.yml
# doc/users/origin_files/help_optic.yml
# doc/users/origin_files/help_respfn.yml
# doc/users/origin_files/helps.yml
# src/72_response/m_ddb_hdr.F90
# src/77_ddb/ddb_interpolate.F90
# tests/Psps_for_tests/Si.12el.LDA-PW-paw.abinit
# tests/Psps_for_tests/Si.12el.LDA-PW-paw.abinit.corewf
# tests/Psps_for_tests/Si.LDA-PW-paw.abinit
# tests/Psps_for_tests/Si.LDA-PW-paw.abinit.corewf
# tests/Psps_for_tests/au.paw
# tests/Psps_for_tests/ba.hpc.paw.xml
# tests/Psps_for_tests/o.hpc.paw
# tests/Psps_for_tests/o.hpc.paw.xml
# tests/Psps_for_tests/ti.hpc.paw
# tests/Psps_for_tests/ti.hpc.paw.xml
# tests/Psps_for_tests/u.hpc.paw
# tests/hpc/Input/t01.in
# tests/hpc/Input/t02.in
# tests/hpc/Input/t03.in
# tests/hpc/Input/t04.in
# tests/hpc/Input/t05.in
# tests/hpc/Input/t06.in
# tests/hpc/README
# tests/hpc/Refs/t01.out.128procs
# tests/hpc/Refs/t01.out.32procs
# tests/hpc/Refs/t01.out.64procs-1
# tests/hpc/Refs/t01.out.64procs-2
# tests/hpc/Refs/t02.out.autoparal.128procs
# tests/hpc/Refs/t02.out.autoparal.32procs
# tests/hpc/Refs/t02.out.autoparal.64procs
# tests/hpc/Refs/t02.out.manual.128procs
# tests/hpc/Refs/t02.out.manual.32procs
# tests/hpc/Refs/t02.out.manual.64procs-1
# tests/hpc/Refs/t02.out.manual.64procs-2
# tests/hpc/Refs/t03.out.128procs
# tests/hpc/Refs/t03.out.32procs
# tests/hpc/Refs/t03.out.64procs
# tests/hpc/Refs/t04.out.autoparal.128procs
# tests/hpc/Refs/t04.out.autoparal.32procs
# tests/hpc/Refs/t04.out.autoparal.64procs
# tests/hpc/Refs/t04.out.manual.128procs
# tests/hpc/Refs/t04.out.manual.32procs
# tests/hpc/Refs/t04.out.manual.64procs-1
# tests/hpc/Refs/t04.out.manual.64procs-2
# tests/hpc/Refs/t05.out.curie.1024procs
# tests/hpc/Refs/t05.out.curie.128procs
# tests/hpc/Refs/t05.out.curie.256procs
# tests/hpc/Refs/t05.out.curie.512procs
# tests/hpc/Refs/t06.out.curie.1024procs
# tests/hpc/Refs/t06.out.curie.128procs
# tests/hpc/Refs/t06.out.curie.2048procs
# tests/hpc/Refs/t06.out.curie.256procs
# tests/hpc/Refs/t06.out.curie.512procs
# tests/hpc/__init__.py
# tests/paral/Input/t101.in
# tests/v8/Input/t13_HIST
# tests/v8/Input/t13_ddb.in
# tests/paral/Input/t102.in
# tests/v8/Input/t14_coeffs.xml
# tests/v8/Refs/t13_sys.xml
# tests/paral/Refs/t98_MPI4_model.xml
# tests/paral/Refs/t101_MPI1.out
# tests/paral/Refs/t101_MPI10.out
# tests/v8/Refs/t13_coeffs.xml
# tests/paral/Refs/t101_MPI2.out
# tests/paral/Refs/t101_MPI4.out
# tests/paral/Refs/t102_MPI1.out
# tests/paral/Refs/t102_MPI10.out
# tests/v8/Refs/t14_model.xml
# tests/paral/Refs/t102_MPI2.out
# tests/paral/Refs/t102_MPI4.out
# tests/tutorespfn/Input/tdepes_1.files
# tests/tutorespfn/Input/tdepes_1.in
# tests/tutorespfn/Input/tdepes_2.files
# tests/tutorespfn/Input/tdepes_2.in
# tests/tutorespfn/Input/tdepes_3.files
# tests/tutorespfn/Input/tdepes_3.in
# tests/tutorespfn/Input/tdepes_3bis.files
# tests/tutorespfn/Input/tdepes_4.files
# tests/tutorespfn/Input/tdepes_4.in
# tests/tutorespfn/Refs/tdepes_1.out
# tests/tutorespfn/Refs/tdepes_2.out
# tests/tutorespfn/Refs/tdepes_3.out
# tests/tutorespfn/Refs/tdepes_4.out
# tests/tutorial/Input/tdftu_1.in
# tests/tutorial/Input/tdftu_2.in
# tests/tutorial/Input/tdftu_3.in
# tests/tutorial/Input/tdftu_4.in
# tests/tutorial/Input/tdftu_x.files
# tests/tutorial/Input/tfold2bloch_1.files
# tests/tutorial/Input/tpositron_1.in
# tests/tutorial/Input/tpositron_12el_x.files
# tests/tutorial/Input/tpositron_2.in
# tests/tutorial/Input/tpositron_3.in
# tests/tutorial/Input/tpositron_4.in
# tests/tutorial/Input/tpositron_5.in
# tests/tutorial/Input/tpositron_6.in
# tests/tutorial/Input/tpositron_7.in
# tests/tutorial/Input/tpositron_x.files
# tests/tutorial/Refs/tdftu_1.out
# tests/tutorial/Refs/tdftu_2.out
# tests/tutorial/Refs/tdftu_3.out
# tests/tutorial/Refs/tdftu_4.out
# tests/tutorial/Refs/tpositron_1.out
# tests/tutorial/Refs/tpositron_2.out
# tests/tutorial/Refs/tpositron_3.out
# tests/tutorial/Refs/tpositron_4.out
# tests/tutorial/Refs/tpositron_5.out
# tests/tutorial/Refs/tpositron_6.out
# tests/tutorial/Refs/tpositron_7.out
# tests/v8/Input/t13.in
# tests/v8/Input/t14.in
# tests/v8/Input/t51.ddb.in
# tests/v8/Input/t51.in
# tests/v8/Refs/t09_model.xml
# tests/v8/Refs/t13.out
# tests/v8/Refs/t14.out
# tests/v8/Refs/t51.out_DDB
# doc/formabinit.css
# doc/tutorial/documents/lesson_welcome/tutorial_flowchart_v6.png
# scripts/post_processing/nonlop_dfpt_test/dfpt_test.py
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_ATM/data
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST1_ATM/inputDFk1.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST1_ATM/inputDFk2.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST1_ATM/inputDFk3.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST1_ATM/inputDFk4.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST1_ATM/inputDFk5.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST1_ATM/inputDFk6.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_STR/data
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST1_K/inputDFk1.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST1_K/inputDFk2.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST1_K/inputDFk3.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST1_STR/inputDFk1.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST1_STR/inputDFk2.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST1_STR/inputDFk3.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST1_STR/inputDFk4.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST1_STR/inputDFk5.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST1_STR/inputDFk6.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST2_K/inputDFk1.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST2_K/inputDFk2.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST2_K/inputDFk3.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST2_STR/inputDFk1.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST2_STR/inputDFk2.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST2_STR/inputDFk3.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST2_STR/inputDFk4.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST2_STR/inputDFk5.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST2_STR/inputDFk6.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST3_ATM/inputDFk1.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST3_ATM/inputDFk2.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST3_ATM/inputDFk3.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST3_ATM/inputDFk4.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST3_ATM/inputDFk5.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST3_ATM/inputDFk6.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST3_K/inputDFk1.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST3_K/inputDFk2.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST3_K/inputDFk3.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST3_STR/inputDFk1.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST3_STR/inputDFk2.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST3_STR/inputDFk3.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST3_STR/inputDFk4.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST3_STR/inputDFk5.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST3_STR/inputDFk6.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_ATM/inputDFk1.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_ATM/inputDFk2.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_ATM/inputDFk3.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_ATM/inputDFk4.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_ATM/inputDFk5.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_ATM/inputDFk6.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_K/inputDFk1.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_K/inputDFk2.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_K/inputDFk3.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_STR/inputDFk1.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_STR/inputDFk2.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_STR/inputDFk3.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_STR/inputDFk4.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_STR/inputDFk5.in
# scripts/post_processing/nonlop_dfpt_test/input_template/TEST4_STR/inputDFk6.in
# scripts/post_processing/nonlop_dfpt_test/input_template/filesdf
# scripts/post_processing/nonlop_dfpt_test/pseudo/Ca.LDA_PW-JTH.xml
# scripts/post_processing/nonlop_dfpt_test/pseudo/O.LDA_PW-JTH.xml
# src/41_geometry/m_supercell.F90
# src/66_nonlocal/nonlop_test.F90
# src/66_wfs/fock2ACE.F90
# src/66_wfs/fock_ACE_getghc.F90
# tests/v8/Input/t61.in
# tests/v8/Input/t62.in
# tests/v8/Input/t63.in
# tests/v8/Input/t64.in
# tests/v8/Input/t65.in
# tests/v8/Refs/t61.out
# tests/v8/Refs/t62.stdout
# tests/v8/Refs/t63.stdout
# tests/v8/Refs/t64.out
# tests/v8/Refs/t64.out_DDB
# tests/v8/Refs/t65.out
# doc/install_notes/install_v8.6.html
# doc/install_notes/install_v8.7.html
# doc/release_notes/release_notes_v8.6.html
# doc/release_notes/release_notes_v8.7.html
# src/64_psp/psp9cc.F90
# src/64_psp/psp_dump_outputs.F90
# src/71_bse/m_bseinterp.F90
# tests/Psps_for_tests/13_Al_atom.psml
# tests/Psps_for_tests/13_Al_oncv.psml
# tests/Psps_for_tests/13_Al_psml.psp8
# tests/Psps_for_tests/14_Si_atom.psml
# tests/Psps_for_tests/14_Si_oncv.psml
# tests/Psps_for_tests/14_Si_psml.psp8
# tests/Psps_for_tests/26_Fe_atom.psml
# tests/Psps_for_tests/26_Fe_oncv.psml
# tests/Psps_for_tests/26_Fe_psml.psp8
# tests/Psps_for_tests/79_Au_atom.psml
# tests/Psps_for_tests/79_Au_oncv.psml
# tests/Psps_for_tests/C.xml
# tests/v7/Input/H.psp8
# tests/Psps_for_tests/H4.GGA_X_PBE+GGA_C_PBE-paw.xml
# tests/v7/Input/N.xml
# tests/libxc/Input/t67.in
# tests/libxc/Input/t68.in
# tests/libxc/Input/t69.in
# tests/libxc/Input/t70.in
# tests/libxc/Input/t71.in
# tests/libxc/Refs/t67.out
# tests/libxc/Refs/t68.out
# tests/libxc/Refs/t69.out
# tests/libxc/Refs/t70.out
# tests/libxc/Refs/t71.out
# tests/psml/Input/t03.in
# tests/psml/Input/t04.in
# tests/psml/Input/t05.in
# tests/psml/Input/t06.in
# tests/psml/Input/t07.in
# tests/psml/Input/t08.in
# tests/psml/Input/t09.in
# tests/psml/Input/t10.in
# tests/psml/Input/t11.in
# tests/psml/Input/t12.in
# tests/psml/Input/t13.in
# tests/psml/Input/t14.in
# tests/psml/Refs/t03.out
# tests/psml/Refs/t04.out
# tests/psml/Refs/t05.out
# tests/psml/Refs/t06.out
# tests/psml/Refs/t07.out
# tests/psml/Refs/t08.out
# tests/psml/Refs/t09.out
# tests/psml/Refs/t10.out
# tests/psml/Refs/t11.out
# tests/psml/Refs/t12.out
# tests/psml/Refs/t13.out
# tests/psml/Refs/t14.out
# tests/v7/Input/C.psp8
# doc/install_notes/install_v8.6.html
# doc/install_notes/install_v8.7.html
# doc/release_notes/release_notes_v8.6.html
# doc/release_notes/release_notes_v8.7.html
# tests/libxc/Input/t70.in
# tests/libxc/Input/t71.in
# tests/libxc/Refs/t70.out
# tests/libxc/Refs/t71.out
# src/80_tdep/m_tdep_abitypes.F90
# src/80_tdep/m_tdep_latt.F90
# src/80_tdep/m_tdep_phdos.F90
# src/80_tdep/m_tdep_phij.F90
# src/80_tdep/m_tdep_psij.F90
# src/80_tdep/m_tdep_qpt.F90
# src/80_tdep/m_tdep_readwrite.F90
# src/80_tdep/m_tdep_shell.F90
# src/80_tdep/m_tdep_sym.F90
# src/80_tdep/m_tdep_utils.F90
# src/80_tdep/abinit.src
# src/80_tdep/m_tdep_abitypes.F90
# src/80_tdep/m_tdep_latt.F90
# src/80_tdep/m_tdep_phdos.F90
# src/80_tdep/m_tdep_phij.F90
# src/80_tdep/m_tdep_qpt.F90
# src/80_tdep/m_tdep_readwrite.F90
# src/80_tdep/m_tdep_shell.F90
# src/80_tdep/m_tdep_sym.F90
# src/80_tdep/m_tdep_utils.F90
# src/98_main/tdep.F90
# src/56_xc/rhotoxc.F90
# tests/v7/Input/t67.in
# tests/v7/Refs/t67.out
# tests/v7/Input/t67.in
# tests/v7/Refs/t67.out

# %%
commit_data = bugs_data.get_commit_count()

# %%
sg_data_list = []
for key, value in sg_data.items():
    temp = [key,value]
    sg_data_list.append(temp)
cg_data_list = []
for key, value in cg_data.items():
    temp = [key,value]
    cg_data_list.append(temp)

# %%
buggy_commit_data_df = pd.DataFrame(buggy_commit_data, columns = ['committer', 'count'])
commit_data_df = pd.DataFrame(commit_data, columns = ['committer', 'count'])
sg_data_df = pd.DataFrame(sg_data_list, columns = ['committer', 'count'])
cg_data_df = pd.DataFrame(cg_data_list, columns = ['committer', 'count'])

# %%
committer_count = []
for i in range(bugs_data.commit.shape[0]):
    commit_id = bugs_data.commit.loc[i,'commit_number']
    user = bugs_data.repo.get(commit_id).committer
    committer_count.append([user.name, commit_id, 1])
committer_count_df = pd.DataFrame(committer_count, columns = ['committer', 'commit_id', 'ob'])
committer_count_df = committer_count_df.drop_duplicates()
df = committer_count_df.groupby( ['committer']).count()
commit_count = []
for key,value in df.iterrows():
    user = key
    count = value.values.tolist()[0]
    commit_count.append([user,count])

# %%
df = []
for i in range(cg_data_df.shape[0]):
    print("+++++++++++")
    buggy_commit_count = buggy_commit_data_df[buggy_commit_data_df['committer'] == cg_data_df.loc[i,'committer']]['count']
    print(buggy_commit_count)
    if len(buggy_commit_count) == 0:
        continue
    commit_count = commit_data_df[commit_data_df['committer'] == cg_data_df.loc[i,'committer']]['count']
    print(commit_count)
    if len(commit_count) == 0:
        continue
    node_degree = cg_data_df[cg_data_df['committer'] == cg_data_df.loc[i,'committer']]['count']
    df.append([buggy_commit_count.values[0]/commit_count.values[0],node_degree.values[0]])

# %%
df = pd.DataFrame(df, columns = ['per','degree'])

# %%
degree_d = np.array(df['degree'].values.tolist())

# %%
first = np.int32(np.percentile(degree_d,99.9))
second = np.int32(np.percentile(degree_d,99))
third = np.int32(np.percentile(degree_d,80))
forth = np.int32(np.percentile(degree_d,50))

# %%
first_l = []
second_l = []
third_l = []
forth_l = []
for i in range(df.shape[0]):
    if df.loc[i,'degree'] < forth:
        forth_l.append(df.loc[i,'per'])
        print("Inside forth",df.loc[i,'degree'],forth)
    elif df.loc[i,'degree'] < third:
        third_l.append(df.loc[i,'per'])
        print("Inside third",df.loc[i,'degree'],third)
    elif df.loc[i,'degree'] < second:
        second_l.append(df.loc[i,'per'])
        print("Inside second",df.loc[i,'degree'],second)
    else:
        first_l.append(df.loc[i,'per'])
        print("Inside first",df.loc[i,'degree'],first)

# %%
print(round(np.median(first_l),2),round(np.median(second_l),2),round(np.median(third_l),2),round(np.median(forth_l),2))

# %%
np.max(degree_d)

# %%
print(len(forth_l))

# %%
b<a

# %%
0.42 0.41 0.59 0.98
0.44 0.87 0.97 0.95
0.53 0.56 nan 0.94
0.41 0.55 0.76 0.91

# %%
len(cg.commits)

# %%
bugs_data.commit

# %%
cg_data

# %%
cg_data

# %%
cg_data

# %%
buggy_commit_data_df['committer'] == cg_data_df.loc[0,'committer']

# %%
df_b = bugs_data.commit

# %%
df_b[df_b['isBuggy'] == 1].shape

# %%
df_b.shape

# %%
x_sum = 0
for x in buggy_commit_data:
    x_sum += x[1]

# %%
buggy_commit_data

# %%
os.path.isfile('/Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/rspec-rails/.git/objects/pack')
