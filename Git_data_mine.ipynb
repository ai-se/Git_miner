# %%
import git_access,api_access,git2repo
import json
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import networkx as nx
import re
import git2data
import social_interaction

import threading
from threading import Barrier
from multiprocessing import Queue

# %%
project_list = pd.read_csv('project_list.csv')
for i in range(project_list.shape[0]):
    access_token = project_list.loc[i,'access_token']
    repo_owner = project_list.loc[i,'repo_owner']
    source_type = project_list.loc[i,'source_type']
    git_url = project_list.loc[i,'git_url']
    api_base_url = project_list.loc[i,'api_base_url']
    repo_name = project_list.loc[i,'repo_name'] 
    git_data = git2data.git2data(access_token,repo_owner,source_type,git_url,api_base_url,repo_name)
    git_data.create_data()
# Out:
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=1&per_page=100
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=2&per_page=100
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=3&per_page=100
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=4&per_page=100
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=5&per_page=100
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=6&per_page=100
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=7&per_page=100
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=8&per_page=100
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=9&per_page=100
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=10&per_page=100
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=11&per_page=100
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=12&per_page=100
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=13&per_page=100
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=14&per_page=100
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=15&per_page=100
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=16&per_page=100
# http://api.github.com/repos/apache/couchdb/issues?state=all&page=17&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=1&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=2&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=3&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=4&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=5&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=6&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=7&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=8&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=9&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=10&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=11&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=12&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=13&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=14&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=15&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=16&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=17&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=18&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=19&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=20&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=21&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=22&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=23&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=24&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=25&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=26&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=27&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=28&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=29&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=30&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=31&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=32&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=33&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=34&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=35&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=36&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=37&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=38&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=39&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=40&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=41&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=42&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=43&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=44&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=45&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=46&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=47&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=48&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=49&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=50&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=51&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=52&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=53&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=54&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=55&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=56&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=57&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=58&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=59&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=60&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=61&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=62&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=63&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=64&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=65&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=66&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=67&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=68&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=69&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=70&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=71&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=72&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=73&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=74&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=75&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=76&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=77&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=78&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=79&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=80&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=81&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=82&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=83&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=84&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=85&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=86&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=87&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=88&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=89&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=90&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=91&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=92&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=93&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=94&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=95&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=96&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=97&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=98&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=99&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=100&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=101&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=102&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=103&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=104&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=105&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=106&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=107&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=108&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=109&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=110&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=111&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/events?page=112&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=1&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=2&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=3&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=4&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=5&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=6&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=7&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=8&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=9&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=10&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=11&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=12&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=13&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=14&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=15&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=16&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=17&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=18&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=19&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=20&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=21&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=22&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=23&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=24&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=25&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=26&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=27&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=28&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=29&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=30&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=31&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=32&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=33&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=34&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=35&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=36&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=37&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=38&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=39&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=40&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=41&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=42&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=43&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=44&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=45&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=46&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=47&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=48&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=49&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=50&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=51&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=52&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=53&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=54&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=55&per_page=100
# http://api.github.com/repos/apache/couchdb/issues/comments?page=56&per_page=100
# Inside get_commit_data in git2data
# 0 10
# <class 'method'>
# cloning branch 1.3.x
# <class 'method'>
# cloning branch 1.4.x
# <class 'method'>
# cloning branch 1.5.x
# <class 'method'>
# cloning branch 1.6.x
# <class 'method'>
# cloning branch 1.7.x<class 'method'>
# cloning branch 1.x.x
# <class 'method'>
#
# cloning branch 1278-add-clustered-db-info
# <class 'method'>
# cloning branch 1296-force-smp
# <class 'method'>
# cloning branch 1338-node-flavors
# <class 'method'>
# cloning branch 1956-attachment-handling
# 2817
# 3225
# 3625
# 4054
# 4180
# 4176
# 11215
# 11127
# 11133
# 3888
# 10 20
# <class 'method'>
# cloning branch 1994-merge-rcouch
# <class 'method'>
# cloning branch 1994-merge-rcouch-multi-repo
# <class 'method'>
# cloning branch 2.0.x
# <class 'method'><class 'method'>
# cloning branch 2.1.x
#
# cloning branch 2.1.x-new
# <class 'method'>
# cloning branch 2.2.x
# <class 'method'>
# cloning branch 553-js-restart
# <class 'method'>
# cloning branch 631-up-process-pool-timeout
# <class 'method'>
# cloning branch 656-remove-oauth
# <class 'method'>
# cloning branch 674-log-monitors-for-compaction-daemon-test
# 3879
# 3868
# 6240
# 10888
# 10895
# 11208
# 10596
# 10651
# 10667
# 10694
# 20 30
# <class 'method'>
# cloning branch 680-fix-couchdb-1283-test
# <class 'method'>
# cloning branch 745-fix-zombie-multipart-writers
# <class 'method'>
# cloning branch 823-bypass-authn-_up
# <class 'method'>
# cloning branch 8409-view-lru
# <class 'method'>
# cloning branch add-chakra-support
# <class 'method'>
# <class 'method'>
# cloning branch allow-database-disabling
# <class 'method'>
# cloning branch bcrypt
# cloning branch add-set-mqd-off-heap
# <class 'method'>
# cloning branch build-docs-outside-release
# <class 'method'>
# cloning branch compactor-id-tree-optimization
# 10717
# 10982
# 10857
# 10480
# 11213
# 11150
# 10768
# 11012
# 10958
# 10796
# 30 40
# <class 'method'>
# cloning branch compactor-optimize-emsort
# <class 'method'>
# cloning branch compactor-rewrite<class 'method'>
# cloning branch contributing-md-update
# <class 'method'>
# cloning branch couch-server-ets-lru
#
# <class 'method'>
# cloning branch couch-server-improvements
# <class 'method'>
# cloning branch couch-server-improvements-with-deadline
# <class 'method'><class 'method'>
# cloning branch COUCHDB-3226-downgrade-clustered-purge
#
# cloning branch COUCHDB-3100
# <class 'method'>
# cloning branch COUCHDB-3226-pre-clustered-purge
# <class 'method'>
# cloning branch COUCHDB-3287-pluggable-storage-engines-rebase
# 10818
# 10782
# 10648
# 11292
# 11282
# 11283
# 10477
# 11225
# 11286
# 10971
# 40 50
# <class 'method'>
# cloning branch COUCHDB-3288-mixed-cluster-upgrade
# <class 'method'>
# cloning branch COUCHDB-3326-clustered-purge-davisp-refactor
# <class 'method'>
# cloning branch COUCHDB-3326-clustered-purge-pr1-misc-cleanup
# <class 'method'>
# cloning branch COUCHDB-3326-clustered-purge-pr2-simplify-mem3-rep
# <class 'method'>
# cloning branch COUCHDB-3326-clustered-purge-pr3-refactor-pse-tests
# <class 'method'>
# cloning branch COUCHDB-3326-clustered-purge-pr4-on-compact-plugin
# <class 'method'>
# cloning branch COUCHDB-3326-clustered-purge-pr5-implementation
# <class 'method'>
# cloning branch COUCHDB-3377
# <class 'method'>
# cloning branch debug-chttpd-test-error
# <class 'method'>
# cloning branch developer-preview-2.0
# 10841
# 11205
# 11238
# 11238
# 11245
# 11247
# 11258
# 10515
# 10488
# 5749
# 50 60
# <class 'method'>
# cloning branch<class 'method'> dns-cluster-discovery
#
# cloning branch documentation-updates
# <class 'method'>
# cloning branch elixir-suite
# <class 'method'>
# cloning branch elixir-suite-davisp
# <class 'method'>
# <class 'method'>cloning branch experiment-transient-stats
#
# cloning branch fauxton
# <class 'method'>
# cloning branch feat-jiffy-dedupe
# <class 'method'>
# cloning branch feat/conf
# <class 'method'>
# cloning branch <class 'method'>feat/max-attachment-count
#
# cloning branch feat/thing
# 11214
# 10933
# 11333
# 10946
# 10975
# 2832
# 10900
# 11296
# 10991
# 11287
# 60 70
# <class 'method'>
# cloning branch feature/user-partitioned-databases
# <class 'method'>
# cloning branch finalize-reduce-optimization
# <class 'method'><class 'method'>
#
# cloning branch fix-builtin-sum
# cloning branch fix-bt-engine-compaction-resumption
# <class 'method'>
# cloning branch fix-couch-server-race-condition
# <class 'method'>
# cloning branch fix-ddoc-cache-upgrade
# <class 'method'>
# cloning branch fix-erlang-21-eunit-failures
# <class 'method'><class 'method'>
#
# cloning branch cloning branch<class 'method'>
# cloning branch fix-pse-fold-local-docs
#  fix-eunit-partitions
# fix-log-resets-during-js-tests
# 11314
# 11137
# 11111
# 11261
# 11279
# 10870
# 11161
# 11314
# 10820
# 10994
# 70 80
# <class 'method'>
# <class 'method'>cloning branch fix/548/view-index-monitor
#
# cloning branch fix/745/davisp
# <class 'method'>
# cloning branch hard-fail-cookie-mode
# <class 'method'>
# cloning branch import-couchdb-setup
# <class 'method'>
# cloning branch increase-default-rounds
# <class 'method'>
# cloning branch issue-822-queries-test
# <class 'method'>
# cloning branch jan-test
# <class 'method'>
# cloning branch kxepal-2752-validate-host
# <class 'method'>
# cloning branch log-file-by-default
# <class 'method'>
# cloning branch master
# 10600
# 10976
# 11288
# 10664
# 10910
# 10995
# 6298
# 4162
# 6168
# 11299
# 80 90
# <class 'method'>
# cloning branch mem3-seedlist
# <class 'method'>
# cloning branch michellephung-patch-1
# <class 'method'>
# cloning branch one-ex-ex
# <class 'method'>
# cloning branch optimize-ddoc-cache
# <class 'method'><class 'method'>
# cloning branch optimize-rexi
#
# cloning branch random-seed-chttpd-pids
# <class 'method'>
# cloning branch rebar3
# <class 'method'>
# cloning branch record_last_compaction
# <class 'method'>
# cloning branch reduce_default_max_dbs_open
# <class 'method'>
# cloning branch reformat-mango-explain
# 11159
# 11129
# 4175
# 10743
# 10759
# 10832
# 6233
# 11186
# 10782
# 11314
# 90 100
# <class 'method'>
# cloning branch revert-1143-issue-820-remove-queries-for_all_docs
# <class 'method'><class 'method'>
#
# cloning branch revert-dedup-detection
# cloning branch revert-1367-COUCHDB-3326-clustered-purge-pr2-simplify-mem3-rep
# <class 'method'>
# cloning branch run-mango-tests-with-check
# <class 'method'>
# cloning branch shard-local-query
# <class 'method'>
# cloning branch <class 'method'>
# cloning branch test-branch
# start-app-order
# <class 'method'>
# cloning branch test-cet_recompact_updates
# <class 'method'>
# cloning branch test-events
# <class 'method'>
# cloning branch test-looking-glass
# 10975
# 11239
# 10901
# 10830
# 11132
# 10566
# 10492
# 11127
# 10852
# 10995
# 100 110
# <class 'method'>
# cloning branch tmp-fix-compaction-daemon-test-with-pse
# <class 'method'>
# cloning branch trigger-chttpd-error
# <class 'method'>
# cloning branch windsor-merge
# <class 'method'>
# cloning branch wip-pse-test-suite-rewrite
# 10990
# 10566
# 5520
# 11127
# Inside get_commit_data in git2data
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_1296-force-smp
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_1.x.x
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_1338-node-flavors
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_1.4.x
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_1956-attachment-handling
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_1.5.x
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_1.3.x
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_1278-add-clustered-db-info
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_1.6.x
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_1.7.x
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_674-log-monitors-for-compaction-daemon-test
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_656-remove-oauth
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_553-js-restart
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_2.1.x-new
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_631-up-process-pool-timeout
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_2.0.x
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_2.1.x
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_1994-merge-rcouch
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_2.2.x
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_1994-merge-rcouch-multi-repo
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_745-fix-zombie-multipart-writers
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_680-fix-couchdb-1283-test
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_allow-database-disabling
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_add-set-mqd-off-heap
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_bcrypt
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_compactor-id-tree-optimization
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_add-chakra-support
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_build-docs-outside-release
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_8409-view-lru
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_823-bypass-authn-_up
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_contributing-md-update
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_couch-server-improvements-with-deadline
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_COUCHDB-3226-downgrade-clustered-purge
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_COUCHDB-3287-pluggable-storage-engines-rebase
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_compactor-optimize-emsort
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_COUCHDB-3100
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_compactor-rewrite
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_COUCHDB-3226-pre-clustered-purge
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_couch-server-ets-lru
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_couch-server-improvements
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_COUCHDB-3326-clustered-purge-pr5-implementation
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_COUCHDB-3326-clustered-purge-davisp-refactor
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_COUCHDB-3326-clustered-purge-pr1-misc-cleanup
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_COUCHDB-3326-clustered-purge-pr4-on-compact-plugin
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_COUCHDB-3326-clustered-purge-pr2-simplify-mem3-rep
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_COUCHDB-3288-mixed-cluster-upgrade
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_COUCHDB-3326-clustered-purge-pr3-refactor-pse-tests
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_COUCHDB-3377
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_developer-preview-2.0
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_debug-chttpd-test-error
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_feat/conf
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_experiment-transient-stats
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_elixir-suite-davisp
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_feat/max-attachment-count
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_fauxton
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_dns-cluster-discovery
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_documentation-updates
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_elixir-suite
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_feat/thing
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_feat-jiffy-dedupe
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_finalize-reduce-optimization
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_fix-log-resets-during-js-tests
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_fix-ddoc-cache-upgrade
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_fix-builtin-sum
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_feature/user-partitioned-databases
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_fix-pse-fold-local-docs
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_fix-couch-server-race-condition
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_fix-bt-engine-compaction-resumption
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_fix-erlang-21-eunit-failures
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_fix-eunit-partitions
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_fix/548/view-index-monitor
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_log-file-by-default
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_import-couchdb-setup
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_fix/745/davisp
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_master
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_issue-822-queries-test
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_increase-default-rounds
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_hard-fail-cookie-mode
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_jan-test
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_kxepal-2752-validate-host
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_reformat-mango-explain
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_random-seed-chttpd-pids
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_rebar3
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_mem3-seedlist
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_michellephung-patch-1
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_reduce_default_max_dbs_open
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_one-ex-ex
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_record_last_compaction
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_optimize-ddoc-cache
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_optimize-rexi
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_test-events
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_revert-dedup-detection
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_revert-1143-issue-820-remove-queries-for_all_docs
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_test-cet_recompact_updates
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_start-app-order
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_shard-local-query
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_test-branch
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_test-looking-glass
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_run-mango-tests-with-check
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_revert-1367-COUCHDB-3326-clustered-purge-pr2-simplify-mem3-rep
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_windsor-merge
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_tmp-fix-compaction-daemon-test-with-pse
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_wip-pse-test-suite-rewrite
# cloning branch /Users/suvodeepmajumder/Documents/AI4SE/Git_miner/temp_repo/couchdb_trigger-chttpd-error
# Phase one done
# Phase two done
# Phase three done
# Phase four done
# Phase five done
# Phase six done
# Phase seven done
# Phase eight done
# couchdb Repo Done
